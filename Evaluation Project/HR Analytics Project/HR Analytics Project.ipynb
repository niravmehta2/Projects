# %%
#importing libraries which is needed for this case study
import pandas as pd
import numpy as np

# %%
#importing csv file
df=pd.read_csv("WA_Fn-UseC_-HR-Employee-Attrition.csv")

# %%
df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
#checking the null values in all the columns
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %% [markdown]
# # EDA
# Scatterplot

# %%
import seaborn as sns
sns.scatterplot(x="Age",y="Attrition",data=df)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Attrition'>

# %%
import seaborn as sns
sns.scatterplot(x="BusinessTravel",y="Attrition",data=df)
# Out:
# <AxesSubplot:xlabel='BusinessTravel', ylabel='Attrition'>

# %%
import seaborn as sns
sns.scatterplot(x="DailyRate",y="Attrition",data=df)
# Out:
# <AxesSubplot:xlabel='DailyRate', ylabel='Attrition'>

# %%
import seaborn as sns
sns.scatterplot(x="Department",y="Attrition",data=df)
# Out:
# <AxesSubplot:xlabel='Department', ylabel='Attrition'>

# %%
import seaborn as sns
sns.scatterplot(x="DistanceFromHome",y="Attrition",data=df)
# Out:
# <AxesSubplot:xlabel='DistanceFromHome', ylabel='Attrition'>

# %%
import seaborn as sns
sns.scatterplot(x="Education",y="Attrition",data=df)
# Out:
# <AxesSubplot:xlabel='Education', ylabel='Attrition'>

# %%
import seaborn as sns
sns.scatterplot(x="EducationField",y="Attrition",data=df)
# Out:
# <AxesSubplot:xlabel='EducationField', ylabel='Attrition'>

# %%
import seaborn as sns
sns.scatterplot(x="EmployeeCount",y="Attrition",data=df)
# Out:
# <AxesSubplot:xlabel='EmployeeCount', ylabel='Attrition'>

# %%
import seaborn as sns
sns.scatterplot(x="EmployeeNumber",y="Attrition",data=df)
# Out:
# <AxesSubplot:xlabel='EmployeeNumber', ylabel='Attrition'>

# %%
import seaborn as sns
sns.scatterplot(x="EnvironmentSatisfaction",y="Attrition",data=df)
# Out:
# <AxesSubplot:xlabel='EnvironmentSatisfaction', ylabel='Attrition'>

# %%
import seaborn as sns
sns.scatterplot(x="Gender",y="Attrition",data=df)
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='Attrition'>

# %%
import seaborn as sns
sns.scatterplot(x="HourlyRate",y="Attrition",data=df)
# Out:
# <AxesSubplot:xlabel='HourlyRate', ylabel='Attrition'>

# %%
import seaborn as sns
sns.scatterplot(x="JobInvolvement",y="Attrition",data=df)
# Out:
# <AxesSubplot:xlabel='JobInvolvement', ylabel='Attrition'>

# %%
import seaborn as sns
sns.scatterplot(x="JobLevel",y="Attrition",data=df)
# Out:
# <AxesSubplot:xlabel='JobLevel', ylabel='Attrition'>

# %%
import seaborn as sns
sns.scatterplot(x="JobRole",y="Attrition",data=df)
# Out:
# <AxesSubplot:xlabel='JobRole', ylabel='Attrition'>

# %%
import seaborn as sns
sns.scatterplot(x="JobSatisfaction",y="Attrition",data=df)
# Out:
# <AxesSubplot:xlabel='JobSatisfaction', ylabel='Attrition'>

# %%
import seaborn as sns
sns.scatterplot(x="MaritalStatus",y="Attrition",data=df)
# Out:
# <AxesSubplot:xlabel='MaritalStatus', ylabel='Attrition'>

# %%
import seaborn as sns
sns.scatterplot(x="MonthlyIncome",y="Attrition",data=df)
# Out:
# <AxesSubplot:xlabel='MonthlyIncome', ylabel='Attrition'>

# %%
import seaborn as sns
sns.scatterplot(x="MonthlyRate",y="Attrition",data=df)
# Out:
# <AxesSubplot:xlabel='MonthlyRate', ylabel='Attrition'>

# %%
import seaborn as sns
sns.scatterplot(x="NumCompaniesWorked",y="Attrition",data=df)
# Out:
# <AxesSubplot:xlabel='NumCompaniesWorked', ylabel='Attrition'>

# %%
import seaborn as sns
sns.scatterplot(x="Over18",y="Attrition",data=df)
# Out:
# <AxesSubplot:xlabel='Over18', ylabel='Attrition'>

# %%
import seaborn as sns
sns.scatterplot(x="OverTime",y="Attrition",data=df)
# Out:
# <AxesSubplot:xlabel='OverTime', ylabel='Attrition'>

# %%
import seaborn as sns
sns.scatterplot(x="PercentSalaryHike",y="Attrition",data=df)
# Out:
# <AxesSubplot:xlabel='PercentSalaryHike', ylabel='Attrition'>

# %%
import seaborn as sns
sns.scatterplot(x="PerformanceRating",y="Attrition",data=df)
# Out:
# <AxesSubplot:xlabel='PerformanceRating', ylabel='Attrition'>

# %%
import seaborn as sns
sns.scatterplot(x="RelationshipSatisfaction",y="Attrition",data=df)
# Out:
# <AxesSubplot:xlabel='RelationshipSatisfaction', ylabel='Attrition'>

# %%
import seaborn as sns
sns.scatterplot(x="StandardHours",y="Attrition",data=df)
# Out:
# <AxesSubplot:xlabel='StandardHours', ylabel='Attrition'>

# %%
import seaborn as sns
sns.scatterplot(x="StockOptionLevel",y="Attrition",data=df)
# Out:
# <AxesSubplot:xlabel='StockOptionLevel', ylabel='Attrition'>

# %%
import seaborn as sns
sns.scatterplot(x="TotalWorkingYears",y="Attrition",data=df)
# Out:
# <AxesSubplot:xlabel='TotalWorkingYears', ylabel='Attrition'>

# %%
import seaborn as sns
sns.scatterplot(x="TrainingTimesLastYear",y="Attrition",data=df)
# Out:
# <AxesSubplot:xlabel='TrainingTimesLastYear', ylabel='Attrition'>

# %%
import seaborn as sns
sns.scatterplot(x="WorkLifeBalance",y="Attrition",data=df)
# Out:
# <AxesSubplot:xlabel='WorkLifeBalance', ylabel='Attrition'>

# %%
import seaborn as sns
sns.scatterplot(x="YearsAtCompany",y="Attrition",data=df)
# Out:
# <AxesSubplot:xlabel='YearsAtCompany', ylabel='Attrition'>

# %%
import seaborn as sns
sns.scatterplot(x="YearsInCurrentRole",y="Attrition",data=df)
# Out:
# <AxesSubplot:xlabel='YearsInCurrentRole', ylabel='Attrition'>

# %%
import seaborn as sns
sns.scatterplot(x="YearsSinceLastPromotion",y="Attrition",data=df)
# Out:
# <AxesSubplot:xlabel='YearsSinceLastPromotion', ylabel='Attrition'>

# %%
import seaborn as sns
sns.scatterplot(x="YearsWithCurrManager",y="Attrition",data=df)
# Out:
# <AxesSubplot:xlabel='YearsWithCurrManager', ylabel='Attrition'>

# %%
#replacing yes and no values to 0 and 1
df = df.replace({'Attrition': {'Yes': 1, 
                                'No': 0}})

# %%
df
# Out:
#       Age  Attrition     BusinessTravel  DailyRate              Department  \
# 0      41          1      Travel_Rarely       1102                   Sales
# 1      49          0  Travel_Frequently        279  Research & Development
# 2      37          1      Travel_Rarely       1373  Research & Development
# 3      33          0  Travel_Frequently       1392  Research & Development
# 4      27          0      Travel_Rarely        591  Research & Development
# ...   ...        ...                ...        ...                     ...
# 1465   36          0  Travel_Frequently        884  Research & Development
# 1466   39          0      Travel_Rarely        613  Research & Development
# 1467   27          0      Travel_Rarely        155  Research & Development
# 1468   49          0  Travel_Frequently       1023                   Sales
# 1469   34          0      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %% [markdown]
# # Correlation

# %%
#checking the correlation with target columns
df.corr()
# Out:
#                                Age  Attrition  DailyRate  DistanceFromHome  \
# Age                       1.000000  -0.159205   0.010661         -0.001686
# Attrition                -0.159205   1.000000  -0.056652          0.077924
# DailyRate                 0.010661  -0.056652   1.000000         -0.004985
# DistanceFromHome         -0.001686   0.077924  -0.004985          1.000000
# Education                 0.208034  -0.031373  -0.016806          0.021042
# EmployeeCount                  NaN        NaN        NaN               NaN
# EmployeeNumber           -0.010145  -0.010577  -0.050990          0.032916
# EnvironmentSatisfaction   0.010146  -0.103369   0.018355         -0.016075
# HourlyRate                0.024287  -0.006846   0.023381          0.031131
# JobInvolvement            0.029820  -0.130016   0.046135          0.008783
# JobLevel                  0.509604  -0.169105   0.002966          0.005303
# ...

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(15,7))
sns.heatmap(df.corr(), annot=True, linewidth=0.5, linecolor="black", fmt=".2f")
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Describing Dataset

# %%
df.describe()
# Out:
#                Age    Attrition    DailyRate  DistanceFromHome    Education  \
# count  1470.000000  1470.000000  1470.000000       1470.000000  1470.000000
# mean     36.923810     0.161224   802.485714          9.192517     2.912925
# std       9.135373     0.367863   403.509100          8.106864     1.024165
# min      18.000000     0.000000   102.000000          1.000000     1.000000
# 25%      30.000000     0.000000   465.000000          2.000000     2.000000
# 50%      36.000000     0.000000   802.000000          7.000000     3.000000
# 75%      43.000000     0.000000  1157.000000         14.000000     4.000000
# max      60.000000     1.000000  1499.000000         29.000000     5.000000
#
#        EmployeeCount  EmployeeNumber  EnvironmentSatisfaction   HourlyRate  \
# count         1470.0     1470.000000              1470.000000  1470.000000
# mean             1.0     1024.865306                 2.721769    65.891156
# ...

# %%
plt.figure(figsize=(15,12))
sns.heatmap(round(df.describe()[1:].transpose(),2),linewidth=2,annot=True,fmt="f")
plt.xticks(fontsize=18)
plt.yticks(fontsize=12)
plt.title("Variables Summary")
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   int64
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %% [markdown]
# # Skewness

# %%
df.skew()
# Out:
# C:\Users\Nirav\AppData\Local\Temp/ipykernel_6688/1665899112.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.skew()
# Age                         0.413286
# Attrition                   1.844366
# DailyRate                  -0.003519
# DistanceFromHome            0.958118
# Education                  -0.289681
# EmployeeCount               0.000000
# EmployeeNumber              0.016574
# EnvironmentSatisfaction    -0.321654
# HourlyRate                 -0.032311
# JobInvolvement             -0.498419
# JobLevel                    1.025401
# JobSatisfaction            -0.329672
# MonthlyIncome               1.369817
# MonthlyRate                 0.018578
# NumCompaniesWorked          1.026471
# PercentSalaryHike           0.821128
# PerformanceRating           1.921883
# RelationshipSatisfaction   -0.302828
# ...

# %% [markdown]
# # Normal Distribution Curve:

# %%
sns.displot(df["Age"])

# %%
sns.displot(df["Attrition"])

# %%
sns.displot(df["DailyRate"])

# %%
sns.displot(df["DistanceFromHome"])

# %%
sns.displot(df["Education"])

# %%
sns.displot(df["EmployeeCount"])

# %%
sns.displot(df["EmployeeNumber"])

# %%
sns.displot(df["EnvironmentSatisfaction"])

# %%
sns.displot(df["HourlyRate"])

# %%
sns.displot(df["JobInvolvement"])

# %%
sns.displot(df["JobLevel"])

# %%
sns.displot(df["JobSatisfaction"])

# %%
sns.displot(df["MonthlyIncome"])

# %%
sns.displot(df["MonthlyRate"])

# %%
sns.displot(df["NumCompaniesWorked"])

# %%
sns.displot(df["PercentSalaryHike"])

# %%
sns.displot(df["PerformanceRating"])

# %%
sns.displot(df["RelationshipSatisfaction"])

# %%
sns.displot(df["StandardHours"])

# %%
sns.displot(df["StockOptionLevel"])

# %%
sns.displot(df["TotalWorkingYears"])

# %%
sns.displot(df["TrainingTimesLastYear"])

# %%
sns.displot(df["WorkLifeBalance"])

# %%
sns.displot(df["YearsAtCompany"])

# %%
sns.displot(df["YearsInCurrentRole"])

# %%
sns.displot(df["YearsSinceLastPromotion"])

# %%
sns.displot(df["YearsWithCurrManager"])

# %% [markdown]
# # Making the data frame for the nominal data

# %%
df_visualization_nominal=df[['Age','Attrition','BusinessTravel','DailyRate','Department','DistanceFromHome','Education','EducationField','EmployeeCount','EmployeeNumber','EnvironmentSatisfaction','Gender','HourlyRate','JobInvolvement','JobLevel','JobRole','JobSatisfaction','MaritalStatus','MonthlyIncome','MonthlyRate','NumCompaniesWorked','Over18','OverTime','PercentSalaryHike','PerformanceRating','RelationshipSatisfaction','StandardHours','StockOptionLevel','TotalWorkingYears','TrainingTimesLastYear','WorkLifeBalance','YearsAtCompany','YearsInCurrentRole','YearsSinceLastPromotion','YearsWithCurrManager']].copy()

# %%
df_visualization_nominal.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %% [markdown]
# # Visualization of the data:

# %%
import seaborn as sns

# %%
ax = sns.countplot(x="Age", data=df_visualization_nominal)
print(df_visualization_nominal["Age"].value_counts())
# Out:
# 35    78
# 34    77
# 36    69
# 31    69
# 29    68
# 32    61
# 30    60
# 33    58
# 38    58
# 40    57
# 37    50
# 27    48
# 28    48
# 42    46
# 39    42
# 45    41
# 41    40
# 26    39
# 44    33
# 46    33
# 43    32
# 50    30
# 25    26
# 24    26
# 49    24
# 47    24
# 55    22
# 51    19
# 53    19
# 48    19
# 54    18
# 52    18
# 22    16
# 56    14
# 23    14
# 58    14
# 21    13
# 20    11
# 59    10
# 19     9
# 18     8
# 60     5
# 57     4
# Name: Age, dtype: int64

# %%
ax = sns.countplot(x="Attrition", data=df_visualization_nominal)
print(df_visualization_nominal["Attrition"].value_counts())
# Out:
# 0    1233
# 1     237
# Name: Attrition, dtype: int64

# %%
ax = sns.countplot(x="BusinessTravel", data=df_visualization_nominal)
print(df_visualization_nominal["BusinessTravel"].value_counts())
# Out:
# Travel_Rarely        1043
# Travel_Frequently     277
# Non-Travel            150
# Name: BusinessTravel, dtype: int64

# %%
ax = sns.countplot(x="DailyRate", data=df_visualization_nominal)
print(df_visualization_nominal["DailyRate"].value_counts())
# Out:
# 691     6
# 408     5
# 530     5
# 1329    5
# 1082    5
#        ..
# 650     1
# 279     1
# 316     1
# 314     1
# 628     1
# Name: DailyRate, Length: 886, dtype: int64

# %%
ax = sns.countplot(x="Department", data=df_visualization_nominal)
print(df_visualization_nominal["Department"].value_counts())
# Out:
# Research & Development    961
# Sales                     446
# Human Resources            63
# Name: Department, dtype: int64

# %%
ax = sns.countplot(x="DistanceFromHome", data=df_visualization_nominal)
print(df_visualization_nominal["DistanceFromHome"].value_counts())
# Out:
# 2     211
# 1     208
# 10     86
# 9      85
# 3      84
# 7      84
# 8      80
# 5      65
# 4      64
# 6      59
# 16     32
# 11     29
# 24     28
# 23     27
# 29     27
# 15     26
# 18     26
# 26     25
# 25     25
# 20     25
# 28     23
# 19     22
# 14     21
# 12     20
# 17     20
# 22     19
# 13     19
# 21     18
# 27     12
# Name: DistanceFromHome, dtype: int64

# %%
ax = sns.countplot(x="Education", data=df_visualization_nominal)
print(df_visualization_nominal["Education"].value_counts())
# Out:
# 3    572
# 4    398
# 2    282
# 1    170
# 5     48
# Name: Education, dtype: int64

# %%
ax = sns.countplot(x="EducationField", data=df_visualization_nominal)
print(df_visualization_nominal["EducationField"].value_counts())
# Out:
# Life Sciences       606
# Medical             464
# Marketing           159
# Technical Degree    132
# Other                82
# Human Resources      27
# Name: EducationField, dtype: int64

# %%
ax = sns.countplot(x="EmployeeCount", data=df_visualization_nominal)
print(df_visualization_nominal["EmployeeCount"].value_counts())
# Out:
# 1    1470
# Name: EmployeeCount, dtype: int64

# %%
ax = sns.countplot(x="EmployeeNumber", data=df_visualization_nominal)
print(df_visualization_nominal["EmployeeNumber"].value_counts())
# Out:
# 1       1
# 1391    1
# 1389    1
# 1387    1
# 1383    1
#        ..
# 659     1
# 657     1
# 656     1
# 655     1
# 2068    1
# Name: EmployeeNumber, Length: 1470, dtype: int64

# %%
ax = sns.countplot(x="EnvironmentSatisfaction", data=df_visualization_nominal)
print(df_visualization_nominal["EnvironmentSatisfaction"].value_counts())
# Out:
# 3    453
# 4    446
# 2    287
# 1    284
# Name: EnvironmentSatisfaction, dtype: int64

# %%
ax = sns.countplot(x="Gender", data=df_visualization_nominal)
print(df_visualization_nominal["Gender"].value_counts())
# Out:
# Male      882
# Female    588
# Name: Gender, dtype: int64

# %%
ax = sns.countplot(x="HourlyRate", data=df_visualization_nominal)
print(df_visualization_nominal["HourlyRate"].value_counts())
# Out:
# 66    29
# 98    28
# 42    28
# 48    28
# 84    28
#       ..
# 31    15
# 53    14
# 68    14
# 38    13
# 34    12
# Name: HourlyRate, Length: 71, dtype: int64

# %%
ax = sns.countplot(x="JobInvolvement", data=df_visualization_nominal)
print(df_visualization_nominal["JobInvolvement"].value_counts())
# Out:
# 3    868
# 2    375
# 4    144
# 1     83
# Name: JobInvolvement, dtype: int64

# %%
ax = sns.countplot(x="JobLevel", data=df_visualization_nominal)
print(df_visualization_nominal["JobLevel"].value_counts())
# Out:
# 1    543
# 2    534
# 3    218
# 4    106
# 5     69
# Name: JobLevel, dtype: int64

# %%
ax = sns.countplot(x="JobRole", data=df_visualization_nominal)
print(df_visualization_nominal["JobRole"].value_counts())
# Out:
# Sales Executive              326
# Research Scientist           292
# Laboratory Technician        259
# Manufacturing Director       145
# Healthcare Representative    131
# Manager                      102
# Sales Representative          83
# Research Director             80
# Human Resources               52
# Name: JobRole, dtype: int64

# %%
ax = sns.countplot(x="JobSatisfaction", data=df_visualization_nominal)
print(df_visualization_nominal["JobSatisfaction"].value_counts())
# Out:
# 4    459
# 3    442
# 1    289
# 2    280
# Name: JobSatisfaction, dtype: int64

# %%
ax = sns.countplot(x="MaritalStatus", data=df_visualization_nominal)
print(df_visualization_nominal["MaritalStatus"].value_counts())
# Out:
# Married     673
# Single      470
# Divorced    327
# Name: MaritalStatus, dtype: int64

# %%
ax = sns.countplot(x="MonthlyIncome", data=df_visualization_nominal)
print(df_visualization_nominal["MonthlyIncome"].value_counts())
# Out:
# 2342     4
# 6142     3
# 2741     3
# 2559     3
# 2610     3
#         ..
# 7104     1
# 2773     1
# 19513    1
# 3447     1
# 4404     1
# Name: MonthlyIncome, Length: 1349, dtype: int64

# %%
ax = sns.countplot(x="MonthlyRate", data=df_visualization_nominal)
print(df_visualization_nominal["MonthlyRate"].value_counts())
# Out:
# 4223     3
# 9150     3
# 9558     2
# 12858    2
# 22074    2
#         ..
# 14561    1
# 2671     1
# 5718     1
# 11757    1
# 10228    1
# Name: MonthlyRate, Length: 1427, dtype: int64

# %%
ax = sns.countplot(x="NumCompaniesWorked", data=df_visualization_nominal)
print(df_visualization_nominal["NumCompaniesWorked"].value_counts())
# Out:
# 1    521
# 0    197
# 3    159
# 2    146
# 4    139
# 7     74
# 6     70
# 5     63
# 9     52
# 8     49
# Name: NumCompaniesWorked, dtype: int64

# %%
ax = sns.countplot(x="Over18", data=df_visualization_nominal)
print(df_visualization_nominal["Over18"].value_counts())
# Out:
# Y    1470
# Name: Over18, dtype: int64

# %%
ax = sns.countplot(x="OverTime", data=df_visualization_nominal)
print(df_visualization_nominal["OverTime"].value_counts())
# Out:
# No     1054
# Yes     416
# Name: OverTime, dtype: int64

# %%
ax = sns.countplot(x="PercentSalaryHike", data=df_visualization_nominal)
print(df_visualization_nominal["PercentSalaryHike"].value_counts())
# Out:
# 11    210
# 13    209
# 14    201
# 12    198
# 15    101
# 18     89
# 17     82
# 16     78
# 19     76
# 22     56
# 20     55
# 21     48
# 23     28
# 24     21
# 25     18
# Name: PercentSalaryHike, dtype: int64

# %%
ax = sns.countplot(x="PerformanceRating", data=df_visualization_nominal)
print(df_visualization_nominal["PerformanceRating"].value_counts())
# Out:
# 3    1244
# 4     226
# Name: PerformanceRating, dtype: int64

# %%
ax = sns.countplot(x="RelationshipSatisfaction", data=df_visualization_nominal)
print(df_visualization_nominal["RelationshipSatisfaction"].value_counts())
# Out:
# 3    459
# 4    432
# 2    303
# 1    276
# Name: RelationshipSatisfaction, dtype: int64

# %%
ax = sns.countplot(x="StandardHours", data=df_visualization_nominal)
print(df_visualization_nominal["StandardHours"].value_counts())
# Out:
# 80    1470
# Name: StandardHours, dtype: int64

# %%
ax = sns.countplot(x="StockOptionLevel", data=df_visualization_nominal)
print(df_visualization_nominal["StockOptionLevel"].value_counts())
# Out:
# 0    631
# 1    596
# 2    158
# 3     85
# Name: StockOptionLevel, dtype: int64

# %%
ax = sns.countplot(x="TotalWorkingYears", data=df_visualization_nominal)
print(df_visualization_nominal["TotalWorkingYears"].value_counts())
# Out:
# 10    202
# 6     125
# 8     103
# 9      96
# 5      88
# 7      81
# 1      81
# 4      63
# 12     48
# 3      42
# 15     40
# 16     37
# 11     36
# 13     36
# 21     34
# 17     33
# 2      31
# 14     31
# 20     30
# 18     27
# 19     22
# 23     22
# 22     21
# 24     18
# 25     14
# 28     14
# 26     14
# 0      11
# 29     10
# 31      9
# 32      9
# 30      7
# 33      7
# 27      7
# 36      6
# 34      5
# 37      4
# 35      3
# 40      2
# 38      1
# Name: TotalWorkingYears, dtype: int64

# %%
ax = sns.countplot(x="TrainingTimesLastYear", data=df_visualization_nominal)
print(df_visualization_nominal["TrainingTimesLastYear"].value_counts())
# Out:
# 2    547
# 3    491
# 4    123
# 5    119
# 1     71
# 6     65
# 0     54
# Name: TrainingTimesLastYear, dtype: int64

# %%
ax = sns.countplot(x="WorkLifeBalance", data=df_visualization_nominal)
print(df_visualization_nominal["WorkLifeBalance"].value_counts())
# Out:
# 3    893
# 2    344
# 4    153
# 1     80
# Name: WorkLifeBalance, dtype: int64

# %%
ax = sns.countplot(x="YearsAtCompany", data=df_visualization_nominal)
print(df_visualization_nominal["YearsAtCompany"].value_counts())
# Out:
# 5     196
# 1     171
# 3     128
# 2     127
# 10    120
# 4     110
# 7      90
# 9      82
# 8      80
# 6      76
# 0      44
# 11     32
# 20     27
# 13     24
# 15     20
# 14     18
# 22     15
# 12     14
# 21     14
# 18     13
# 16     12
# 19     11
# 17      9
# 24      6
# 33      5
# 25      4
# 26      4
# 31      3
# 32      3
# 27      2
# 36      2
# 29      2
# 23      2
# 37      1
# 40      1
# 34      1
# 30      1
# Name: YearsAtCompany, dtype: int64

# %%
ax = sns.countplot(x="YearsInCurrentRole", data=df_visualization_nominal)
print(df_visualization_nominal["YearsInCurrentRole"].value_counts())
# Out:
# 2     372
# 0     244
# 7     222
# 3     135
# 4     104
# 8      89
# 9      67
# 1      57
# 6      37
# 5      36
# 10     29
# 11     22
# 13     14
# 14     11
# 12     10
# 15      8
# 16      7
# 17      4
# 18      2
# Name: YearsInCurrentRole, dtype: int64

# %%
ax = sns.countplot(x="YearsSinceLastPromotion", data=df_visualization_nominal)
print(df_visualization_nominal["YearsSinceLastPromotion"].value_counts())
# Out:
# 0     581
# 1     357
# 2     159
# 7      76
# 4      61
# 3      52
# 5      45
# 6      32
# 11     24
# 8      18
# 9      17
# 15     13
# 13     10
# 12     10
# 14      9
# 10      6
# Name: YearsSinceLastPromotion, dtype: int64

# %%
ax = sns.countplot(x="YearsWithCurrManager", data=df_visualization_nominal)
print(df_visualization_nominal["YearsWithCurrManager"].value_counts())
# Out:
# 2     344
# 0     263
# 7     216
# 3     142
# 8     107
# 4      98
# 1      76
# 9      64
# 5      31
# 6      29
# 10     27
# 11     22
# 12     18
# 13     14
# 17      7
# 15      5
# 14      5
# 16      2
# Name: YearsWithCurrManager, dtype: int64

# %% [markdown]
# # Making Dataframe of the ordinal data

# %%
sns.catplot(x="Age",y="Attrition", data=df)

# %%
sns.catplot(x="DailyRate",y="Attrition", data=df)

# %%
sns.catplot(x="DistanceFromHome",y="Attrition", data=df)

# %%
sns.catplot(x="Education",y="Attrition", data=df)

# %%
sns.catplot(x="EmployeeCount",y="Attrition", data=df)

# %%
sns.catplot(x="EmployeeNumber",y="Attrition", data=df)

# %%
sns.catplot(x="EnvironmentSatisfaction",y="Attrition", data=df)

# %%
sns.catplot(x="HourlyRate",y="Attrition", data=df)

# %%
sns.catplot(x="JobInvolvement",y="Attrition", data=df)

# %%
sns.catplot(x="JobLevel",y="Attrition", data=df)

# %%
sns.catplot(x="JobSatisfaction",y="Attrition", data=df)

# %%
sns.catplot(x="MonthlyIncome",y="Attrition", data=df)

# %%
sns.catplot(x="MonthlyRate",y="Attrition", data=df)

# %%
sns.catplot(x="NumCompaniesWorked",y="Attrition", data=df)

# %%
sns.catplot(x="PercentSalaryHike",y="Attrition", data=df)

# %%
sns.catplot(x="PerformanceRating",y="Attrition", data=df)

# %%
sns.catplot(x="RelationshipSatisfaction",y="Attrition", data=df)

# %%
sns.catplot(x="StandardHours",y="Attrition", data=df)

# %%
sns.catplot(x="StockOptionLevel",y="Attrition", data=df)

# %%
sns.catplot(x="TotalWorkingYears",y="Attrition", data=df)

# %%
sns.catplot(x="TrainingTimesLastYear",y="Attrition", data=df)

# %%
sns.catplot(x="WorkLifeBalance",y="Attrition", data=df)

# %%
sns.catplot(x="YearsAtCompany",y="Attrition", data=df)

# %%
sns.catplot(x="YearsInCurrentRole",y="Attrition", data=df)

# %%
sns.catplot(x="YearsSinceLastPromotion",y="Attrition", data=df)

# %%
sns.catplot(x="YearsWithCurrManager",y="Attrition", data=df)

# %%
df
# Out:
#       Age  Attrition     BusinessTravel  DailyRate              Department  \
# 0      41          1      Travel_Rarely       1102                   Sales
# 1      49          0  Travel_Frequently        279  Research & Development
# 2      37          1      Travel_Rarely       1373  Research & Development
# 3      33          0  Travel_Frequently       1392  Research & Development
# 4      27          0      Travel_Rarely        591  Research & Development
# ...   ...        ...                ...        ...                     ...
# 1465   36          0  Travel_Frequently        884  Research & Development
# 1466   39          0      Travel_Rarely        613  Research & Development
# 1467   27          0      Travel_Rarely        155  Research & Development
# 1468   49          0  Travel_Frequently       1023                   Sales
# 1469   34          0      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(22,7))
sns.heatmap(df.describe(),annot=True,linewidths=0.1,linecolor="black",fmt="0.2f")
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Correlation of the columns with the target columns

# %%
df.corr()
# Out:
#                                Age  Attrition  DailyRate  DistanceFromHome  \
# Age                       1.000000  -0.159205   0.010661         -0.001686
# Attrition                -0.159205   1.000000  -0.056652          0.077924
# DailyRate                 0.010661  -0.056652   1.000000         -0.004985
# DistanceFromHome         -0.001686   0.077924  -0.004985          1.000000
# Education                 0.208034  -0.031373  -0.016806          0.021042
# EmployeeCount                  NaN        NaN        NaN               NaN
# EmployeeNumber           -0.010145  -0.010577  -0.050990          0.032916
# EnvironmentSatisfaction   0.010146  -0.103369   0.018355         -0.016075
# HourlyRate                0.024287  -0.006846   0.023381          0.031131
# JobInvolvement            0.029820  -0.130016   0.046135          0.008783
# JobLevel                  0.509604  -0.169105   0.002966          0.005303
# ...

# %%
plt.figure(figsize=(22,7))
sns.heatmap(df.corr(),annot=True,linewidths=0.1,linecolor="black",fmt="0.2f")
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Checking the columns which are positively and negetively correlated with taget columns

# %%
plt.figure(figsize=(22,7))
df.corr()["Attrition"].drop(['Attrition']).plot(kind="bar",color="c")
plt.xlabel("Feature",fontsize=14)
plt.ylabel('columns with target names' ,fontsize=14)
plt.title('correlation',fontsize=18)
plt.show()

# %%
df.skew()
# Out:
# C:\Users\Nirav\AppData\Local\Temp/ipykernel_6688/1665899112.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.skew()
# Age                         0.413286
# Attrition                   1.844366
# DailyRate                  -0.003519
# DistanceFromHome            0.958118
# Education                  -0.289681
# EmployeeCount               0.000000
# EmployeeNumber              0.016574
# EnvironmentSatisfaction    -0.321654
# HourlyRate                 -0.032311
# JobInvolvement             -0.498419
# JobLevel                    1.025401
# JobSatisfaction            -0.329672
# MonthlyIncome               1.369817
# MonthlyRate                 0.018578
# NumCompaniesWorked          1.026471
# PercentSalaryHike           0.821128
# PerformanceRating           1.921883
# RelationshipSatisfaction   -0.302828
# ...

# %% [markdown]
# # Outliers Checking

# %%
df.dtypes
# Out:
# Age                          int64
# Attrition                    int64
# BusinessTravel              object
# DailyRate                    int64
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                      object
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                     object
# JobSatisfaction              int64
# MaritalStatus               object
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# Over18                      object
# OverTime                    object
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# ...

# %% [markdown]
# # Data Cleaning:

# %%
delete=pd.DataFrame([["Over18"],["OverTime"],["MaritalStatus"],["OverTime"],["JobRole"],["Gender"],["EducationField"],["Department"],["BusinessTravel"],["EmployeeCount"],["StandardHours"]],columns=["column name"])
delete
# Out:
#        column name
# 0           Over18
# 1         OverTime
# 2    MaritalStatus
# 3         OverTime
# 4          JobRole
# 5           Gender
# 6   EducationField
# 7       Department
# 8   BusinessTravel
# 9    EmployeeCount
# 10   StandardHours

# %%
df=df.drop(["StandardHours","EmployeeCount","BusinessTravel","Department","EducationField","Gender","JobRole","OverTime","MaritalStatus","Over18"],axis=1)
df
# Out:
#       Age  Attrition  DailyRate  DistanceFromHome  Education  EmployeeNumber  \
# 0      41          1       1102                 1          2               1
# 1      49          0        279                 8          1               2
# 2      37          1       1373                 2          2               4
# 3      33          0       1392                 3          4               5
# 4      27          0        591                 2          1               7
# ...   ...        ...        ...               ...        ...             ...
# 1465   36          0        884                23          2            2061
# 1466   39          0        613                 6          1            2062
# 1467   27          0        155                 4          3            2064
# 1468   49          0       1023                 2          3            2065
# 1469   34          0        628                 8          3            2068
#
# ...

# %%
df['Age'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['Attrition'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['DailyRate'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['DistanceFromHome'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['Education'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['EmployeeNumber'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['EnvironmentSatisfaction'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['HourlyRate'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['JobInvolvement'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['JobLevel'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['JobSatisfaction'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['MonthlyIncome'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['MonthlyRate'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['NumCompaniesWorked'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['PercentSalaryHike'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['PerformanceRating'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['RelationshipSatisfaction'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['StockOptionLevel'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['TotalWorkingYears'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['TrainingTimesLastYear'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['WorkLifeBalance'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['YearsAtCompany'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['YearsInCurrentRole'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['YearsSinceLastPromotion'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['YearsWithCurrManager'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Removing outliers:

# %%
from scipy.stats import zscore
import numpy as np
z=np.abs(zscore(df))
z.shape
# Out:
# (1470, 25)

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([  28,   45,   62,   62,   63,   64,   85,   98,   98,  110,  123,
#         123,  123,  126,  126,  126,  153,  178,  187,  187,  190,  190,
#         218,  231,  231,  237,  237,  270,  270,  281,  326,  386,  386,
#         401,  411,  425,  425,  427,  445,  466,  473,  477,  535,  561,
#         561,  584,  592,  595,  595,  595,  616,  624,  635,  653,  653,
#         677,  686,  701,  716,  746,  749,  752,  799,  838,  861,  861,
#         875,  875,  894,  914,  914,  918,  922,  926,  926,  937,  956,
#         962,  976,  976, 1008, 1024, 1043, 1078, 1078, 1086, 1086, 1093,
#        1111, 1116, 1116, 1135, 1138, 1138, 1156, 1184, 1221, 1223, 1242,
#        1295, 1301, 1301, 1303, 1327, 1331, 1348, 1351, 1401, 1414, 1430],
#       dtype=int64), array([24, 23, 21, 23, 22, 23, 18, 18, 21, 23, 22, 23, 24, 18, 21, 23, 24,
#        23, 18, 24, 21, 22, 23, 22, 24, 21, 23, 18, 21, 22, 23, 23, 24, 18,
# ...

# %%
df_new=df[(z<3).all(axis=1)]
print(df.shape)
print(df_new.shape)
# Out:
# (1470, 25)
# (1387, 25)

# %% [markdown]
# # Percentage data loss:

# %%
loss_percent=(1470-1387)/1470*100
print(loss_percent)
# Out:
# 5.646258503401361

# %% [markdown]
# # Model without outliers is df and model with desired outliers is df_new1

# %%
x=df_new.iloc[:,:-1]
y=df_new.iloc[:,-1]

# %% [markdown]
# # Transforming data to remove skewness

# %%
from sklearn.preprocessing import power_transform
x=power_transform(x,method='yeo-johnson')
# Out:
# C:\Users\Nirav\anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:3237: RuntimeWarning: divide by zero encountered in log
#   loglike = -n_samples / 2 * np.log(x_trans.var())

# %%
x
# Out:
# array([[ 0.61281697,  2.24872599,  0.73108262, ...,  0.22175343,
#          0.27723209, -1.09800485],
#        [ 1.36747456, -0.44469624, -1.3032589 , ...,  0.94834801,
#          1.00841729,  0.26355728],
#        [ 0.1870853 ,  2.24872599,  1.40174582, ..., -2.12278559,
#         -1.55241624, -1.09800485],
#        ...,
#        [-1.08172691, -0.44469624, -1.65176844, ...,  0.22175343,
#         -0.40317247, -1.09800485],
#        [ 1.36747456, -0.44469624,  0.53569569, ...,  0.78824636,
#          0.78975636, -1.09800485],
#        [-0.15913516, -0.44469624, -0.4293719 , ..., -0.26719515,
#         -0.0337768 ,  0.26355728]])

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(x)
x
# Out:
# array([[ 0.61281697,  2.24872599,  0.73108262, ...,  0.22175343,
#          0.27723209, -1.09800485],
#        [ 1.36747456, -0.44469624, -1.3032589 , ...,  0.94834801,
#          1.00841729,  0.26355728],
#        [ 0.1870853 ,  2.24872599,  1.40174582, ..., -2.12278559,
#         -1.55241624, -1.09800485],
#        ...,
#        [-1.08172691, -0.44469624, -1.65176844, ...,  0.22175343,
#         -0.40317247, -1.09800485],
#        [ 1.36747456, -0.44469624,  0.53569569, ...,  0.78824636,
#          0.78975636, -1.09800485],
#        [-0.15913516, -0.44469624, -0.4293719 , ..., -0.26719515,
#         -0.0337768 ,  0.26355728]])

# %% [markdown]
# # Since the outcome has only two variable we willuse binary classification mode

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression()
from sklearn.metrics import accuracy_score

# %% [markdown]
# # Encoding of Dataframe

# %%
from sklearn.preprocessing import OrdinalEncoder
enc=OrdinalEncoder()

# %%
for i in df.columns:
    if df[i].dtypes=="object":
        df[i]=enc.fit_transform(df[i].values.reshape(-1,1))

# %%
df
# Out:
#       Age  Attrition  DailyRate  DistanceFromHome  Education  EmployeeNumber  \
# 0      41          1       1102                 1          2               1
# 1      49          0        279                 8          1               2
# 2      37          1       1373                 2          2               4
# 3      33          0       1392                 3          4               5
# 4      27          0        591                 2          1               7
# ...   ...        ...        ...               ...        ...             ...
# 1465   36          0        884                23          2            2061
# 1466   39          0        613                 6          1            2062
# 1467   27          0        155                 4          3            2064
# 1468   49          0       1023                 2          3            2065
# 1469   34          0        628                 8          3            2068
#
# ...

# %% [markdown]
# # Let's Check the Data Distribution among all the columns

# %%
df.plot(kind='density', subplots=True, layout=(6,11), sharex=False, legend=False, fontsize=1, figsize=(18,12))
plt.show()

# %% [markdown]
# # Data distriubution in each column

# %%
plt.figure(figsize=(20,25), facecolor='white')
plotnumber = 1

for column in df:
    if plotnumber<=18:
        ax = plt.subplot(6,3,plotnumber)
        sns.distplot(df[column],color='b')
        plt.xlabel(column,fontsize=20)
    plotnumber+=1
plt.show()
# Out:
# C:\Users\Nirav\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Nirav\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %% [markdown]
# # Seprating the columns into features and target:

# %%
features=df.drop("Attrition",axis=1)
target=df["Attrition"]

# %% [markdown]
# # Scalling the data using min max scaler

# %%
from sklearn.preprocessing import MinMaxScaler
mms=MinMaxScaler()
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
for i in range(0,100):
    features_train,features_test,target_train,target_test=train_test_split(features,target,test_size=0.2,random_state=i)
    lr.fit(features_train,target_train)
    pred_train=lr.predict(features_train)
    pred_test=lr.predict(features_test)
    print(f"At random state {i},the training accuracy is: - {r2_score(target_train,pred_train)}")
    print(f"At random state {i},the testing accuracy is: - {r2_score(target_test,pred_test)}")
    print("\n")
# Out:
# At random state 0,the training accuracy is: - 0.1367271301385976
# At random state 0,the testing accuracy is: - 0.13153779299543356
#
#
# At random state 1,the training accuracy is: - 0.13524383281867214
# At random state 1,the testing accuracy is: - 0.11078483786143278
#
#
# At random state 2,the training accuracy is: - 0.1457678295415692
# At random state 2,the testing accuracy is: - 0.09026497573963022
#
#
# At random state 3,the training accuracy is: - 0.1393813988738869
# At random state 3,the testing accuracy is: - 0.11413389588025669
#
#
# At random state 4,the training accuracy is: - 0.13609610513019654
# At random state 4,the testing accuracy is: - 0.12499612825585737
#
#
# At random state 5,the training accuracy is: - 0.13860562278771615
# At random state 5,the testing accuracy is: - 0.12418102132380082
#
#
# At random state 6,the training accuracy is: - 0.13238324392935885
# At random state 6,the testing accuracy is: - 0.14353873881507762
#
#
# ...

# %%
features_train,features_test,target_train,target_test=train_test_split(features,target,test_size=0.2,random_state=12)

# %%
lr.fit(features_train,target_train)
# Out:
# LinearRegression()

# %%
pred_test=lr.predict(features_test)

# %%
print(r2_score(target_test,pred_test))
# Out:
# 0.11855335344952656

# %% [markdown]
# # Crosss-validation of the model

# %%
Train_accuracy=r2_score(target_train,pred_train)
Test_accuracy=r2_score(target_test,pred_test)

from sklearn.model_selection import cross_val_score
for j in range(2,10):
    cv_score=cross_val_score(lr,features,target,cv=j)
    cv_mean=cv_score.mean()
    print(f"At cross fold {j} the cv score is {cv_mean} and accuracy score for training is {Train_accuracy} and accuracy for the testing is {Test_accuracy}")
    print("\n")
# Out:
# At cross fold 2 the cv score is 0.07548784955421917 and accuracy score for training is -0.14101500110021004 and accuracy for the testing is 0.11855335344952656
#
#
# At cross fold 3 the cv score is 0.09893862221371497 and accuracy score for training is -0.14101500110021004 and accuracy for the testing is 0.11855335344952656
#
#
# At cross fold 4 the cv score is 0.0969035455784209 and accuracy score for training is -0.14101500110021004 and accuracy for the testing is 0.11855335344952656
#
#
# At cross fold 5 the cv score is 0.10651090038489688 and accuracy score for training is -0.14101500110021004 and accuracy for the testing is 0.11855335344952656
#
#
# At cross fold 6 the cv score is 0.1086223853718097 and accuracy score for training is -0.14101500110021004 and accuracy for the testing is 0.11855335344952656
#
#
# At cross fold 7 the cv score is 0.1017044530096362 and accuracy score for training is -0.14101500110021004 and accuracy for the testing is 0.11855335344952656
#
#
# ...

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(8,6))
plt.scatter(x=target_test, y=pred_test, color='r')
plt.plot(target_test,target_test, color='b')
plt.xlabel('Actual charges',fontsize=14)
plt.ylabel('Predicted charges',fontsize=14)
plt.title('Linear Regression',fontsize=18)
plt.show()

# %% [markdown]
# # Regularization

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
import warnings
warnings.filterwarnings('ignore')

# %%
from sklearn.linear_model import Lasso

parameters = {'alpha' :[.0001, .001, .01, .1, 1, 10], 'random_state':list(range(0,10))}
ls = Lasso()
clf = GridSearchCV(ls,parameters)
clf.fit(features_train,target_train)

print(clf.best_params_)
# Out:
# {'alpha': 0.001, 'random_state': 0}

# %%
ls = Lasso(alpha=0.001,random_state=0)
ls.fit(features_train,target_train)
ls.score(features_train,target_train)
pred_ls = ls.predict(features_test)

lss = r2_score(target_test,pred_ls)
lss
# Out:
# 0.12095661526396695

# %%
cv_score=cross_val_score(ls,features,target,cv=5)
cv_mean=cv_score.mean()
cv_mean
# Out:
# 0.1067759727251816

# %% [markdown]
# # Ensemble technique

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor

parameters = {'criterion':['mse', 'mae'],'max_features':["auto", "sqrt", "log2"]}
rf =RandomForestRegressor()
clf = GridSearchCV(rf,parameters)
clf.fit(features_train,target_train)

print(clf.best_params_)
# Out:
# {'criterion': 'mse', 'max_features': 'sqrt'}

# %%
rf= RandomForestRegressor(criterion="mse",max_features="sqrt")
rf.fit(features_train, target_train)
rf.score(features_train, target_train)
pred_decision = rf.predict(features_test)

rfs = r2_score(target_test,pred_decision)
print('R2 Score:',rfs*100)

rfscore = cross_val_score(rf,features,target,cv=5)
rfc = rfscore.mean()
print('Cross Val Score:',rfc*100)
# Out:
# R2 Score: 11.56620426829268
# Cross Val Score: 10.154169498420137

# %% [markdown]
# # We are getting model accuracy 11.56% and cross validation 10.15%

# %% [markdown]
# # Modeling

# %%
from sklearn.model_selection import train_test_split as TTS
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

# %%
from sklearn.linear_model import LinearRegression, Lasso, Ridge
from sklearn.ensemble import RandomForestRegressor, AdaBoostRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor as KNN
from sklearn.svm import SVR
from sklearn.linear_model import SGDRegressor
from sklearn.metrics import classification_report
from sklearn.model_selection import cross_val_score
from sklearn import metrics

# %%
#Linear Regression
LR = LinearRegression()
LR.fit(x_train,y_train)
predLR = LR.predict(x_test)
# R2_Score
print("R2_score:",r2_score(y_test,predLR))

# Mean Absolute Error (MAE)
print("MAE:",metrics.mean_absolute_error(y_test,predLR))

#Mean Squared Error (MSE)
print("MSE:",metrics.mean_squared_error(y_test,predLR))
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_test,predLR)))
# Out:
# R2_score: 0.565813730041703
# MAE: 1.4807668211261165
# MSE: 4.208607897332299
# RMSE: 2.051489190157311

# %%
from sklearn.linear_model import Ridge
from sklearn.model_selection import GridSearchCV
paramsRidge = {'alpha':[0.01,0.1,1.0,10.26],'solver':['auto','svd','cholesky','lsqr','sparse_cg','sag','saga']}
ridge = Ridge()
clf = GridSearchCV(ridge,paramsRidge)
clf.fit(x_train,y_train)
print(clf.best_params_)
# Out:
# {'alpha': 1.0, 'solver': 'auto'}

# %%
#Ridge Regression
ridge = Ridge(alpha=1.0,solver='auto')
ridge.fit(x_train,y_train)
ridge.score(x_train,y_train)
pred_ridge = ridge.predict(x_test)
# R2_Score
print("R2_score:",r2_score(y_test,pred_ridge))

# Mean Absolute Error (MAE)
print("MAE:",metrics.mean_absolute_error(y_test,pred_ridge))

#Mean Squared Error (MSE)
print("MSE:",metrics.mean_squared_error(y_test,pred_ridge))

# Root Mean Squared Error
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_test,pred_ridge)))
# Out:
# R2_score: 0.5661083653551346
# MAE: 1.4802060778668473
# MSE: 4.205751969835879
# RMSE: 2.050793009992934

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import Lasso
parameters = {'alpha':[0.0001,0.001,0.01,0.1,1,10],'random_state':list(range(0,100))}
lasso = Lasso()
clf = GridSearchCV(lasso,parameters)
clf.fit(x_train,y_train)
print(clf.best_params_)
# Out:
# {'alpha': 0.1, 'random_state': 0}

# %%
#Lasso Regression
lasso = Lasso(alpha=0.1,random_state=0)
lasso.fit(x_train,y_train)
lasso.score(x_train,y_train)
pred_lasso = lasso.predict(x_test)
# R2_Score
print("R2_score:",r2_score(y_test,pred_lasso))

# Mean Absolute Error (MAE)
print("MAE:",metrics.mean_absolute_error(y_test,pred_lasso))

#Mean Squared Error (MSE)
print("MSE:",metrics.mean_squared_error(y_test,pred_lasso))

# Root Mean Squared Error
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_test,pred_lasso)))
# Out:
# R2_score: 0.580323969602847
# MAE: 1.442699815955199
# MSE: 4.0679587957034515
# RMSE: 2.0169181430349252

# %%
#SGD regression
SGD = SGDRegressor()
SGD.fit(x_train,y_train)

predSGD=SGD.predict(x_test)
# R2_Score
print("R2_score:",r2_score(y_test,predSGD))

# Mean Absolute Error (MAE)
print("MAE:",metrics.mean_absolute_error(y_test,predSGD))

#Mean Squared Error (MSE)
print("MSE:",metrics.mean_squared_error(y_test,predSGD))

# Root Mean Squared Error
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_test,predSGD)))
# Out:
# R2_score: 0.5641089726635471
# MAE: 1.4854146645566793
# MSE: 4.22513226915417
# RMSE: 2.055512653610814

# %% [markdown]
# # After all the modeling regression the score is like for
# 1)Linear Regression
# R2_score: 0.565813730041703
# MAE: 1.4807668211261165
# MSE: 4.208607897332299
# RMSE: 2.051489190157311
#
# 2)Ridge Regression
# R2_score: 0.5661083653551346
# MAE: 1.4802060778668473
# MSE: 4.205751969835879
# RMSE: 2.050793009992934
#
# 3)Lasso Regression
# R2_score: 0.580323969602847
# MAE: 1.442699815955199
# MSE: 4.0679587957034515
# RMSE: 2.0169181430349252
#
# 4)SGD regression
# R2_score: 0.5641089726635471
# MAE: 1.4854146645566793
# MSE: 4.22513226915417
# RMSE: 2.055512653610814

# %%
import pickle
filename = 'HR_Analytics_Project.pkl'
pickle.dump(rf, open(filename, 'wb'))
