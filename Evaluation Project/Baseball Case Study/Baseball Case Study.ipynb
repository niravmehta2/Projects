# %%
#importing libraries which is needed for this case study
import pandas as pd
import numpy as np

# %%
#importing csv file
df=pd.read_csv("https://raw.githubusercontent.com/dsrscientist/Data-Science-ML-Capstone-Projects/master/baseball.csv")

# %%
df
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# 11   86  729  5459  1363  278  26  230  486  1392  121  618  572  3.57   5
# 12   85  661  5417  1331  243  21  176  435  1150   52  675  630  3.94   2
# 13   76  656  5544  1379  262  22  198  478  1336   69  726  677  4.16   6
# 14   68  694  5600  1405  277  46  146  475  1119   78  729  664  4.14   5
# 15  100  647  5484  1386  288  39  137  506  1267   69  525  478  2.94   1
# 16   98  697  5631  1462  292  27  140  461  1322   98  596  532  3.21   0
# 17   97  689  5491  1341  272  30  171  567  1518   95  608  546  3.36   6
# 18   68  655  5480  1378  274  34  145  412  1299   84  737  682  4.28   1
# 19   64  640  5571  1382  257  27  167  496  1255  134  754  700  4.33   2
# 20   90  683  5527  1351  295  17  177  488  1290   51  613  557  3.43   1
# 21   83  703  5428  1363  265  13  177  539  1344   57  635  577  3.62   4
# 22   71  613  5463  1420  236  40  120  375  1150  112  678  638  4.02   0
# 23   67  573  5420  1361  251  18  100  471  1107   69  760  698  4.41   3
# 24   63  626  5529  1374  272  37  130  387  1274   88  809  749  4.69   1
# 25   92  667  5385  1346  263  26  187  563  1258   59  595  553  3.44   6
# 26   84  696  5565  1486  288  39  136  457  1159   93  627  597  3.72   7
# 27   79  720  5649  1494  289  48  154  490  1312  132  713  659  4.04   1
# 28   74  650  5457  1324  260  36  148  426  1327   82  731  655  4.09   1
# 29   68  737  5572  1479  274  49  186  388  1283   97  844  799  5.04   4
#
#     SHO  SV    E
# 0     8  56   88
# 1    12  45   86
# 2    10  38   79
# 3     9  37  101
# 4    12  35   86
# 5    10  34   88
# 6     4  48   93
# 7    10  43   77
# 8    12  60   95
# 9    10  40   97
# 10    9  45  119
# 11   13  39   85
# 12   12  46   93
# 13   12  45   94
# 14   15  28  126
# 15   15  62   96
# 16   13  54  122
# 17   21  48  111
# 18    7  40  116
# 19    8  35   90
# 20   14  50   88
# 21   13  41   90
# 22   12  35   77
# 23   10  44   90
# 24    7  35  117
# 25   21  47   75
# 26   18  41   78
# 27   12  44   86
# 28    6  41   92
# 29    4  36   95

# %%
df.columns
# Out:
# Index(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
#        'ERA', 'CG', 'SHO', 'SV', 'E'],
#       dtype='object')

# %%
#checking the null values in all the columns
df.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %% [markdown]
# # EDA
# Scatterplot

# %%
import seaborn as sns
sns.scatterplot(x="R",y="W",data=df)
# Out:
# <AxesSubplot:xlabel='R', ylabel='W'>

# %%
import seaborn as sns
sns.scatterplot(x="AB",y="W",data=df)
# Out:
# <AxesSubplot:xlabel='AB', ylabel='W'>

# %%
import seaborn as sns
sns.scatterplot(x="H",y="W",data=df)
# Out:
# <AxesSubplot:xlabel='H', ylabel='W'>

# %%
import seaborn as sns
sns.scatterplot(x="2B",y="W",data=df)
# Out:
# <AxesSubplot:xlabel='2B', ylabel='W'>

# %%
import seaborn as sns
sns.scatterplot(x="3B",y="W",data=df)
# Out:
# <AxesSubplot:xlabel='3B', ylabel='W'>

# %%
import seaborn as sns
sns.scatterplot(x="HR",y="W",data=df)
# Out:
# <AxesSubplot:xlabel='HR', ylabel='W'>

# %%
import seaborn as sns
sns.scatterplot(x="BB",y="W",data=df)
# Out:
# <AxesSubplot:xlabel='BB', ylabel='W'>

# %%
import seaborn as sns
sns.scatterplot(x="SO",y="W",data=df)
# Out:
# <AxesSubplot:xlabel='SO', ylabel='W'>

# %%
import seaborn as sns
sns.scatterplot(x="SB",y="W",data=df)
# Out:
# <AxesSubplot:xlabel='SB', ylabel='W'>

# %%
import seaborn as sns
sns.scatterplot(x="RA",y="W",data=df)
# Out:
# <AxesSubplot:xlabel='RA', ylabel='W'>

# %%
import seaborn as sns
sns.scatterplot(x="ER",y="W",data=df)
# Out:
# <AxesSubplot:xlabel='ER', ylabel='W'>

# %%
import seaborn as sns
sns.scatterplot(x="ERA",y="W",data=df)
# Out:
# <AxesSubplot:xlabel='ERA', ylabel='W'>

# %%
import seaborn as sns
sns.scatterplot(x="CG",y="W",data=df)
# Out:
# <AxesSubplot:xlabel='CG', ylabel='W'>

# %%
import seaborn as sns
sns.scatterplot(x="SHO",y="W",data=df)
# Out:
# <AxesSubplot:xlabel='SHO', ylabel='W'>

# %%
import seaborn as sns
sns.scatterplot(x="SV",y="W",data=df)
# Out:
# <AxesSubplot:xlabel='SV', ylabel='W'>

# %%
import seaborn as sns
sns.scatterplot(x="E",y="W",data=df)
# Out:
# <AxesSubplot:xlabel='E', ylabel='W'>

# %% [markdown]
# # Correlation

# %%
#checking the correlation with target columns
df.corr()
# Out:
#             W         R        AB         H        2B        3B        HR  \
# W    1.000000  0.430751 -0.087947  0.037612  0.427797 -0.251118  0.307407
# R    0.430751  1.000000  0.319464  0.482856  0.560084 -0.070072  0.671283
# AB  -0.087947  0.319464  1.000000  0.739122  0.453370  0.435422 -0.066983
# H    0.037612  0.482856  0.739122  1.000000  0.566847  0.478694 -0.090855
# 2B   0.427797  0.560084  0.453370  0.566847  1.000000  0.220490  0.056292
# 3B  -0.251118 -0.070072  0.435422  0.478694  0.220490  1.000000 -0.430915
# HR   0.307407  0.671283 -0.066983 -0.090855  0.056292 -0.430915  1.000000
# BB   0.484342  0.402452 -0.136414 -0.118281  0.302700 -0.454949  0.425691
# SO   0.111850 -0.054726 -0.106022 -0.398830 -0.150752 -0.141196  0.359923
# SB  -0.157234  0.081367  0.372618  0.413444  0.195027  0.457437 -0.136567
# RA  -0.812952 -0.041623  0.316010  0.224324 -0.218160  0.314125 -0.103903
# ER  -0.809435 -0.041245  0.309686  0.252489 -0.235531  0.340225 -0.085922
# ERA -0.819600 -0.049281  0.255551  0.231172 -0.254854  0.330951 -0.090917
# CG   0.080533  0.232042 -0.080876  0.147955  0.306675 -0.065898  0.156502
# SHO  0.471805 -0.103274 -0.197321 -0.145559  0.057998 -0.041396 -0.019119
# SV   0.666530 -0.096380 -0.106367 -0.130371  0.171576 -0.142370 -0.028540
# E   -0.089485 -0.023262  0.316743 -0.033173  0.105754  0.126678 -0.207597
#
#            BB        SO        SB        RA        ER       ERA        CG  \
# W    0.484342  0.111850 -0.157234 -0.812952 -0.809435 -0.819600  0.080533
# R    0.402452 -0.054726  0.081367 -0.041623 -0.041245 -0.049281  0.232042
# AB  -0.136414 -0.106022  0.372618  0.316010  0.309686  0.255551 -0.080876
# H   -0.118281 -0.398830  0.413444  0.224324  0.252489  0.231172  0.147955
# 2B   0.302700 -0.150752  0.195027 -0.218160 -0.235531 -0.254854  0.306675
# 3B  -0.454949 -0.141196  0.457437  0.314125  0.340225  0.330951 -0.065898
# HR   0.425691  0.359923 -0.136567 -0.103903 -0.085922 -0.090917  0.156502
# BB   1.000000  0.233652 -0.098347 -0.416445 -0.452663 -0.459832  0.462478
# SO   0.233652  1.000000  0.030968 -0.129745 -0.161612 -0.180368 -0.093418
# SB  -0.098347  0.030968  1.000000  0.132290  0.143068  0.126063 -0.020783
# RA  -0.416445 -0.129745  0.132290  1.000000  0.991018  0.986674 -0.016659
# ER  -0.452663 -0.161612  0.143068  0.991018  1.000000  0.997248 -0.020221
# ERA -0.459832 -0.180368  0.126063  0.986674  0.997248  1.000000 -0.009856
# CG   0.462478 -0.093418 -0.020783 -0.016659 -0.020221 -0.009856  1.000000
# SHO  0.426004  0.237721 -0.106563 -0.636862 -0.630192 -0.630833  0.241676
# SV   0.099445  0.126297 -0.183418 -0.616224 -0.589663 -0.607005 -0.367766
# E   -0.075685  0.155133  0.079149  0.198996  0.136921  0.113137 -0.140047
#
#           SHO        SV         E
# W    0.471805  0.666530 -0.089485
# R   -0.103274 -0.096380 -0.023262
# AB  -0.197321 -0.106367  0.316743
# H   -0.145559 -0.130371 -0.033173
# 2B   0.057998  0.171576  0.105754
# 3B  -0.041396 -0.142370  0.126678
# HR  -0.019119 -0.028540 -0.207597
# BB   0.426004  0.099445 -0.075685
# SO   0.237721  0.126297  0.155133
# SB  -0.106563 -0.183418  0.079149
# RA  -0.636862 -0.616224  0.198996
# ER  -0.630192 -0.589663  0.136921
# ERA -0.630833 -0.607005  0.113137
# CG   0.241676 -0.367766 -0.140047
# SHO  1.000000  0.221639 -0.115716
# SV   0.221639  1.000000 -0.025636
# E   -0.115716 -0.025636  1.000000

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(15,7))
sns.heatmap(df.corr(), annot=True, linewidth=0.5, linecolor="black", fmt=".2f")
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Outcome of Correlation
# All the columnsv of dataset is positivly correlated to the target columns
#
# max correlation with :- BB(Base on balls or walk)
#
# min correlation with :- ERA(Earned Run Average)

# %% [markdown]
# # Describing Dataset

# %%
df.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# min    13.000000  100.000000  375.000000   973.00000   44.000000  525.000000
# 25%    23.000000  140.250000  428.250000  1157.50000   69.000000  636.250000
# 50%    31.000000  158.500000  473.000000  1261.50000   83.500000  695.500000
# 75%    39.000000  177.000000  501.250000  1311.50000   96.500000  732.500000
# max    49.000000  232.000000  570.000000  1518.00000  134.000000  844.000000
#
#                ER        ERA         CG        SHO         SV           E
# count   30.000000  30.000000  30.000000  30.000000  30.000000   30.000000
# mean   635.833333   3.956333   3.466667  11.300000  43.066667   94.333333
# std     70.140786   0.454089   2.763473   4.120177   7.869335   13.958889
# min    478.000000   2.940000   0.000000   4.000000  28.000000   75.000000
# 25%    587.250000   3.682500   1.000000   9.000000  37.250000   86.000000
# 50%    644.500000   4.025000   3.000000  12.000000  42.000000   91.000000
# 75%    679.250000   4.220000   5.750000  13.000000  46.750000   96.750000
# max    799.000000   5.040000  11.000000  21.000000  62.000000  126.000000

# %%
plt.figure(figsize=(15,12))
sns.heatmap(round(df.describe()[1:].transpose(),2),linewidth=2,annot=True,fmt="f")
plt.xticks(fontsize=18)
plt.yticks(fontsize=12)
plt.title("Variables Summary")
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       30 non-null     int64
#  1   R       30 non-null     int64
#  2   AB      30 non-null     int64
#  3   H       30 non-null     int64
#  4   2B      30 non-null     int64
#  5   3B      30 non-null     int64
#  6   HR      30 non-null     int64
#  7   BB      30 non-null     int64
#  8   SO      30 non-null     int64
#  9   SB      30 non-null     int64
#  10  RA      30 non-null     int64
#  11  ER      30 non-null     int64
#  12  ERA     30 non-null     float64
#  13  CG      30 non-null     int64
#  14  SHO     30 non-null     int64
#  15  SV      30 non-null     int64
#  16  E       30 non-null     int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %% [markdown]
# # Outliers Checking:

# %%
collist=df.columns.values
ncol=30
nrows=14
plt.figure(figsize=(ncol,3*ncol))
for i in range (0, len(collist)):
    plt.subplot(nrows,ncol,i+1)
    sns.boxplot(df[collist[i]],color='green',orient='v')
    plt.tight_layout()
# Out:
# C:\Users\Nirav\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Nirav\anaconda3\lib\site-packages\seaborn\_core.py:1326: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))
# C:\Users\Nirav\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Nirav\anaconda3\lib\site-packages\seaborn\_core.py:1326: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))
# C:\Users\Nirav\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Nirav\anaconda3\lib\site-packages\seaborn\_core.py:1326: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))
# C:\Users\Nirav\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Nirav\anaconda3\lib\site-packages\seaborn\_core.py:1326: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))
# C:\Users\Nirav\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Nirav\anaconda3\lib\site-packages\seaborn\_core.py:1326: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))
# C:\Users\Nirav\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Nirav\anaconda3\lib\site-packages\seaborn\_core.py:1326: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))
# C:\Users\Nirav\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Nirav\anaconda3\lib\site-packages\seaborn\_core.py:1326: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))
# C:\Users\Nirav\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Nirav\anaconda3\lib\site-packages\seaborn\_core.py:1326: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))
# C:\Users\Nirav\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Nirav\anaconda3\lib\site-packages\seaborn\_core.py:1326: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))
# C:\Users\Nirav\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Nirav\anaconda3\lib\site-packages\seaborn\_core.py:1326: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))
# C:\Users\Nirav\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Nirav\anaconda3\lib\site-packages\seaborn\_core.py:1326: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))
# C:\Users\Nirav\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Nirav\anaconda3\lib\site-packages\seaborn\_core.py:1326: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))
# C:\Users\Nirav\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Nirav\anaconda3\lib\site-packages\seaborn\_core.py:1326: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))
# C:\Users\Nirav\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Nirav\anaconda3\lib\site-packages\seaborn\_core.py:1326: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))
# C:\Users\Nirav\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Nirav\anaconda3\lib\site-packages\seaborn\_core.py:1326: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))
# C:\Users\Nirav\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Nirav\anaconda3\lib\site-packages\seaborn\_core.py:1326: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))
# C:\Users\Nirav\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Nirav\anaconda3\lib\site-packages\seaborn\_core.py:1326: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))

# %%
plt.figure(figsize=(20,25),facecolor='white')
plotnumber=1

for column in df:
    if plotnumber<=15:
        ax=plt.subplot(6,4,plotnumber)
        sns.boxplot(df[column],color='green')
        plt.xlabel(column,fontsize=20)
    plotnumber+=1
plt.show()

# %% [markdown]
# # Skewness

# %%
df.skew()
# Out:
# W      0.047089
# R      1.200786
# AB     0.183437
# H      0.670254
# 2B    -0.230650
# 3B     0.129502
# HR     0.516441
# BB     0.158498
# SO    -0.156065
# SB     0.479893
# RA     0.045734
# ER     0.058710
# ERA    0.053331
# CG     0.736845
# SHO    0.565790
# SV     0.657524
# E      0.890132
# dtype: float64

# %% [markdown]
# # Normal Distribution Curve:

# %%
sns.displot(df["W"])

# %%
sns.displot(df["R"])

# %%
sns.displot(df["AB"])

# %%
sns.displot(df["H"])

# %%
sns.displot(df["2B"])

# %%
sns.displot(df["3B"])

# %%
sns.displot(df["HR"])

# %%
sns.displot(df["BB"])

# %%
sns.displot(df["SO"])

# %%
sns.displot(df["SB"])

# %%
sns.displot(df["RA"])

# %%
sns.displot(df["ER"])

# %%
sns.displot(df["ERA"])

# %%
sns.displot(df["CG"])

# %%
sns.displot(df["SHO"])

# %%
sns.displot(df["SV"])

# %%
sns.displot(df["E"])

# %% [markdown]
# # Removing outliers:

# %%
from scipy.stats import zscore
import numpy as np
z=np.abs(zscore(df))
z.shape
# Out:
# (30, 17)

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([5], dtype=int64), array([1], dtype=int64))

# %%
df_new=df[(z<3).all(axis=1)]
print(df.shape)
print(df_new.shape)
# Out:
# (30, 17)
# (29, 17)

# %% [markdown]
# # Percentage data loss:

# %%
loss_percent=(30-29)/30*100
print(loss_percent)
# Out:
# 3.3333333333333335

# %% [markdown]
# # Model without outliers is df and model with desired outliers is df_new1

# %%
x=df_new.iloc[:,:-1]
y=df_new.iloc[:,-1]

# %% [markdown]
# # Transforming data to remove skewness

# %%
from sklearn.preprocessing import power_transform
x=power_transform(x,method='yeo-johnson')
# Out:
# C:\Users\Nirav\anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:3237: RuntimeWarning: divide by zero encountered in log
#   loglike = -n_samples / 2 * np.log(x_trans.var())

# %%
x
# Out:
# array([[ 1.38207890e+00,  9.62543504e-01,  0.00000000e+00,
#          0.00000000e+00,  1.68518793e+00,  1.00615029e+00,
#         -7.41927000e-01, -1.60519802e+00, -2.55061247e+00,
#          9.36131648e-01, -6.60978697e-01, -5.08052224e-01,
#         -5.09292146e-01, -3.07098204e-01, -7.87002186e-01,
#          1.53275292e+00],
#        [ 2.75098810e-01,  2.98863300e-01,  0.00000000e+00,
#          0.00000000e+00,  1.38197902e-01,  1.18522654e+00,
#         -1.09958425e-01, -4.62095966e-01,  9.36832915e-02,
#         -5.16377335e-01,  1.60225829e-01,  2.35800488e-01,
#          2.41440214e-01, -3.07098204e-01,  2.36736538e-01,
#          3.12020186e-01],
#        [ 8.15199217e-02, -3.12105130e-01,  0.00000000e+00,
#          0.00000000e+00,  1.90738550e+00, -2.28819392e-01,
#         -6.64354121e-01,  1.23209786e+00, -9.35611465e-01,
#          2.25038365e-01, -6.74967476e-01, -7.52213881e-01,
#         -6.42097599e-01,  2.01131531e+00, -2.52844176e-01,
#         -6.64136739e-01],
#        [-4.15211377e-01, -1.30829774e+00,  0.00000000e+00,
#          0.00000000e+00, -8.37664770e-01, -4.32227907e-01,
#         -8.60039342e-01, -1.16272085e+00, -2.30682707e-01,
#         -6.18421529e-01,  1.74076810e-01,  9.30906974e-02,
#          4.30132461e-02,  1.26446344e+00, -5.13554932e-01,
#         -8.20688859e-01],
#        [-6.19336470e-01,  1.37737301e-01,  0.00000000e+00,
#          0.00000000e+00,  9.11434794e-01,  1.62263592e+00,
#         -2.89646675e-01, -1.55685826e-01,  4.41433307e-02,
#          9.50377681e-02,  1.57597053e+00,  1.55585333e+00,
#          1.49349103e+00,  1.26446344e+00,  2.36736538e-01,
#         -1.14916472e+00],
#        [ 6.54092576e-01,  1.96420873e+00,  0.00000000e+00,
#          0.00000000e+00, -1.63010220e-01, -1.29582738e+00,
#          1.63163749e+00,  1.57949358e+00, -2.69582692e-01,
#         -8.84525554e-01,  1.32517300e-01,  2.21536563e-01,
#          1.53276229e-01,  1.21870592e-01, -2.06403920e+00,
#          6.77176215e-01],
#        [ 8.15199217e-02,  6.98145564e-01,  0.00000000e+00,
#          0.00000000e+00, -1.54263548e+00, -1.18275843e+00,
#         -2.21933710e-01],
#        [-1.25213173e+00,  1.28115156e+00,  0.00000000e+00,
#          0.00000000e+00, -4.39755655e-02,  1.62263592e+00,
#          8.77641898e-01, -1.49822954e+00,  2.83212126e-01,
#          6.72393731e-01,  2.13380015e+00,  2.30280108e+00,
#          2.36764236e+00,  4.72300348e-01, -2.06403920e+00,
#         -9.82263658e-01]])

# %% [markdown]
# # Since the outcome has only two variable we willuse binary classification model

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression()
from sklearn.metrics import accuracy_score

# %% [markdown]
# # Encoding of Dataframe

# %%
from sklearn.preprocessing import OrdinalEncoder
enc=OrdinalEncoder()

# %%
for i in df.columns:
    if df[i].dtypes=="object":
        df[i]=enc.fit_transform(df[i].values.reshape(-1,1))

# %%
df
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# 11   86  729  5459  1363  278  26  230  486  1392  121  618  572  3.57   5
# 12   85  661  5417  1331  243  21  176  435  1150   52  675  630  3.94   2
# 13   76  656  5544  1379  262  22  198  478  1336   69  726  677  4.16   6
# 14   68  694  5600  1405  277  46  146  475  1119   78  729  664  4.14   5
# 15  100  647  5484  1386  288  39  137  506  1267   69  525  478  2.94   1
# 16   98  697  5631  1462  292  27  140  461  1322   98  596  532  3.21   0
# 17   97  689  5491  1341  272  30  171  567  1518   95  608  546  3.36   6
# 18   68  655  5480  1378  274  34  145  412  1299   84  737  682  4.28   1
# 19   64  640  5571  1382  257  27  167  496  1255  134  754  700  4.33   2
# 20   90  683  5527  1351  295  17  177  488  1290   51  613  557  3.43   1
# 21   83  703  5428  1363  265  13  177  539  1344   57  635  577  3.62   4
# 22   71  613  5463  1420  236  40  120  375  1150  112  678  638  4.02   0
# 23   67  573  5420  1361  251  18  100  471  1107   69  760  698  4.41   3
# 24   63  626  5529  1374  272  37  130  387  1274   88  809  749  4.69   1
# 25   92  667  5385  1346  263  26  187  563  1258   59  595  553  3.44   6
# 26   84  696  5565  1486  288  39  136  457  1159   93  627  597  3.72   7
# 27   79  720  5649  1494  289  48  154  490  1312  132  713  659  4.04   1
# 28   74  650  5457  1324  260  36  148  426  1327   82  731  655  4.09   1
# 29   68  737  5572  1479  274  49  186  388  1283   97  844  799  5.04   4
#
#     SHO  SV    E
# 0     8  56   88
# 1    12  45   86
# 2    10  38   79
# 3     9  37  101
# 4    12  35   86
# 5    10  34   88
# 6     4  48   93
# 7    10  43   77
# 8    12  60   95
# 9    10  40   97
# 10    9  45  119
# 11   13  39   85
# 12   12  46   93
# 13   12  45   94
# 14   15  28  126
# 15   15  62   96
# 16   13  54  122
# 17   21  48  111
# 18    7  40  116
# 19    8  35   90
# 20   14  50   88
# 21   13  41   90
# 22   12  35   77
# 23   10  44   90
# 24    7  35  117
# 25   21  47   75
# 26   18  41   78
# 27   12  44   86
# 28    6  41   92
# 29    4  36   95

# %% [markdown]
# # Describe the dataset

# %%
df.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# min    13.000000  100.000000  375.000000   973.00000   44.000000  525.000000
# 25%    23.000000  140.250000  428.250000  1157.50000   69.000000  636.250000
# 50%    31.000000  158.500000  473.000000  1261.50000   83.500000  695.500000
# 75%    39.000000  177.000000  501.250000  1311.50000   96.500000  732.500000
# max    49.000000  232.000000  570.000000  1518.00000  134.000000  844.000000
#
#                ER        ERA         CG        SHO         SV           E
# count   30.000000  30.000000  30.000000  30.000000  30.000000   30.000000
# mean   635.833333   3.956333   3.466667  11.300000  43.066667   94.333333
# std     70.140786   0.454089   2.763473   4.120177   7.869335   13.958889
# min    478.000000   2.940000   0.000000   4.000000  28.000000   75.000000
# 25%    587.250000   3.682500   1.000000   9.000000  37.250000   86.000000
# 50%    644.500000   4.025000   3.000000  12.000000  42.000000   91.000000
# 75%    679.250000   4.220000   5.750000  13.000000  46.750000   96.750000
# max    799.000000   5.040000  11.000000  21.000000  62.000000  126.000000

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(22,7))
sns.heatmap(df.describe(),annot=True,linewidths=0.1,linecolor="black",fmt="0.2f")
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Correlation with target columns

# %%
df.corr()
# Out:
#             W         R        AB         H        2B        3B        HR  \
# W    1.000000  0.430751 -0.087947  0.037612  0.427797 -0.251118  0.307407
# R    0.430751  1.000000  0.319464  0.482856  0.560084 -0.070072  0.671283
# AB  -0.087947  0.319464  1.000000  0.739122  0.453370  0.435422 -0.066983
# H    0.037612  0.482856  0.739122  1.000000  0.566847  0.478694 -0.090855
# 2B   0.427797  0.560084  0.453370  0.566847  1.000000  0.220490  0.056292
# 3B  -0.251118 -0.070072  0.435422  0.478694  0.220490  1.000000 -0.430915
# HR   0.307407  0.671283 -0.066983 -0.090855  0.056292 -0.430915  1.000000
# BB   0.484342  0.402452 -0.136414 -0.118281  0.302700 -0.454949  0.425691
# SO   0.111850 -0.054726 -0.106022 -0.398830 -0.150752 -0.141196  0.359923
# SB  -0.157234  0.081367  0.372618  0.413444  0.195027  0.457437 -0.136567
# RA  -0.812952 -0.041623  0.316010  0.224324 -0.218160  0.314125 -0.103903
# ER  -0.809435 -0.041245  0.309686  0.252489 -0.235531  0.340225 -0.085922
# ERA -0.819600 -0.049281  0.255551  0.231172 -0.254854  0.330951 -0.090917
# CG   0.080533  0.232042 -0.080876  0.147955  0.306675 -0.065898  0.156502
# SHO  0.471805 -0.103274 -0.197321 -0.145559  0.057998 -0.041396 -0.019119
# SV   0.666530 -0.096380 -0.106367 -0.130371  0.171576 -0.142370 -0.028540
# E   -0.089485 -0.023262  0.316743 -0.033173  0.105754  0.126678 -0.207597
#
#            BB        SO        SB        RA        ER       ERA        CG  \
# W    0.484342  0.111850 -0.157234 -0.812952 -0.809435 -0.819600  0.080533
# R    0.402452 -0.054726  0.081367 -0.041623 -0.041245 -0.049281  0.232042
# AB  -0.136414 -0.106022  0.372618  0.316010  0.309686  0.255551 -0.080876
# H   -0.118281 -0.398830  0.413444  0.224324  0.252489  0.231172  0.147955
# 2B   0.302700 -0.150752  0.195027 -0.218160 -0.235531 -0.254854  0.306675
# 3B  -0.454949 -0.141196  0.457437  0.314125  0.340225  0.330951 -0.065898
# HR   0.425691  0.359923 -0.136567 -0.103903 -0.085922 -0.090917  0.156502
# BB   1.000000  0.233652 -0.098347 -0.416445 -0.452663 -0.459832  0.462478
# SO   0.233652  1.000000  0.030968 -0.129745 -0.161612 -0.180368 -0.093418
# SB  -0.098347  0.030968  1.000000  0.132290  0.143068  0.126063 -0.020783
# RA  -0.416445 -0.129745  0.132290  1.000000  0.991018  0.986674 -0.016659
# ER  -0.452663 -0.161612  0.143068  0.991018  1.000000  0.997248 -0.020221
# ERA -0.459832 -0.180368  0.126063  0.986674  0.997248  1.000000 -0.009856
# CG   0.462478 -0.093418 -0.020783 -0.016659 -0.020221 -0.009856  1.000000
# SHO  0.426004  0.237721 -0.106563 -0.636862 -0.630192 -0.630833  0.241676
# SV   0.099445  0.126297 -0.183418 -0.616224 -0.589663 -0.607005 -0.367766
# E   -0.075685  0.155133  0.079149  0.198996  0.136921  0.113137 -0.140047
#
#           SHO        SV         E
# W    0.471805  0.666530 -0.089485
# R   -0.103274 -0.096380 -0.023262
# AB  -0.197321 -0.106367  0.316743
# H   -0.145559 -0.130371 -0.033173
# 2B   0.057998  0.171576  0.105754
# 3B  -0.041396 -0.142370  0.126678
# HR  -0.019119 -0.028540 -0.207597
# BB   0.426004  0.099445 -0.075685
# SO   0.237721  0.126297  0.155133
# SB  -0.106563 -0.183418  0.079149
# RA  -0.636862 -0.616224  0.198996
# ER  -0.630192 -0.589663  0.136921
# ERA -0.630833 -0.607005  0.113137
# CG   0.241676 -0.367766 -0.140047
# SHO  1.000000  0.221639 -0.115716
# SV   0.221639  1.000000 -0.025636
# E   -0.115716 -0.025636  1.000000

# %%
plt.figure(figsize=(22,7))
sns.heatmap(df.corr(),annot=True,linewidths=0.1,linecolor="black",fmt="0.2f")
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(22,7))
df.corr()['W'].sort_values(ascending=False).drop(['W']).plot(kind='bar' ,color='c')
plt.xlabel('Feature' ,fontsize=14)
plt.ylabel('column with target names',fontsize=14)
plt.title('correlation',fontsize=18)
plt.show()

# %%
df.skew()
# Out:
# W      0.047089
# R      1.200786
# AB     0.183437
# H      0.670254
# 2B    -0.230650
# 3B     0.129502
# HR     0.516441
# BB     0.158498
# SO    -0.156065
# SB     0.479893
# RA     0.045734
# ER     0.058710
# ERA    0.053331
# CG     0.736845
# SHO    0.565790
# SV     0.657524
# E      0.890132
# dtype: float64

# %% [markdown]
# # Outliers checking

# %%
df.dtypes
# Out:
# W        int64
# R        int64
# AB       int64
# H        int64
# 2B       int64
# 3B       int64
# HR       int64
# BB       int64
# SO       int64
# SB       int64
# RA       int64
# ER       int64
# ERA    float64
# CG       int64
# SHO      int64
# SV       int64
# E        int64
# dtype: object

# %%
df['W'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['R'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['AB'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['H'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['2B'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['3B'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['HR'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['BB'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['SO'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['SB'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['RA'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['ER'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['ERA'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['CG'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['SHO'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['SV'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['E'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Let's Check the Data Distribution among all the columns

# %%
df.plot(kind='density', subplots=True, layout=(6,11), sharex=False, legend=False, fontsize=1, figsize=(18,12))
plt.show()

# %% [markdown]
# # Considering the outliers removal

# %%
df.shape
# Out:
# (30, 17)

# %%
from scipy.stats import zscore
import numpy as np
z=np.abs(zscore(df))
threshold=3
np.where(z>3)
# Out:
# (array([5], dtype=int64), array([1], dtype=int64))

# %%
df_new_z=df[(z<3).all(axis=1)]
df_new_z
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# 11   86  729  5459  1363  278  26  230  486  1392  121  618  572  3.57   5
# 12   85  661  5417  1331  243  21  176  435  1150   52  675  630  3.94   2
# 13   76  656  5544  1379  262  22  198  478  1336   69  726  677  4.16   6
# 14   68  694  5600  1405  277  46  146  475  1119   78  729  664  4.14   5
# 15  100  647  5484  1386  288  39  137  506  1267   69  525  478  2.94   1
# 16   98  697  5631  1462  292  27  140  461  1322   98  596  532  3.21   0
# 17   97  689  5491  1341  272  30  171  567  1518   95  608  546  3.36   6
# 18   68  655  5480  1378  274  34  145  412  1299   84  737  682  4.28   1
# 19   64  640  5571  1382  257  27  167  496  1255  134  754  700  4.33   2
# 20   90  683  5527  1351  295  17  177  488  1290   51  613  557  3.43   1
# 21   83  703  5428  1363  265  13  177  539  1344   57  635  577  3.62   4
# 22   71  613  5463  1420  236  40  120  375  1150  112  678  638  4.02   0
# 23   67  573  5420  1361  251  18  100  471  1107   69  760  698  4.41   3
# 24   63  626  5529  1374  272  37  130  387  1274   88  809  749  4.69   1
# 25   92  667  5385  1346  263  26  187  563  1258   59  595  553  3.44   6
# 26   84  696  5565  1486  288  39  136  457  1159   93  627  597  3.72   7
# 27   79  720  5649  1494  289  48  154  490  1312  132  713  659  4.04   1
# 28   74  650  5457  1324  260  36  148  426  1327   82  731  655  4.09   1
# 29   68  737  5572  1479  274  49  186  388  1283   97  844  799  5.04   4
#
#     SHO  SV    E
# 0     8  56   88
# 1    12  45   86
# 2    10  38   79
# 3     9  37  101
# 4    12  35   86
# 6     4  48   93
# 7    10  43   77
# 8    12  60   95
# 9    10  40   97
# 10    9  45  119
# 11   13  39   85
# 12   12  46   93
# 13   12  45   94
# 14   15  28  126
# 15   15  62   96
# 16   13  54  122
# 17   21  48  111
# 18    7  40  116
# 19    8  35   90
# 20   14  50   88
# 21   13  41   90
# 22   12  35   77
# 23   10  44   90
# 24    7  35  117
# 25   21  47   75
# 26   18  41   78
# 27   12  44   86
# 28    6  41   92
# 29    4  36   95

# %%
df_new_z.shape
# Out:
# (29, 17)

# %%
Data_loss=((30-29)/30)*100

# %%
Data_loss
# Out:
# 3.3333333333333335

# %% [markdown]
# # Data distriubution in each column

# %%
plt.figure(figsize=(20,25), facecolor='white')
plotnumber = 1

for column in df:
    if plotnumber<=18:
        ax = plt.subplot(6,3,plotnumber)
        sns.distplot(df[column],color='b')
        plt.xlabel(column,fontsize=20)
    plotnumber+=1
plt.show()

# %% [markdown]
# # Separating the columns into features and target

# %%
features=df.drop("W",axis=1)
target=df["W"]

# %% [markdown]
# # Scaling the data using Min-max scalar

# %%
from sklearn.preprocessing import MinMaxScaler
mms=MinMaxScaler()
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
for i in range(0,100):
    features_train,features_test,target_train,target_test=train_test_split(features,target,test_size=0.2,random_state=i)
    lr.fit(features_train,target_train)
    pred_train=lr.predict(features_train)
    pred_test=lr.predict(features_test)
    print(f"At random state {i},the training accuracy is :- {r2_score(target_train,pred_train)}")
    print(f"At random state {i},the testing accuracy is :- {r2_score(target_test,pred_test)}")
    print("\n")
# Out:
# At random state 0,the training accuracy is :- 0.9609590618835543
# At random state 0,the testing accuracy is :- 0.6629341689506705
#
#
# At random state 1,the training accuracy is :- 0.9715846357165405
# At random state 1,the testing accuracy is :- 0.3841724690075786
#
#
# At random state 2,the training accuracy is :- 0.9898192153844548
# At random state 2,the testing accuracy is :- -2.081998955010787
#
#
# At random state 3,the training accuracy is :- 0.9722553885185528
# At random state 3,the testing accuracy is :- 0.4618378970602377
#
#
# At random state 4,the training accuracy is :- 0.964746149799658
# At random state 4,the testing accuracy is :- 0.4660685292728437
#
#
# At random state 5,the training accuracy is :- 0.9503092887369992
# At random state 5,the testing accuracy is :- 0.7517105066858546
#
#
# At random state 6,the training accuracy is :- 0.948947004521447
# At random state 6,the testing accuracy is :- 0.8376419521868339
#
#
# At random state 7,the training accuracy is :- 0.9631978535911326
# At random state 7,the testing accuracy is :- -0.25547694158915535
#
#
# At random state 8,the training accuracy is :- 0.9623956064118225
# At random state 8,the testing accuracy is :- 0.5868676500008577
#
#
# At random state 9,the training accuracy is :- 0.9558190206474735
# At random state 9,the testing accuracy is :- 0.7290448155515925
#
#
# At random state 10,the training accuracy is :- 0.9658380488238816
# At random state 10,the testing accuracy is :- -0.2279712919950747
#
#
# At random state 11,the training accuracy is :- 0.9794801537272682
# At random state 11,the testing accuracy is :- 0.2481759765614716
#
#
# At random state 12,the training accuracy is :- 0.9737413001008608
# At random state 12,the testing accuracy is :- -1.1916550064202482
#
#
# At random state 13,the training accuracy is :- 0.9750450815078384
# At random state 13,the testing accuracy is :- 0.676707984334459
#
#
# At random state 14,the training accuracy is :- 0.9469984720280225
# At random state 14,the testing accuracy is :- 0.7947948235207332
#
#
# At random state 15,the training accuracy is :- 0.9709420941407676
# At random state 15,the testing accuracy is :- 0.08782646885313528
#
#
# At random state 16,the training accuracy is :- 0.9858809375178788
# At random state 16,the testing accuracy is :- 0.2156636142748778
#
#
# At random state 17,the training accuracy is :- 0.9749884441968527
# At random state 17,the testing accuracy is :- 0.2429837566512275
#
#
# At random state 18,the training accuracy is :- 0.9619051538791019
# At random state 18,the testing accuracy is :- 0.44692713019862174
#
#
# At random state 19,the training accuracy is :- 0.9495167250254274
# At random state 19,the testing accuracy is :- 0.838113419335654
#
#
# At random state 20,the training accuracy is :- 0.9648282100620996
# At random state 20,the testing accuracy is :- 0.30103553183443355
#
#
# At random state 21,the training accuracy is :- 0.9632922835126104
# At random state 21,the testing accuracy is :- 0.43748497306629985
#
#
# At random state 22,the training accuracy is :- 0.9538756336575558
# At random state 22,the testing accuracy is :- -0.022968263180221937
#
#
# At random state 23,the training accuracy is :- 0.9614513761755267
# At random state 23,the testing accuracy is :- 0.5703263346963161
#
#
# At random state 24,the training accuracy is :- 0.9930550857101428
# At random state 24,the testing accuracy is :- -3.9281386887175183
#
#
# At random state 25,the training accuracy is :- 0.9579610563737945
# At random state 25,the testing accuracy is :- 0.4181713062412423
#
#
# At random state 26,the training accuracy is :- 0.9658277445021987
# At random state 26,the testing accuracy is :- 0.324133608651172
#
#
# At random state 27,the training accuracy is :- 0.9552740421332101
# At random state 27,the testing accuracy is :- 0.6767959850140982
#
#
# At random state 28,the training accuracy is :- 0.9597644213445621
# At random state 28,the testing accuracy is :- 0.6699377101719095
#
#
# At random state 29,the training accuracy is :- 0.9511213168423279
# At random state 29,the testing accuracy is :- 0.8790507229532956
#
#
# At random state 30,the training accuracy is :- 0.9494811939208996
# At random state 30,the testing accuracy is :- 0.8365092739163154
#
#
# At random state 31,the training accuracy is :- 0.9951572148896561
# At random state 31,the testing accuracy is :- 0.2592083827638959
#
#
# At random state 32,the training accuracy is :- 0.9631618129568901
# At random state 32,the testing accuracy is :- 0.24486497945420882
#
#
# At random state 33,the training accuracy is :- 0.9828979279570369
# At random state 33,the testing accuracy is :- 0.7251644237527008
#
#
# At random state 34,the training accuracy is :- 0.9721607076503062
# At random state 34,the testing accuracy is :- 0.7974272428667585
#
#
# At random state 35,the training accuracy is :- 0.980068511522487
# At random state 35,the testing accuracy is :- 0.18097976995379672
#
#
# At random state 36,the training accuracy is :- 0.9577869158330774
# At random state 36,the testing accuracy is :- 0.7342034319837716
#
#
# At random state 37,the training accuracy is :- 0.9564708376178136
# At random state 37,the testing accuracy is :- 0.5924138149123603
#
#
# At random state 38,the training accuracy is :- 0.9684911861559723
# At random state 38,the testing accuracy is :- 0.23284767333799095
#
#
# At random state 39,the training accuracy is :- 0.9531716157253376
# At random state 39,the testing accuracy is :- 0.8073613092401453
#
#
# At random state 40,the training accuracy is :- 0.9693187478384305
# At random state 40,the testing accuracy is :- 0.45805077232058156
#
#
# At random state 41,the training accuracy is :- 0.9586218982294639
# At random state 41,the testing accuracy is :- 0.7343696065237005
#
#
# At random state 42,the training accuracy is :- 0.9740426384448528
# At random state 42,the testing accuracy is :- 0.7876400316149446
#
#
# At random state 43,the training accuracy is :- 0.9881881791911085
# At random state 43,the testing accuracy is :- -1.0543428896604752
#
#
# At random state 44,the training accuracy is :- 0.9567296904413439
# At random state 44,the testing accuracy is :- 0.5894992447123721
#
#
# At random state 45,the training accuracy is :- 0.954954901790532
# At random state 45,the testing accuracy is :- 0.6385651240924294
#
#
# At random state 46,the training accuracy is :- 0.9627441089213999
# At random state 46,the testing accuracy is :- 0.6261439472974861
#
#
# At random state 47,the training accuracy is :- 0.9572737663157227
# At random state 47,the testing accuracy is :- 0.8116559418363234
#
#
# At random state 48,the training accuracy is :- 0.9460990720082069
# At random state 48,the testing accuracy is :- 0.8234694071796368
#
#
# At random state 49,the training accuracy is :- 0.9871259881150013
# At random state 49,the testing accuracy is :- -0.07399772649633274
#
#
# At random state 50,the training accuracy is :- 0.9823137618455432
# At random state 50,the testing accuracy is :- 0.6111709711671869
#
#
# At random state 51,the training accuracy is :- 0.9786247301654906
# At random state 51,the testing accuracy is :- 0.4582745176586478
#
#
# At random state 52,the training accuracy is :- 0.9772088150616494
# At random state 52,the testing accuracy is :- 0.5097793692109345
#
#
# At random state 53,the training accuracy is :- 0.9854055261633469
# At random state 53,the testing accuracy is :- 0.2550058206707292
#
#
# At random state 54,the training accuracy is :- 0.9639045549917286
# At random state 54,the testing accuracy is :- 0.7551746347340793
#
#
# At random state 55,the training accuracy is :- 0.9548931781151017
# At random state 55,the testing accuracy is :- 0.7860903369149369
#
#
# At random state 56,the training accuracy is :- 0.959902264838421
# At random state 56,the testing accuracy is :- 0.6079899644112027
#
#
# At random state 57,the training accuracy is :- 0.9773161013476726
# At random state 57,the testing accuracy is :- -0.7979271743714578
#
#
# At random state 58,the training accuracy is :- 0.9554433249805975
# At random state 58,the testing accuracy is :- 0.41049923062100524
#
#
# At random state 59,the training accuracy is :- 0.9860359788865672
# At random state 59,the testing accuracy is :- 0.008019457575950795
#
#
# At random state 60,the training accuracy is :- 0.9870382905760342
# At random state 60,the testing accuracy is :- -0.41187977286930155
#
#
# At random state 61,the training accuracy is :- 0.9852781686735402
# At random state 61,the testing accuracy is :- -0.11594360026659212
#
#
# At random state 62,the training accuracy is :- 0.9561041370877833
# At random state 62,the testing accuracy is :- 0.6185871131833671
#
#
# At random state 63,the training accuracy is :- 0.9579361117394376
# At random state 63,the testing accuracy is :- 0.5576984549178928
#
#
# At random state 64,the training accuracy is :- 0.9560367093903079
# At random state 64,the testing accuracy is :- 0.6352725305740629
#
#
# At random state 65,the training accuracy is :- 0.9525149014820992
# At random state 65,the testing accuracy is :- 0.7247598156620236
#
#
# At random state 66,the training accuracy is :- 0.9899795721247048
# At random state 66,the testing accuracy is :- 0.1719134662476841
#
#
# At random state 67,the training accuracy is :- 0.9489471263761321
# At random state 67,the testing accuracy is :- 0.8087753828913911
#
#
# At random state 68,the training accuracy is :- 0.9433712692742346
# At random state 68,the testing accuracy is :- 0.8732463116865993
#
#
# At random state 69,the training accuracy is :- 0.9584500267196242
# At random state 69,the testing accuracy is :- 0.5242852201259449
#
#
# At random state 70,the training accuracy is :- 0.9669105523499834
# At random state 70,the testing accuracy is :- -0.19350775610923399
#
#
# At random state 71,the training accuracy is :- 0.96469155628748
# At random state 71,the testing accuracy is :- 0.3790991443797861
#
#
# At random state 72,the training accuracy is :- 0.958465646280237
# At random state 72,the testing accuracy is :- 0.7102012570894161
#
#
# At random state 73,the training accuracy is :- 0.9669581454532016
# At random state 73,the testing accuracy is :- 0.7261324544603858
#
#
# At random state 74,the training accuracy is :- 0.9824485230030252
# At random state 74,the testing accuracy is :- -2.006452499229162
# At random state 75,the training accuracy is :- 0.9619107292032059
# At random state 75,the testing accuracy is :- 0.31970899130267183
#
#
# At random state 76,the training accuracy is :- 0.9823020250956469
# At random state 76,the testing accuracy is :- -0.5350831359883372
#
#
# At random state 77,the training accuracy is :- 0.9852345925877508
# At random state 77,the testing accuracy is :- -0.3919915994033878
#
#
# At random state 78,the training accuracy is :- 0.9617795239455276
# At random state 78,the testing accuracy is :- 0.39264201587679226
#
#
# At random state 79,the training accuracy is :- 0.9746721228360483
# At random state 79,the testing accuracy is :- 0.25891280632901215
#
#
# At random state 80,the training accuracy is :- 0.9815940714701807
# At random state 80,the testing accuracy is :- -1.3881438676976905
#
#
# At random state 81,the training accuracy is :- 0.9671418744471724
# At random state 81,the testing accuracy is :- -3.832495192183848
#
#
# At random state 82,the training accuracy is :- 0.9792528357720713
# At random state 82,the testing accuracy is :- 0.7619024479455736
#
#
# At random state 83,the training accuracy is :- 0.9538482413124927
# At random state 83,the testing accuracy is :- 0.8479393575196346
#
#
# At random state 84,the training accuracy is :- 0.953949316151689
# At random state 84,the testing accuracy is :- 0.7098512965463728
#
#
# At random state 85,the training accuracy is :- 0.9526629781970174
# At random state 85,the testing accuracy is :- 0.8407963276845669
#
#
# At random state 86,the training accuracy is :- 0.9543878085444035
# At random state 86,the testing accuracy is :- 0.7404936612670406
#
#
# At random state 87,the training accuracy is :- 0.9631177788804777
# At random state 87,the testing accuracy is :- 0.3095696288138776
#
#
# At random state 88,the training accuracy is :- 0.9774273263600962
# At random state 88,the testing accuracy is :- -4.229901909248935
#
#
# At random state 89,the training accuracy is :- 0.9722162780072603
# At random state 89,the testing accuracy is :- -0.779814482533445
#
#
# At random state 90,the training accuracy is :- 0.9530090276344043
# At random state 90,the testing accuracy is :- 0.8300294405682725
#
#
# At random state 91,the training accuracy is :- 0.9535273897994727
# At random state 91,the testing accuracy is :- 0.6922110717277895
#
#
# At random state 92,the training accuracy is :- 0.9650375090233065
# At random state 92,the testing accuracy is :- 0.5943186016078721
#
#
# At random state 93,the training accuracy is :- 0.9667903742911996
# At random state 93,the testing accuracy is :- 0.42035802794473476
#
#
# At random state 94,the training accuracy is :- 0.9714128770121184
# At random state 94,the testing accuracy is :- -0.865226596250888
#
#
# At random state 95,the training accuracy is :- 0.9570916052259711
# At random state 95,the testing accuracy is :- 0.5065497917817132
#
#
# At random state 96,the training accuracy is :- 0.9664588096020406
# At random state 96,the testing accuracy is :- 0.13466114454257616
#
#
# At random state 97,the training accuracy is :- 0.949458968097837
# At random state 97,the testing accuracy is :- 0.8340143915795823
#
#
# At random state 98,the training accuracy is :- 0.9856174713033907
# At random state 98,the testing accuracy is :- 0.5691793123627711
#
#
# At random state 99,the training accuracy is :- 0.9531948414942486
# At random state 99,the testing accuracy is :- 0.8804448045510347

# %%
features_train,features_test,target_train,target_test=train_test_split(features,target,test_size=0.2,random_state=12)

# %%
lr.fit(features_train,target_train)
# Out:
# LinearRegression()

# %%
pred_test=lr.predict(features_test)

# %%
print(r2_score(target_test,pred_test))
# Out:
# -1.1916550064202482

# %% [markdown]
# # Crosss-validation of the model

# %%
Train_accuracy=r2_score(target_train,pred_train)
Test_accuracy=r2_score(target_test,pred_test)

from sklearn.model_selection import cross_val_score
for j in range(2,10):
    cv_score=cross_val_score(lr,features,target,cv=j)
    cv_mean=cv_score.mean()
    print(f"At cross fold {j} the cv score is {cv_mean} and accuracy score for training is {Train_accuracy} and accuracy for the testing is {Test_accuracy}")
    print("\n")
# Out:
# At cross fold 2 the cv score is -1.057932205834568 and accuracy score for training is -0.1583818009988358 and accuracy for the testing is -1.1916550064202482
#
#
# At cross fold 3 the cv score is 0.2258846016774 and accuracy score for training is -0.1583818009988358 and accuracy for the testing is -1.1916550064202482
#
#
# At cross fold 4 the cv score is 0.24952166654368527 and accuracy score for training is -0.1583818009988358 and accuracy for the testing is -1.1916550064202482
#
#
# At cross fold 5 the cv score is 0.04075540667465847 and accuracy score for training is -0.1583818009988358 and accuracy for the testing is -1.1916550064202482
#
#
# At cross fold 6 the cv score is 0.2515353093720216 and accuracy score for training is -0.1583818009988358 and accuracy for the testing is -1.1916550064202482
#
#
# At cross fold 7 the cv score is 0.3890804644289939 and accuracy score for training is -0.1583818009988358 and accuracy for the testing is -1.1916550064202482
#
#
# At cross fold 8 the cv score is 0.31937022109669355 and accuracy score for training is -0.1583818009988358 and accuracy for the testing is -1.1916550064202482
#
#
# At cross fold 9 the cv score is -4.8090841203953385 and accuracy score for training is -0.1583818009988358 and accuracy for the testing is -1.1916550064202482

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(8,6))
plt.scatter(x=target_test, y=pred_test, color='r')
plt.plot(target_test,target_test, color='b')
plt.xlabel('Actual charges',fontsize=14)
plt.ylabel('Predicted charges',fontsize=14)
plt.title('Linear Regression',fontsize=18)
plt.show()

# %% [markdown]
# # Regularization

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
import warnings
warnings.filterwarnings('ignore')

# %%
from sklearn.linear_model import Lasso

parameters = {'alpha' :[.0001, .001, .01, .1, 1, 10], 'random_state':list(range(0,10))}
ls = Lasso()
clf = GridSearchCV(ls,parameters)
clf.fit(features_train,target_train)

print(clf.best_params_)
# Out:
# {'alpha': 10, 'random_state': 0}

# %%
ls = Lasso(alpha=10,random_state=0)
ls.fit(features_train,target_train)
ls.score(features_train,target_train)
pred_ls = ls.predict(features_test)

lss = r2_score(target_test,pred_ls)
lss
# Out:
# -0.17818804308507152

# %%
cv_score=cross_val_score(ls,features,target,cv=5)
cv_mean=cv_score.mean()
cv_mean
# Out:
# 0.4379000482583654

# %% [markdown]
# # Ensemble technique

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor

parameters = {'criterion':['mse', 'mae'],'max_features':["auto", "sqrt", "log2"]}
rf =RandomForestRegressor()
clf = GridSearchCV(rf,parameters)
clf.fit(features_train,target_train)

print(clf.best_params_)
# Out:
# {'criterion': 'mse', 'max_features': 'log2'}

# %%
rf= RandomForestRegressor(criterion="mse",max_features="log2")
rf.fit(features_train, target_train)
rf.score(features_train, target_train)
pred_decision = rf.predict(features_test)

rfs = r2_score(target_test,pred_decision)
print('R2 Score:',rfs*100)

rfscore = cross_val_score(rf,features,target,cv=5)
rfc = rfscore.mean()
print('Cross Val Score:',rfc*100)
# Out:
# R2 Score: 5.451331719128339
# Cross Val Score: -28.860767328288052

# %% [markdown]
# # We are getting model accuracy 5.45% and cross validation -28.86%

# %% [markdown]
# # Modeling

# %%
from sklearn.model_selection import train_test_split as TTS
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

# %%
from sklearn.linear_model import LinearRegression, Lasso, Ridge
from sklearn.ensemble import RandomForestRegressor, AdaBoostRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor as KNN
from sklearn.svm import SVR
from sklearn.linear_model import SGDRegressor
from sklearn.metrics import classification_report
from sklearn.model_selection import cross_val_score
from sklearn import metrics

# %%
#Linear Regression
LR = LinearRegression()
LR.fit(x_train,y_train)
predLR = LR.predict(x_test)
# R2_Score
print("R2_score:",r2_score(y_test,predLR))

# Mean Absolute Error (MAE)
print("MAE:",metrics.mean_absolute_error(y_test,predLR))

#Mean Squared Error (MSE)
print("MSE:",metrics.mean_squared_error(y_test,predLR))
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_test,predLR)))
# Out:
# R2_score: -7.077942839538181
# MAE: 40.09526839171419
# MSE: 1896.4217411933091
# RMSE: 43.54792464852153

# %%
from sklearn.linear_model import Ridge
from sklearn.model_selection import GridSearchCV
paramsRidge = {'alpha':[0.01,0.1,1.0,10.26],'solver':['auto','svd','cholesky','lsqr','sparse_cg','sag','saga']}
ridge = Ridge()
clf = GridSearchCV(ridge,paramsRidge)
clf.fit(x_train,y_train)
print(clf.best_params_)
# Out:
# {'alpha': 10.26, 'solver': 'lsqr'}

# %%
#Ridge Regression
ridge = Ridge(alpha=10.26,solver='lsqr')
ridge.fit(x_train,y_train)
ridge.score(x_train,y_train)
pred_ridge = ridge.predict(x_test)
# R2_Score
print("R2_score:",r2_score(y_test,pred_ridge))

# Mean Absolute Error (MAE)
print("MAE:",metrics.mean_absolute_error(y_test,pred_ridge))

#Mean Squared Error (MSE)
print("MSE:",metrics.mean_squared_error(y_test,pred_ridge))

# Root Mean Squared Error
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_test,pred_ridge)))
# Out:
# R2_score: -0.6093375995160213
# MAE: 15.618039980369568
# MSE: 377.8168369431686
# RMSE: 19.437511078920792

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import Lasso
parameters = {'alpha':[0.0001,0.001,0.01,0.1,1,10],'random_state':list(range(0,100))}
lasso = Lasso()
clf = GridSearchCV(lasso,parameters)
clf.fit(x_train,y_train)
print(clf.best_params_)
# Out:
# {'alpha': 1, 'random_state': 0}

# %%
#Lasso Regression
lasso = Lasso(alpha=1,random_state=0)
lasso.fit(x_train,y_train)
lasso.score(x_train,y_train)
pred_lasso = lasso.predict(x_test)
# R2_Score
print("R2_score:",r2_score(y_test,pred_lasso))

# Mean Absolute Error (MAE)
print("MAE:",metrics.mean_absolute_error(y_test,pred_lasso))

#Mean Squared Error (MSE)
print("MSE:",metrics.mean_squared_error(y_test,pred_lasso))

# Root Mean Squared Error
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_test,pred_lasso)))
# Out:
# R2_score: -0.784723843073573
# MAE: 16.887500920996736
# MSE: 418.9914641961366
# RMSE: 20.469280988743513

# %%
#SGD regression
SGD = SGDRegressor()
SGD.fit(x_train,y_train)

predSGD=SGD.predict(x_test)
# R2_Score
print("R2_score:",r2_score(y_test,predSGD))

# Mean Absolute Error (MAE)
print("MAE:",metrics.mean_absolute_error(y_test,predSGD))

#Mean Squared Error (MSE)
print("MSE:",metrics.mean_squared_error(y_test,predSGD))

# Root Mean Squared Error
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_test,predSGD)))
# Out:
# R2_score: -2.045438508859479
# MAE: 20.610047014028503
# MSE: 714.9636874626153
# RMSE: 26.73880489966998

# %% [markdown]
# # After all the modeling regression the score is like for
# 1)Linear Regression
# R2_score: -7.077942839538181
# MAE: 40.09526839171419
# MSE: 1896.4217411933091
# RMSE: 43.54792464852153
#
# 2)Ridge Regression
# R2_score: -0.6093375995160213
# MAE: 15.618039980369568
# MSE: 377.8168369431686
# RMSE: 19.437511078920792
#
# 3)Lasso Regression
# R2_score: -0.784723843073573
# MAE: 16.887500920996736
# MSE: 418.9914641961366
# RMSE: 20.469280988743513
#
# 4)SGD regression
# R2_score: -2.045438508859479
# MAE: 20.610047014028503
# MSE: 714.9636874626153
# RMSE: 26.73880489966998

# %%
import pickle
filename = 'Baseball_Case_Study.pkl'
pickle.dump(rf, open(filename, 'wb'))
