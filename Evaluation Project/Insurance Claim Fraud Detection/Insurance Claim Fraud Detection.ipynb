# %%
#import required library
import pandas as pd 
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline 

import warnings
warnings.filterwarnings('ignore')

# %%
#importing csv file
df=pd.read_csv("https://raw.githubusercontent.com/dsrscientist/Data-Science-ML-Capstone-Projects/master/Automobile_insurance_fraud.csv")

# %%
df
# Out:
#      months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                   328   48         521585       17-10-2014           OH
# 1                   228   42         342868       27-06-2006           IN
# 2                   134   29         687698       06-09-2000           OH
# 3                   256   41         227811       25-05-1990           IL
# 4                   228   44         367455       06-06-2014           IL
# ..                  ...  ...            ...              ...          ...
# 995                   3   38         941851       16-07-1991           OH
# 996                 285   41         186934       05-01-2014           IL
# 997                 130   34         918516       17-02-2003           OH
# 998                 458   62         533940       18-11-2011           IL
# 999                 456   60         556080       11-11-1996           OH
#
#     policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# ...

# %%
df.columns
# Out:
# Index(['months_as_customer', 'age', 'policy_number', 'policy_bind_date',
#        'policy_state', 'policy_csl', 'policy_deductable',
#        'policy_annual_premium', 'umbrella_limit', 'insured_zip', 'insured_sex',
#        'insured_education_level', 'insured_occupation', 'insured_hobbies',
#        'insured_relationship', 'capital-gains', 'capital-loss',
#        'incident_date', 'incident_type', 'collision_type', 'incident_severity',
#        'authorities_contacted', 'incident_state', 'incident_city',
#        'incident_location', 'incident_hour_of_the_day',
#        'number_of_vehicles_involved', 'property_damage', 'bodily_injuries',
#        'witnesses', 'police_report_available', 'total_claim_amount',
#        'injury_claim', 'property_claim', 'vehicle_claim', 'auto_make',
#        'auto_model', 'auto_year', 'fraud_reported', '_c39'],
#       dtype='object')

# %%
#checking the null values in all the columns
df.isnull().sum()
# Out:
# months_as_customer                0
# age                               0
# policy_number                     0
# policy_bind_date                  0
# policy_state                      0
# policy_csl                        0
# policy_deductable                 0
# policy_annual_premium             0
# umbrella_limit                    0
# insured_zip                       0
# insured_sex                       0
# insured_education_level           0
# insured_occupation                0
# insured_hobbies                   0
# insured_relationship              0
# capital-gains                     0
# capital-loss                      0
# incident_date                     0
# incident_type                     0
# collision_type                    0
# incident_severity                 0
# authorities_contacted             0
# incident_state                    0
# incident_city                     0
# incident_location                 0
# incident_hour_of_the_day          0
# ...

# %%
df.shape
# Out:
# (1000, 40)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 40 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   months_as_customer           1000 non-null   int64
#  1   age                          1000 non-null   int64
#  2   policy_number                1000 non-null   int64
#  3   policy_bind_date             1000 non-null   object
#  4   policy_state                 1000 non-null   object
#  5   policy_csl                   1000 non-null   object
#  6   policy_deductable            1000 non-null   int64
#  7   policy_annual_premium        1000 non-null   float64
#  8   umbrella_limit               1000 non-null   int64
#  9   insured_zip                  1000 non-null   int64
#  10  insured_sex                  1000 non-null   object
#  11  insured_education_level      1000 non-null   object
#  12  insured_occupation           1000 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# months_as_customer                0
# age                               0
# policy_number                     0
# policy_bind_date                  0
# policy_state                      0
# policy_csl                        0
# policy_deductable                 0
# policy_annual_premium             0
# umbrella_limit                    0
# insured_zip                       0
# insured_sex                       0
# insured_education_level           0
# insured_occupation                0
# insured_hobbies                   0
# insured_relationship              0
# capital-gains                     0
# capital-loss                      0
# incident_date                     0
# incident_type                     0
# collision_type                    0
# incident_severity                 0
# authorities_contacted             0
# incident_state                    0
# incident_city                     0
# incident_location                 0
# incident_hour_of_the_day          0
# ...

# %%
#we delete _c39 beacuse it is not important for our result
delete=pd.DataFrame([["_c39"]],columns=["column name"])
delete
# Out:
#   column name
# 0        _c39

# %%
df=df.drop(["_c39"],axis=1)
df
# Out:
#      months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                   328   48         521585       17-10-2014           OH
# 1                   228   42         342868       27-06-2006           IN
# 2                   134   29         687698       06-09-2000           OH
# 3                   256   41         227811       25-05-1990           IL
# 4                   228   44         367455       06-06-2014           IL
# ..                  ...  ...            ...              ...          ...
# 995                   3   38         941851       16-07-1991           OH
# 996                 285   41         186934       05-01-2014           IL
# 997                 130   34         918516       17-02-2003           OH
# 998                 458   62         533940       18-11-2011           IL
# 999                 456   60         556080       11-11-1996           OH
#
#     policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# ...

# %%
# Check Duplicate values. 
df.duplicated().sum()
# Out:
# 0

# %%
#Check sapce in the columns 
df.isin([" "]).sum()
# Out:
# months_as_customer             0
# age                            0
# policy_number                  0
# policy_bind_date               0
# policy_state                   0
# policy_csl                     0
# policy_deductable              0
# policy_annual_premium          0
# umbrella_limit                 0
# insured_zip                    0
# insured_sex                    0
# insured_education_level        0
# insured_occupation             0
# insured_hobbies                0
# insured_relationship           0
# capital-gains                  0
# capital-loss                   0
# incident_date                  0
# incident_type                  0
# collision_type                 0
# incident_severity              0
# authorities_contacted          0
# incident_state                 0
# incident_city                  0
# incident_location              0
# incident_hour_of_the_day       0
# number_of_vehicles_involved    0
# property_damage                0
# ...

# %%
#Check ? in the columns
df.isin(["?"]).sum()
# Out:
# months_as_customer               0
# age                              0
# policy_number                    0
# policy_bind_date                 0
# policy_state                     0
# policy_csl                       0
# policy_deductable                0
# policy_annual_premium            0
# umbrella_limit                   0
# insured_zip                      0
# insured_sex                      0
# insured_education_level          0
# insured_occupation               0
# insured_hobbies                  0
# insured_relationship             0
# capital-gains                    0
# capital-loss                     0
# incident_date                    0
# incident_type                    0
# collision_type                 178
# incident_severity                0
# authorities_contacted            0
# incident_state                   0
# incident_city                    0
# incident_location                0
# incident_hour_of_the_day         0
# number_of_vehicles_involved      0
# ...

# %%
#Replace ? with Nan 
df.replace(to_replace="?", value=np.nan, inplace= True)

# %%
df.isnull().sum()
# Out:
# months_as_customer               0
# age                              0
# policy_number                    0
# policy_bind_date                 0
# policy_state                     0
# policy_csl                       0
# policy_deductable                0
# policy_annual_premium            0
# umbrella_limit                   0
# insured_zip                      0
# insured_sex                      0
# insured_education_level          0
# insured_occupation               0
# insured_hobbies                  0
# insured_relationship             0
# capital-gains                    0
# capital-loss                     0
# incident_date                    0
# incident_type                    0
# collision_type                 178
# incident_severity                0
# authorities_contacted            0
# incident_state                   0
# incident_city                    0
# incident_location                0
# incident_hour_of_the_day         0
# number_of_vehicles_involved      0
# ...

# %% [markdown]
# # We will fill the null values

# %%
df['collision_type'].fillna(df['collision_type'].mode()[0], inplace = True)

# %%
df['property_damage'].fillna(df['property_damage'].mode()[0], inplace = True)

# %%
df['police_report_available'].fillna(df['police_report_available'].mode()[0], inplace = True)

# %%
df.isnull().sum()
# Out:
# months_as_customer             0
# age                            0
# policy_number                  0
# policy_bind_date               0
# policy_state                   0
# policy_csl                     0
# policy_deductable              0
# policy_annual_premium          0
# umbrella_limit                 0
# insured_zip                    0
# insured_sex                    0
# insured_education_level        0
# insured_occupation             0
# insured_hobbies                0
# insured_relationship           0
# capital-gains                  0
# capital-loss                   0
# incident_date                  0
# incident_type                  0
# collision_type                 0
# incident_severity              0
# authorities_contacted          0
# incident_state                 0
# incident_city                  0
# incident_location              0
# incident_hour_of_the_day       0
# number_of_vehicles_involved    0
# property_damage                0
# ...

# %% [markdown]
# # EDA

# %%
import seaborn as sns
sns.scatterplot(x="months_as_customer",y="fraud_reported",data=df)
# Out:
# <AxesSubplot:xlabel='months_as_customer', ylabel='fraud_reported'>

# %%
sns.scatterplot(x="age",y="fraud_reported",data=df)
# Out:
# <AxesSubplot:xlabel='age', ylabel='fraud_reported'>

# %%
sns.scatterplot(x="policy_number",y="fraud_reported",data=df)
# Out:
# <AxesSubplot:xlabel='policy_number', ylabel='fraud_reported'>

# %%
sns.scatterplot(x="policy_bind_date",y="fraud_reported",data=df)
# Out:
# <AxesSubplot:xlabel='policy_bind_date', ylabel='fraud_reported'>

# %%
sns.scatterplot(x="policy_state",y="fraud_reported",data=df)
# Out:
# <AxesSubplot:xlabel='policy_state', ylabel='fraud_reported'>

# %%
sns.scatterplot(x="policy_csl",y="fraud_reported",data=df)
# Out:
# <AxesSubplot:xlabel='policy_csl', ylabel='fraud_reported'>

# %%
sns.scatterplot(x="policy_deductable",y="fraud_reported",data=df)
# Out:
# <AxesSubplot:xlabel='policy_deductable', ylabel='fraud_reported'>

# %%
sns.scatterplot(x="policy_annual_premium",y="fraud_reported",data=df)
# Out:
# <AxesSubplot:xlabel='policy_annual_premium', ylabel='fraud_reported'>

# %%
sns.scatterplot(x="umbrella_limit",y="fraud_reported",data=df)
# Out:
# <AxesSubplot:xlabel='umbrella_limit', ylabel='fraud_reported'>

# %%
sns.scatterplot(x="insured_zip",y="fraud_reported",data=df)
# Out:
# <AxesSubplot:xlabel='insured_zip', ylabel='fraud_reported'>

# %%
sns.scatterplot(x="insured_sex",y="fraud_reported",data=df)
# Out:
# <AxesSubplot:xlabel='insured_sex', ylabel='fraud_reported'>

# %%
sns.scatterplot(x="insured_education_level",y="fraud_reported",data=df)
# Out:
# <AxesSubplot:xlabel='insured_education_level', ylabel='fraud_reported'>

# %%
sns.scatterplot(x="insured_occupation",y="fraud_reported",data=df)
# Out:
# <AxesSubplot:xlabel='insured_occupation', ylabel='fraud_reported'>

# %%
sns.scatterplot(x="insured_hobbies",y="fraud_reported",data=df)
# Out:
# <AxesSubplot:xlabel='insured_hobbies', ylabel='fraud_reported'>

# %%
sns.scatterplot(x="insured_relationship",y="fraud_reported",data=df)
# Out:
# <AxesSubplot:xlabel='insured_relationship', ylabel='fraud_reported'>

# %%
sns.scatterplot(x="capital-gains",y="fraud_reported",data=df)
# Out:
# <AxesSubplot:xlabel='capital-gains', ylabel='fraud_reported'>

# %%
sns.scatterplot(x="capital-loss",y="fraud_reported",data=df)
# Out:
# <AxesSubplot:xlabel='capital-loss', ylabel='fraud_reported'>

# %%
sns.scatterplot(x="incident_date",y="fraud_reported",data=df)
# Out:
# <AxesSubplot:xlabel='incident_date', ylabel='fraud_reported'>

# %%
sns.scatterplot(x="incident_type",y="fraud_reported",data=df)
# Out:
# <AxesSubplot:xlabel='incident_type', ylabel='fraud_reported'>

# %%
sns.scatterplot(x="collision_type",y="fraud_reported",data=df)
# Out:
# <AxesSubplot:xlabel='collision_type', ylabel='fraud_reported'>

# %%
sns.scatterplot(x="incident_severity",y="fraud_reported",data=df)
# Out:
# <AxesSubplot:xlabel='incident_severity', ylabel='fraud_reported'>

# %%
sns.scatterplot(x="authorities_contacted",y="fraud_reported",data=df)
# Out:
# <AxesSubplot:xlabel='authorities_contacted', ylabel='fraud_reported'>

# %%
sns.scatterplot(x="incident_state",y="fraud_reported",data=df)
# Out:
# <AxesSubplot:xlabel='incident_state', ylabel='fraud_reported'>

# %%
sns.scatterplot(x="incident_city",y="fraud_reported",data=df)
# Out:
# <AxesSubplot:xlabel='incident_city', ylabel='fraud_reported'>

# %%
sns.scatterplot(x="incident_location",y="fraud_reported",data=df)
# Out:
# <AxesSubplot:xlabel='incident_location', ylabel='fraud_reported'>

# %%
sns.scatterplot(x="incident_hour_of_the_day",y="fraud_reported",data=df)
# Out:
# <AxesSubplot:xlabel='incident_hour_of_the_day', ylabel='fraud_reported'>

# %%
sns.scatterplot(x="number_of_vehicles_involved",y="fraud_reported",data=df)
# Out:
# <AxesSubplot:xlabel='number_of_vehicles_involved', ylabel='fraud_reported'>

# %%
sns.scatterplot(x="property_damage",y="fraud_reported",data=df)
# Out:
# <AxesSubplot:xlabel='property_damage', ylabel='fraud_reported'>

# %%
sns.scatterplot(x="bodily_injuries",y="fraud_reported",data=df)
# Out:
# <AxesSubplot:xlabel='bodily_injuries', ylabel='fraud_reported'>

# %%
sns.scatterplot(x="witnesses",y="fraud_reported",data=df)
# Out:
# <AxesSubplot:xlabel='witnesses', ylabel='fraud_reported'>

# %%
sns.scatterplot(x="police_report_available",y="fraud_reported",data=df)
# Out:
# <AxesSubplot:xlabel='police_report_available', ylabel='fraud_reported'>

# %%
sns.scatterplot(x="total_claim_amount",y="fraud_reported",data=df)
# Out:
# <AxesSubplot:xlabel='total_claim_amount', ylabel='fraud_reported'>

# %%
sns.scatterplot(x="injury_claim",y="fraud_reported",data=df)
# Out:
# <AxesSubplot:xlabel='injury_claim', ylabel='fraud_reported'>

# %%
sns.scatterplot(x="property_claim",y="fraud_reported",data=df)
# Out:
# <AxesSubplot:xlabel='property_claim', ylabel='fraud_reported'>

# %%
sns.scatterplot(x="vehicle_claim",y="fraud_reported",data=df)
# Out:
# <AxesSubplot:xlabel='vehicle_claim', ylabel='fraud_reported'>

# %%
sns.scatterplot(x="auto_make",y="fraud_reported",data=df)
# Out:
# <AxesSubplot:xlabel='auto_make', ylabel='fraud_reported'>

# %%
sns.scatterplot(x="auto_model",y="fraud_reported",data=df)
# Out:
# <AxesSubplot:xlabel='auto_model', ylabel='fraud_reported'>

# %%
sns.scatterplot(x="auto_year",y="fraud_reported",data=df)
# Out:
# <AxesSubplot:xlabel='auto_year', ylabel='fraud_reported'>

# %% [markdown]
# # Let's Check the Data Distribution among all the columns

# %%
df.plot(kind='density', subplots=True, layout=(6,11), sharex=False, legend=False, fontsize=1, figsize=(18,12))
plt.show()

# %% [markdown]
# # Encoding Target columns

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df['fraud_reported']=le.fit_transform(df['fraud_reported'])

# %%
df
# Out:
#      months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                   328   48         521585       17-10-2014           OH
# 1                   228   42         342868       27-06-2006           IN
# 2                   134   29         687698       06-09-2000           OH
# 3                   256   41         227811       25-05-1990           IL
# 4                   228   44         367455       06-06-2014           IL
# ..                  ...  ...            ...              ...          ...
# 995                   3   38         941851       16-07-1991           OH
# 996                 285   41         186934       05-01-2014           IL
# 997                 130   34         918516       17-02-2003           OH
# 998                 458   62         533940       18-11-2011           IL
# 999                 456   60         556080       11-11-1996           OH
#
#     policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# ...

# %% [markdown]
# # Correlation

# %%
#checking the correlation with target columns
df.corr()
# Out:
#                              months_as_customer       age  policy_number  \
# months_as_customer                     1.000000  0.922098       0.057555
# age                                    0.922098  1.000000       0.059413
# policy_number                          0.057555  0.059413       1.000000
# policy_deductable                      0.026807  0.029188      -0.006738
# policy_annual_premium                  0.005018  0.014404       0.022566
# umbrella_limit                         0.015498  0.018126       0.008968
# insured_zip                            0.017895  0.025604       0.007083
# capital-gains                          0.006399 -0.007075       0.009802
# capital-loss                           0.020209  0.007368      -0.005669
# incident_hour_of_the_day               0.070639  0.087161       0.000113
# number_of_vehicles_involved            0.014736  0.022102       0.013432
# bodily_injuries                       -0.010162 -0.015679      -0.004558
# ...

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(15,7))
sns.heatmap(df.corr(), annot=True, linewidth=0.5, linecolor="black", fmt=".2f")
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Outcome of Correlation
# All the columnsv of dataset is positivly correlated to the target columns
#
# max correlation with :- vehicle_claim
#
# min correlation with :- policy_number

# %% [markdown]
# # Describing Dataset

# %%
df.describe()
# Out:
#        months_as_customer          age  policy_number  policy_deductable  \
# count         1000.000000  1000.000000    1000.000000        1000.000000
# mean           203.954000    38.948000  546238.648000        1136.000000
# std            115.113174     9.140287  257063.005276         611.864673
# min              0.000000    19.000000  100804.000000         500.000000
# 25%            115.750000    32.000000  335980.250000         500.000000
# 50%            199.500000    38.000000  533135.000000        1000.000000
# 75%            276.250000    44.000000  759099.750000        2000.000000
# max            479.000000    64.000000  999435.000000        2000.000000
#
#        policy_annual_premium  umbrella_limit    insured_zip  capital-gains  \
# count            1000.000000    1.000000e+03    1000.000000    1000.000000
# mean             1256.406150    1.101000e+06  501214.488000   25126.100000
# std               244.167395    2.297407e+06   71701.610941   27872.187708
# ...

# %%
plt.figure(figsize=(15,12))
sns.heatmap(round(df.describe()[1:].transpose(),2),linewidth=2,annot=True,fmt="f")
plt.xticks(fontsize=18)
plt.yticks(fontsize=12)
plt.title("Variables Summary")
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 39 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   months_as_customer           1000 non-null   int64
#  1   age                          1000 non-null   int64
#  2   policy_number                1000 non-null   int64
#  3   policy_bind_date             1000 non-null   object
#  4   policy_state                 1000 non-null   object
#  5   policy_csl                   1000 non-null   object
#  6   policy_deductable            1000 non-null   int64
#  7   policy_annual_premium        1000 non-null   float64
#  8   umbrella_limit               1000 non-null   int64
#  9   insured_zip                  1000 non-null   int64
#  10  insured_sex                  1000 non-null   object
#  11  insured_education_level      1000 non-null   object
#  12  insured_occupation           1000 non-null   object
# ...

# %% [markdown]
# # Skewness

# %%
df.skew()
# Out:
# months_as_customer             0.362177
# age                            0.478988
# policy_number                  0.038991
# policy_deductable              0.477887
# policy_annual_premium          0.004402
# umbrella_limit                 1.806712
# insured_zip                    0.816554
# capital-gains                  0.478850
# capital-loss                  -0.391472
# incident_hour_of_the_day      -0.035584
# number_of_vehicles_involved    0.502664
# bodily_injuries                0.014777
# witnesses                      0.019636
# total_claim_amount            -0.594582
# injury_claim                   0.264811
# property_claim                 0.378169
# vehicle_claim                 -0.621098
# auto_year                     -0.048289
# fraud_reported                 1.175051
# dtype: float64

# %% [markdown]
# # Normal Distribution Curve:

# %%
sns.displot(df["months_as_customer"])

# %%
sns.displot(df["age"])

# %%
sns.displot(df["policy_number"])

# %%
sns.displot(df["policy_deductable"])

# %%
sns.displot(df["policy_annual_premium"])

# %%
sns.displot(df["umbrella_limit"])

# %%
sns.displot(df["insured_zip"])

# %%
sns.displot(df["capital-gains"])

# %%
sns.displot(df["capital-loss"])

# %%
sns.displot(df["incident_hour_of_the_day"])

# %%
sns.displot(df["number_of_vehicles_involved"])

# %%
sns.displot(df["bodily_injuries"])

# %%
sns.displot(df["witnesses"])

# %%
sns.displot(df["total_claim_amount"])

# %%
sns.displot(df["injury_claim"])

# %%
sns.displot(df["property_claim"])

# %%
sns.displot(df["vehicle_claim"])

# %%
sns.displot(df["auto_year"])

# %%
sns.displot(df["fraud_reported"])

# %% [markdown]
# # Outliers checking

# %%
df.dtypes
# Out:
# months_as_customer               int64
# age                              int64
# policy_number                    int64
# policy_bind_date                object
# policy_state                    object
# policy_csl                      object
# policy_deductable                int64
# policy_annual_premium          float64
# umbrella_limit                   int64
# insured_zip                      int64
# insured_sex                     object
# insured_education_level         object
# insured_occupation              object
# insured_hobbies                 object
# insured_relationship            object
# capital-gains                    int64
# capital-loss                     int64
# incident_date                   object
# incident_type                   object
# collision_type                  object
# incident_severity               object
# authorities_contacted           object
# incident_state                  object
# incident_city                   object
# ...

# %%
df['months_as_customer'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['age'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['policy_number'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['policy_deductable'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['policy_annual_premium'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['umbrella_limit'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['insured_zip'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['capital-gains'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['capital-loss'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['incident_hour_of_the_day'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['number_of_vehicles_involved'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['bodily_injuries'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['witnesses'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['total_claim_amount'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['injury_claim'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['property_claim'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['vehicle_claim'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['auto_year'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['fraud_reported'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Data Cleaning:

# %%
#delete columns which has not effecting the dataset and the final result
delete=pd.DataFrame([["months_as_customer"],["policy_number"],["policy_bind_date"],["incident_date"],["incident_location"],["auto_model"],["auto_year"],["auto_make"],["umbrella_limit"]],columns=["column name"])
delete
# Out:
#           column name
# 0  months_as_customer
# 1       policy_number
# 2    policy_bind_date
# 3       incident_date
# 4   incident_location
# 5          auto_model
# 6           auto_year
# 7           auto_make
# 8      umbrella_limit

# %%
df=df.drop(["months_as_customer","policy_number","policy_bind_date","incident_date","incident_location","auto_model","auto_year","auto_make","umbrella_limit"],axis=1)
df
# Out:
#      age policy_state policy_csl  policy_deductable  policy_annual_premium  \
# 0     48           OH    250/500               1000                1406.91
# 1     42           IN    250/500               2000                1197.22
# 2     29           OH    100/300               2000                1413.14
# 3     41           IL    250/500               2000                1415.74
# 4     44           IL   500/1000               1000                1583.91
# ..   ...          ...        ...                ...                    ...
# 995   38           OH   500/1000               1000                1310.80
# 996   41           IL    100/300               1000                1436.79
# 997   34           OH    250/500                500                1383.49
# 998   62           IL   500/1000               2000                1356.92
# 999   60           OH    250/500               1000                 766.19
#
# ...

# %%
df.dtypes
# Out:
# age                              int64
# policy_state                    object
# policy_csl                      object
# policy_deductable                int64
# policy_annual_premium          float64
# insured_zip                      int64
# insured_sex                     object
# insured_education_level         object
# insured_occupation              object
# insured_hobbies                 object
# insured_relationship            object
# capital-gains                    int64
# capital-loss                     int64
# incident_type                   object
# collision_type                  object
# incident_severity               object
# authorities_contacted           object
# incident_state                  object
# incident_city                   object
# incident_hour_of_the_day         int64
# number_of_vehicles_involved      int64
# property_damage                 object
# bodily_injuries                  int64
# witnesses                        int64
# ...

# %%
#delete columns which has not effecting the dataset and the final result
delete=pd.DataFrame([["police_report_available"],["property_damage"],["incident_city"],["incident_state"],["authorities_contacted"],["incident_severity"],["collision_type"],["incident_type"],["insured_relationship"],["insured_hobbies"],["insured_occupation"],["insured_education_level"],["insured_sex"],["policy_csl"],["policy_state"]],columns=["column name"])
delete
# Out:
#                 column name
# 0   police_report_available
# 1           property_damage
# 2             incident_city
# 3            incident_state
# 4     authorities_contacted
# 5         incident_severity
# 6            collision_type
# 7             incident_type
# 8      insured_relationship
# 9           insured_hobbies
# 10       insured_occupation
# 11  insured_education_level
# 12              insured_sex
# 13               policy_csl
# 14             policy_state

# %%
df=df.drop(["police_report_available","property_damage","incident_city","incident_state","authorities_contacted","incident_severity","collision_type","incident_type","insured_relationship","insured_hobbies","insured_occupation","insured_education_level","insured_sex","policy_csl","policy_state"],axis=1)
df
# Out:
#      age  policy_deductable  policy_annual_premium  insured_zip  \
# 0     48               1000                1406.91       466132
# 1     42               2000                1197.22       468176
# 2     29               2000                1413.14       430632
# 3     41               2000                1415.74       608117
# 4     44               1000                1583.91       610706
# ..   ...                ...                    ...          ...
# 995   38               1000                1310.80       431289
# 996   41               1000                1436.79       608177
# 997   34                500                1383.49       442797
# 998   62               2000                1356.92       441714
# 999   60               1000                 766.19       612260
#
#      capital-gains  capital-loss  incident_hour_of_the_day  \
# 0            53300             0                         5
# 1                0             0                         8
# ...

# %% [markdown]
# # Removing outliers:

# %%
from scipy.stats import zscore
import numpy as np
z=np.abs(zscore(df))
z.shape
# Out:
# (1000, 15)

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([229, 248, 500, 763, 807], dtype=int64), array([ 2,  2, 12,  2,  5], dtype=int64))

# %%
df_new=df[(z<3).all(axis=1)]
print(df.shape)
print(df_new.shape)
# Out:
# (1000, 15)
# (995, 15)

# %% [markdown]
# # Percentage data loss:

# %%
loss_percent=(1000-995)/1000*100
print(loss_percent)
# Out:
# 0.5

# %% [markdown]
# # Model without outliers is df and model with desired outliers is df_new1

# %%
x=df_new.iloc[:,:-1]
y=df_new.iloc[:,-1]

# %% [markdown]
# # Transforming data to remove skewness

# %%
from sklearn.preprocessing import power_transform
x=power_transform(x,method='yeo-johnson')

# %%
x
# Out:
# array([[ 1.00474512,  0.        ,  0.62507075, ...,  0.00828983,
#          1.08832037,  0.75486151],
#        [ 0.42665617,  0.        , -0.2441833 , ..., -1.5236401 ,
#         -1.55832569, -1.78664443],
#        [-1.14251992,  0.        ,  0.65075045, ...,  0.22626878,
#         -0.57741232, -0.81953465],
#        ...,
#        [-0.47490863,  0.        ,  0.52846302, ...,  0.19071997,
#          0.18863181,  0.77838246],
#        [ 2.13029167,  0.        ,  0.41872211, ..., -0.2487679 ,
#         -0.26404669, -0.10277997],
#        [ 1.98482075,  0.        , -2.06777452, ..., -1.69451823,
#         -1.49360744, -1.77907906]])

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(x)
x
# Out:
# array([[ 1.00474512,  0.        ,  0.62507075, ...,  0.00828983,
#          1.08832037,  0.75486151],
#        [ 0.42665617,  0.        , -0.2441833 , ..., -1.5236401 ,
#         -1.55832569, -1.78664443],
#        [-1.14251992,  0.        ,  0.65075045, ...,  0.22626878,
#         -0.57741232, -0.81953465],
#        ...,
#        [-0.47490863,  0.        ,  0.52846302, ...,  0.19071997,
#          0.18863181,  0.77838246],
#        [ 2.13029167,  0.        ,  0.41872211, ..., -0.2487679 ,
#         -0.26404669, -0.10277997],
#        [ 1.98482075,  0.        , -2.06777452, ..., -1.69451823,
#         -1.49360744, -1.77907906]])

# %% [markdown]
# # Since the outcome has only two variable we willuse binary classification model

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression()
from sklearn.metrics import accuracy_score

# %% [markdown]
# # Correlation with target columns

# %%
df.corr()
# Out:
#                                   age  policy_deductable  \
# age                          1.000000           0.029188
# policy_deductable            0.029188           1.000000
# policy_annual_premium        0.014404          -0.003245
# insured_zip                  0.025604           0.004545
# capital-gains               -0.007075           0.035212
# capital-loss                 0.007368          -0.023544
# incident_hour_of_the_day     0.087161           0.060935
# number_of_vehicles_involved  0.022102           0.051214
# bodily_injuries             -0.015679          -0.022765
# witnesses                    0.052359           0.066639
# total_claim_amount           0.069863           0.022839
# injury_claim                 0.075522           0.039107
# property_claim               0.060898           0.064792
# vehicle_claim                0.062588           0.005269
# fraud_reported               0.012143           0.014817
#
# ...

# %%
plt.figure(figsize=(22,7))
sns.heatmap(df.corr(),annot=True,linewidths=0.1,linecolor="black",fmt="0.2f")
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(22,7))
df.corr()['fraud_reported'].sort_values(ascending=False).drop(['fraud_reported']).plot(kind='bar' ,color='c')
plt.xlabel('Feature' ,fontsize=14)
plt.ylabel('column with target names',fontsize=14)
plt.title('correlation',fontsize=18)
plt.show()

# %%
df.skew()
# Out:
# age                            0.478988
# policy_deductable              0.477887
# policy_annual_premium          0.004402
# insured_zip                    0.816554
# capital-gains                  0.478850
# capital-loss                  -0.391472
# incident_hour_of_the_day      -0.035584
# number_of_vehicles_involved    0.502664
# bodily_injuries                0.014777
# witnesses                      0.019636
# total_claim_amount            -0.594582
# injury_claim                   0.264811
# property_claim                 0.378169
# vehicle_claim                 -0.621098
# fraud_reported                 1.175051
# dtype: float64

# %% [markdown]
# # Data distriubution in each column

# %%
plt.figure(figsize=(20,25), facecolor='white')
plotnumber = 1

for column in df:
    if plotnumber<=18:
        ax = plt.subplot(6,3,plotnumber)
        sns.distplot(df[column],color='b')
        plt.xlabel(column,fontsize=20)
    plotnumber+=1
plt.show()

# %% [markdown]
# # Splitting the dataframe:

# %%
for i in range(0,1000):
    x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=i,test_size=0.20)
    lr.fit(x_train,y_train)
    pred_train=lr.predict(x_train)
    pred_test=lr.predict(x_test)
    if round(accuracy_score(y_train,pred_train)*100,1)==round(accuracy_score(y_test,pred_test)*100,1):
        print("At random state",i,"The model performs very well")
        print("At random_state:-",i)
        print("Training r2_score is:-",accuracy_score(y_train,pred_train)*100)
        print("Testing r2_score is:-",accuracy_score(y_test,pred_test)*100)
# Out:
# At random state 21 The model performs very well
# At random_state:- 21
# Training r2_score is:- 75.37688442211056
# Testing r2_score is:- 75.37688442211056
# At random state 34 The model performs very well
# At random_state:- 34
# Training r2_score is:- 75.87939698492463
# Testing r2_score is:- 75.87939698492463
# At random state 38 The model performs very well
# At random_state:- 38
# Training r2_score is:- 75.37688442211056
# Testing r2_score is:- 75.37688442211056
# At random state 113 The model performs very well
# At random_state:- 113
# Training r2_score is:- 75.37688442211056
# Testing r2_score is:- 75.37688442211056
# At random state 124 The model performs very well
# At random_state:- 124
# Training r2_score is:- 75.37688442211056
# Testing r2_score is:- 75.37688442211056
# At random state 203 The model performs very well
# At random_state:- 203
# Training r2_score is:- 75.37688442211056
# Testing r2_score is:- 75.37688442211056
# ...

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.20,random_state=899)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,pred_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.75      1.00      0.86       150
#            1       0.00      0.00      0.00        49
#
#     accuracy                           0.75       199
#    macro avg       0.38      0.50      0.43       199
# weighted avg       0.57      0.75      0.65       199

# %% [markdown]
# # Cross validation score for logistic regression

# %%
# pred_lr = lr.predict(x_test)
from sklearn.model_selection import cross_val_score
lss = accuracy_score(y_test,pred_lr)
for j in range(2,10):
    lsscore = cross_val_score(lr,x,y,cv=j)
    lsc = lsscore.mean()
    print("At cv:-",j)
    print("Cross validation score is:-",lsc*100)
    print("accuracy_score is :-",lss*100)
    print("\n")
# Out:
# At cv:- 2
# Cross validation score is:- 75.577965786688
# accuracy_score is :- 75.37688442211056
#
#
# At cv:- 3
# Cross validation score is:- 74.77462720974532
# accuracy_score is :- 75.37688442211056
#
#
# At cv:- 4
# Cross validation score is:- 75.07570605000647
# accuracy_score is :- 75.37688442211056
#
#
# At cv:- 5
# Cross validation score is:- 74.9748743718593
# accuracy_score is :- 75.37688442211056
#
#
# At cv:- 6
# Cross validation score is:- 75.17585493489106
# accuracy_score is :- 75.37688442211056
#
#
# At cv:- 7
# Cross validation score is:- 75.27683584021612
# accuracy_score is :- 75.37688442211056
#
#
# At cv:- 8
# Cross validation score is:- 75.075
# accuracy_score is :- 75.37688442211056
#
#
# At cv:- 9
# Cross validation score is:- 75.17608517608517
# accuracy_score is :- 75.37688442211056

# %%
lsscore_selected = cross_val_score(lr,x,y,cv=4).mean()
print("The cv score is: ", lsscore_selected,"\nThe accuracy score is: ",lss)
# Out:
# The cv score is:  0.7507570605000647
# The accuracy score is:  0.7537688442211056

# %% [markdown]
# # The CV score is 0.7507 and the accuracy score is 0.7537 so this is our best model

# %% [markdown]
# # AUC ROC Curve:

# %%
from sklearn.metrics import roc_curve, auc
fpr, tpr, thresholds = roc_curve(pred_test, y_test)
roc_auc = auc(fpr, tpr)

plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=10, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=10, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.show()

# %%
import pickle
filename = 'Insurance_Claim_Fraud_Detection.pkl'
pickle.dump(df, open(filename, 'wb'))
