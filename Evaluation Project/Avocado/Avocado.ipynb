# %%
#importing libraries which is needed for this case study
import pandas as pd
import numpy as np

# %%
#importing csv file
df=pd.read_csv("avocado.csv")

# %%
df
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0               0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1               1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2               2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3               3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4               4  2015-11-29          1.28      51039.60   941.48   43838.39
# ...           ...         ...           ...           ...      ...        ...
# 18244           7  2018-02-04          1.63      17074.83  2046.96    1529.20
# 18245           8  2018-01-28          1.71      13888.04  1191.70    3431.50
# 18246           9  2018-01-21          1.87      13766.76  1191.92    2452.79
# 18247          10  2018-01-14          1.93      16205.22  1527.63    2981.04
# 18248          11  2018-01-07          1.62      17489.58  2894.77    2356.13
#
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'AveragePrice', 'Total Volume', '4046', '4225',
#        '4770', 'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'type',
#        'year', 'region'],
#       dtype='object')

# %%
#checking the null values in all the columns
df.isnull().sum()
# Out:
# Unnamed: 0      0
# Date            0
# AveragePrice    0
# Total Volume    0
# 4046            0
# 4225            0
# 4770            0
# Total Bags      0
# Small Bags      0
# Large Bags      0
# XLarge Bags     0
# type            0
# year            0
# region          0
# dtype: int64

# %% [markdown]
# # EDA
# Scatterplot

# %%
import seaborn as sns
sns.scatterplot(x="Unnamed: 0",y="AveragePrice",data=df)
# Out:
# <AxesSubplot:xlabel='Unnamed: 0', ylabel='AveragePrice'>

# %%
import seaborn as sns
sns.scatterplot(x="Date",y="AveragePrice",data=df)
# Out:
# <AxesSubplot:xlabel='Date', ylabel='AveragePrice'>

# %%
import seaborn as sns
sns.scatterplot(x="Total Volume",y="AveragePrice",data=df)
# Out:
# <AxesSubplot:xlabel='Total Volume', ylabel='AveragePrice'>

# %%
import seaborn as sns
sns.scatterplot(x="4046",y="AveragePrice",data=df)
# Out:
# <AxesSubplot:xlabel='4046', ylabel='AveragePrice'>

# %%
import seaborn as sns
sns.scatterplot(x="4770",y="AveragePrice",data=df)
# Out:
# <AxesSubplot:xlabel='4770', ylabel='AveragePrice'>

# %%
import seaborn as sns
sns.scatterplot(x="4225",y="AveragePrice",data=df)
# Out:
# <AxesSubplot:xlabel='4225', ylabel='AveragePrice'>

# %%
import seaborn as sns
sns.scatterplot(x="Total Bags",y="AveragePrice",data=df)
# Out:
# <AxesSubplot:xlabel='Total Bags', ylabel='AveragePrice'>

# %%
import seaborn as sns
sns.scatterplot(x="Small Bags",y="AveragePrice",data=df)
# Out:
# <AxesSubplot:xlabel='Small Bags', ylabel='AveragePrice'>

# %%
import seaborn as sns
sns.scatterplot(x="Large Bags",y="AveragePrice",data=df)
# Out:
# <AxesSubplot:xlabel='Large Bags', ylabel='AveragePrice'>

# %%
import seaborn as sns
sns.scatterplot(x="XLarge Bags",y="AveragePrice",data=df)
# Out:
# <AxesSubplot:xlabel='XLarge Bags', ylabel='AveragePrice'>

# %%
import seaborn as sns
sns.scatterplot(x="type",y="AveragePrice",data=df)
# Out:
# <AxesSubplot:xlabel='type', ylabel='AveragePrice'>

# %%
import seaborn as sns
sns.scatterplot(x="year",y="AveragePrice",data=df)
# Out:
# <AxesSubplot:xlabel='year', ylabel='AveragePrice'>

# %%
import seaborn as sns
sns.scatterplot(x="region",y="AveragePrice",data=df)
# Out:
# <AxesSubplot:xlabel='region', ylabel='AveragePrice'>

# %%
import seaborn as sns
sns.scatterplot(x="Unnamed: 0",y="region",data=df)
# Out:
# <AxesSubplot:xlabel='Unnamed: 0', ylabel='region'>

# %%
import seaborn as sns
sns.scatterplot(x="Date",y="region",data=df)
# Out:
# <AxesSubplot:xlabel='Date', ylabel='region'>

# %%
import seaborn as sns
sns.scatterplot(x="Total Volume",y="region",data=df)
# Out:
# <AxesSubplot:xlabel='Total Volume', ylabel='region'>

# %%
import seaborn as sns
sns.scatterplot(x="4046",y="region",data=df)
# Out:
# <AxesSubplot:xlabel='4046', ylabel='region'>

# %%
import seaborn as sns
sns.scatterplot(x="4770",y="region",data=df)
# Out:
# <AxesSubplot:xlabel='4770', ylabel='region'>

# %%
import seaborn as sns
sns.scatterplot(x="4225",y="region",data=df)
# Out:
# <AxesSubplot:xlabel='4225', ylabel='region'>

# %%
import seaborn as sns
sns.scatterplot(x="Total Bags",y="region",data=df)
# Out:
# <AxesSubplot:xlabel='Total Bags', ylabel='region'>

# %%
import seaborn as sns
sns.scatterplot(x="Small Bags",y="region",data=df)
# Out:
# <AxesSubplot:xlabel='Small Bags', ylabel='region'>

# %%
import seaborn as sns
sns.scatterplot(x="Large Bags",y="region",data=df)
# Out:
# <AxesSubplot:xlabel='Large Bags', ylabel='region'>

# %%
import seaborn as sns
sns.scatterplot(x="XLarge Bags",y="region",data=df)
# Out:
# <AxesSubplot:xlabel='XLarge Bags', ylabel='region'>

# %%
import seaborn as sns
sns.scatterplot(x="type",y="region",data=df)
# Out:
# <AxesSubplot:xlabel='type', ylabel='region'>

# %%
import seaborn as sns
sns.scatterplot(x="year",y="region",data=df)
# Out:
# <AxesSubplot:xlabel='year', ylabel='region'>

# %%
import seaborn as sns
sns.scatterplot(x="AveragePrice",y="region",data=df)
# Out:
# <AxesSubplot:xlabel='AveragePrice', ylabel='region'>

# %% [markdown]
# # Correlation

# %%
#checking the correlation with target columns
df.corr()
# Out:
#               Unnamed: 0  AveragePrice  Total Volume      4046      4225  \
# Unnamed: 0      1.000000     -0.133008      0.014035  0.017628  0.019829
# AveragePrice   -0.133008      1.000000     -0.192752 -0.208317 -0.172928
# Total Volume    0.014035     -0.192752      1.000000  0.977863  0.974181
# 4046            0.017628     -0.208317      0.977863  1.000000  0.926110
# 4225            0.019829     -0.172928      0.974181  0.926110  1.000000
# 4770            0.041752     -0.179446      0.872202  0.833389  0.887855
# Total Bags     -0.002219     -0.177088      0.963047  0.920057  0.905787
# Small Bags      0.000347     -0.174730      0.967238  0.925280  0.916031
# Large Bags     -0.009196     -0.172940      0.880640  0.838645  0.810015
# XLarge Bags    -0.011546     -0.117592      0.747157  0.699377  0.688809
# year           -0.171667      0.093197      0.017193  0.003353 -0.009559
#
#                   4770  Total Bags  Small Bags  Large Bags  XLarge Bags  \
# ...

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(15,7))
sns.heatmap(df.corr(), annot=True, linewidth=0.5, linecolor="black", fmt=".2f")
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Outcome of Correlation
# All the columnsv of dataset is positivly correlated to the target columns
#
# max correlation with :- year
#
# min correlation with :- 4046(Total number of avocados with PLU 4046 sold)

# %% [markdown]
# # Describing Dataset

# %%
df.describe()
# Out:
#          Unnamed: 0  AveragePrice  Total Volume          4046          4225  \
# count  18249.000000  18249.000000  1.824900e+04  1.824900e+04  1.824900e+04
# mean      24.232232      1.405978  8.506440e+05  2.930084e+05  2.951546e+05
# std       15.481045      0.402677  3.453545e+06  1.264989e+06  1.204120e+06
# min        0.000000      0.440000  8.456000e+01  0.000000e+00  0.000000e+00
# 25%       10.000000      1.100000  1.083858e+04  8.540700e+02  3.008780e+03
# 50%       24.000000      1.370000  1.073768e+05  8.645300e+03  2.906102e+04
# 75%       38.000000      1.660000  4.329623e+05  1.110202e+05  1.502069e+05
# max       52.000000      3.250000  6.250565e+07  2.274362e+07  2.047057e+07
#
#                4770    Total Bags    Small Bags    Large Bags    XLarge Bags  \
# count  1.824900e+04  1.824900e+04  1.824900e+04  1.824900e+04   18249.000000
# mean   2.283974e+04  2.396392e+05  1.821947e+05  5.433809e+04    3106.426507
# ...

# %%
plt.figure(figsize=(15,12))
sns.heatmap(round(df.describe()[1:].transpose(),2),linewidth=2,annot=True,fmt="f")
plt.xticks(fontsize=18)
plt.yticks(fontsize=12)
plt.title("Variables Summary")
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18249 entries, 0 to 18248
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    18249 non-null  int64
#  1   Date          18249 non-null  object
#  2   AveragePrice  18249 non-null  float64
#  3   Total Volume  18249 non-null  float64
#  4   4046          18249 non-null  float64
#  5   4225          18249 non-null  float64
#  6   4770          18249 non-null  float64
#  7   Total Bags    18249 non-null  float64
#  8   Small Bags    18249 non-null  float64
#  9   Large Bags    18249 non-null  float64
#  10  XLarge Bags   18249 non-null  float64
#  11  type          18249 non-null  object
#  12  year          18249 non-null  int64
#  13  region        18249 non-null  object
# dtypes: float64(9), int64(2), object(3)
# memory usage: 1.9+ MB

# %% [markdown]
# # Skewness

# %%
df.skew()
# Out:
# C:\Users\Nirav\AppData\Local\Temp/ipykernel_7848/1665899112.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.skew()
# Unnamed: 0       0.108334
# AveragePrice     0.580303
# Total Volume     9.007687
# 4046             8.648220
# 4225             8.942466
# 4770            10.159396
# Total Bags       9.756072
# Small Bags       9.540660
# Large Bags       9.796455
# XLarge Bags     13.139751
# year             0.215339
# dtype: float64

# %% [markdown]
# # Normal Distribution Curve:

# %%
sns.displot(df["Unnamed: 0"])

# %%
sns.displot(df["AveragePrice"])

# %%
sns.displot(df["Total Volume"])

# %%
sns.displot(df["4046"])

# %%
sns.displot(df["4225"])

# %%
sns.displot(df["4770"])

# %%
sns.displot(df["Total Bags"])

# %%
sns.displot(df["Small Bags"])

# %%
sns.displot(df["Large Bags"])

# %%
sns.displot(df["XLarge Bags"])

# %%
sns.displot(df["year"])

# %% [markdown]
# # Making the data frame for the nominal data

# %%
df_visualization_nominal=df[['Unnamed: 0','Date','AveragePrice','Total Volume','4046','4225','4770','Total Bags','Small Bags','Large Bags','XLarge Bags','type','year','region']].copy()

# %%
df_visualization_nominal.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'AveragePrice', 'Total Volume', '4046', '4225',
#        '4770', 'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'type',
#        'year', 'region'],
#       dtype='object')

# %% [markdown]
# # Visualization of the data:

# %%
import seaborn as sns

# %%
ax = sns.countplot(x="Unnamed: 0", data=df_visualization_nominal)
print(df_visualization_nominal["Unnamed: 0"].value_counts())
# Out:
# 0     432
# 7     432
# 1     432
# 11    432
# 9     432
# 8     432
# 10    432
# 6     432
# 5     432
# 4     432
# 3     432
# 2     432
# 41    324
# 34    324
# 35    324
# 36    324
# 37    324
# 38    324
# 39    324
# 40    324
# 47    324
# 42    324
# 43    324
# 44    324
# 45    324
# 46    324
# 32    324
# 48    324
# 49    324
# 50    324
# 33    324
# 26    324
# 31    324
# 30    324
# 12    324
# 13    324
# 14    324
# 15    324
# 16    324
# 17    324
# 18    324
# 19    324
# 20    324
# 21    324
# 22    324
# 23    324
# 24    324
# 25    324
# 27    324
# 28    324
# 29    324
# 51    322
# 52    107
# Name: Unnamed: 0, dtype: int64

# %%
ax = sns.countplot(x="Date", data=df_visualization_nominal)
print(df_visualization_nominal["Date"].value_counts())
# Out:
# 2015-12-27    108
# 2017-12-24    108
# 2017-12-10    108
# 2017-12-03    108
# 2017-11-26    108
#              ...
# 2016-11-06    108
# 2018-01-07    108
# 2017-06-18    107
# 2017-06-25    107
# 2015-12-06    107
# Name: Date, Length: 169, dtype: int64

# %%
ax = sns.countplot(x="AveragePrice", data=df_visualization_nominal)
print(df_visualization_nominal["AveragePrice"].value_counts())
# Out:
# 1.15    202
# 1.18    199
# 1.08    194
# 1.26    193
# 1.13    192
#        ...
# 3.25      1
# 3.12      1
# 2.68      1
# 3.03      1
# 3.17      1
# Name: AveragePrice, Length: 259, dtype: int64

# %%
ax = sns.countplot(x="Total Volume", data=df_visualization_nominal)
print(df_visualization_nominal["Total Volume"].value_counts())
# Out:
# 4103.97       2
# 3529.44       2
# 46602.16      2
# 13234.04      2
# 3713.49       2
#              ..
# 874349.55     1
# 1621253.97    1
# 830499.38     1
# 845065.66     1
# 17489.58      1
# Name: Total Volume, Length: 18237, dtype: int64

# %%
ax = sns.countplot(x="4046", data=df_visualization_nominal)
print(df_visualization_nominal["4046"].value_counts())
# Out:
# 0.00       242
# 3.00        10
# 4.00         8
# 1.24         8
# 1.00         8
#           ...
# 1486.31      1
# 1761.80      1
# 1772.26      1
# 1803.39      1
# 2894.77      1
# Name: 4046, Length: 17702, dtype: int64

# %%
ax = sns.countplot(x="4225", data=df_visualization_nominal)
print(df_visualization_nominal["4225"].value_counts())
# Out:
# 0.00         61
# 177.87        3
# 215.36        3
# 1.30          3
# 1.26          3
#              ..
# 417905.67     1
# 275986.91     1
# 277789.30     1
# 378155.00     1
# 2356.13       1
# Name: 4225, Length: 18103, dtype: int64

# %%
ax = sns.countplot(x="4770", data=df_visualization_nominal)
print(df_visualization_nominal["4770"].value_counts())
# Out:
# 0.00      5497
# 2.66         7
# 3.32         7
# 10.97        6
# 1.59         6
#           ...
# 547.08       1
# 155.87       1
# 72.01        1
# 128.06       1
# 224.53       1
# Name: 4770, Length: 12071, dtype: int64

# %%
ax = sns.countplot(x="Total Bags", data=df_visualization_nominal)
print(df_visualization_nominal["Total Bags"].value_counts())
# Out:
# 0.00         15
# 990.00        5
# 300.00        5
# 550.00        4
# 266.67        4
#              ..
# 90196.05      1
# 130858.02     1
# 510679.10     1
# 84522.00      1
# 12014.15      1
# Name: Total Bags, Length: 18097, dtype: int64

# %%
ax = sns.countplot(x="Small Bags", data=df_visualization_nominal)
print(df_visualization_nominal["Small Bags"].value_counts())
# Out:
# 0.00        159
# 203.33       11
# 223.33       10
# 533.33       10
# 123.33        8
#            ...
# 14002.00      1
# 32441.00      1
# 29560.96      1
# 22077.20      1
# 11988.14      1
# Name: Small Bags, Length: 17321, dtype: int64

# %%
ax = sns.countplot(x="Large Bags", data=df_visualization_nominal)
print(df_visualization_nominal["Large Bags"].value_counts())
# Out:
# 0.00          2370
# 3.33           187
# 6.67            78
# 10.00           47
# 4.44            38
#               ...
# 2528089.14       1
# 2287449.76       1
# 731388.25        1
# 673464.14        1
# 26.01            1
# Name: Large Bags, Length: 15082, dtype: int64

# %%
ax = sns.countplot(x="XLarge Bags", data=df_visualization_nominal)
print(df_visualization_nominal["XLarge Bags"].value_counts())
# Out:
# 0.00       12048
# 3.33          29
# 6.67          16
# 1.11          15
# 5.00          12
#            ...
# 3018.05        1
# 2739.44        1
# 9301.67        1
# 8640.00        1
# 24.18          1
# Name: XLarge Bags, Length: 5588, dtype: int64

# %%
ax = sns.countplot(x="type", data=df_visualization_nominal)
print(df_visualization_nominal["type"].value_counts())
# Out:
# conventional    9126
# organic         9123
# Name: type, dtype: int64

# %%
ax = sns.countplot(x="year", data=df_visualization_nominal)
print(df_visualization_nominal["year"].value_counts())
# Out:
# 2017    5722
# 2016    5616
# 2015    5615
# 2018    1296
# Name: year, dtype: int64

# %%
ax = sns.countplot(x="region", data=df_visualization_nominal)
print(df_visualization_nominal["region"].value_counts())
# Out:
# Albany                 338
# Sacramento             338
# Northeast              338
# NorthernNewEngland     338
# Orlando                338
# Philadelphia           338
# PhoenixTucson          338
# Pittsburgh             338
# Plains                 338
# Portland               338
# RaleighGreensboro      338
# RichmondNorfolk        338
# Roanoke                338
# SanDiego               338
# Atlanta                338
# SanFrancisco           338
# Seattle                338
# SouthCarolina          338
# SouthCentral           338
# Southeast              338
# Spokane                338
# StLouis                338
# Syracuse               338
# Tampa                  338
# TotalUS                338
# West                   338
# NewYork                338
# NewOrleansMobile       338
# Nashville              338
# Midsouth               338
# BaltimoreWashington    338
# Boise                  338
# Boston                 338
# BuffaloRochester       338
# ...

# %% [markdown]
# # Making Dataframe of the ordinal data

# %%
sns.catplot(x="Unnamed: 0",y="year", data=df)

# %% [markdown]
# # Checking the distribution of the continuous value of float type columns

# %%
df_visualazation_continuous=df[["AveragePrice","Total Volume","4046","4225","4770","Total Bags","Small Bags","Large Bags","XLarge Bags"]].copy()

# %%
import seaborn as sns
sns.distplot(df_visualazation_continuous['AveragePrice'], kde=True)
# Out:
# C:\Users\Nirav\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='AveragePrice', ylabel='Density'>

# %%
sns.distplot(df_visualazation_continuous['Total Volume'], kde=True)
# Out:
# C:\Users\Nirav\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Total Volume', ylabel='Density'>

# %%
sns.distplot(df_visualazation_continuous['4046'], kde=True)
# Out:
# C:\Users\Nirav\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='4046', ylabel='Density'>

# %%
sns.distplot(df_visualazation_continuous['4225'], kde=True)
# Out:
# C:\Users\Nirav\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='4225', ylabel='Density'>

# %%
sns.distplot(df_visualazation_continuous['4770'], kde=True)
# Out:
# C:\Users\Nirav\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='4770', ylabel='Density'>

# %%
sns.distplot(df_visualazation_continuous['Total Bags'], kde=True)
# Out:
# C:\Users\Nirav\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Total Bags', ylabel='Density'>

# %%
sns.distplot(df_visualazation_continuous['Small Bags'], kde=True)
# Out:
# C:\Users\Nirav\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Small Bags', ylabel='Density'>

# %%
sns.distplot(df_visualazation_continuous['Large Bags'], kde=True)
# Out:
# C:\Users\Nirav\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Large Bags', ylabel='Density'>

# %%
sns.distplot(df_visualazation_continuous['XLarge Bags'], kde=True)
# Out:
# C:\Users\Nirav\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='XLarge Bags', ylabel='Density'>

# %%
df
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0               0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1               1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2               2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3               3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4               4  2015-11-29          1.28      51039.60   941.48   43838.39
# ...           ...         ...           ...           ...      ...        ...
# 18244           7  2018-02-04          1.63      17074.83  2046.96    1529.20
# 18245           8  2018-01-28          1.71      13888.04  1191.70    3431.50
# 18246           9  2018-01-21          1.87      13766.76  1191.92    2452.79
# 18247          10  2018-01-14          1.93      16205.22  1527.63    2981.04
# 18248          11  2018-01-07          1.62      17489.58  2894.77    2356.13
#
# ...

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(22,7))
sns.heatmap(df.describe(),annot=True,linewidths=0.1,linecolor="black",fmt="0.2f")
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Correlation of the columns with the target columns

# %%
df.corr()
# Out:
#               Unnamed: 0  AveragePrice  Total Volume      4046      4225  \
# Unnamed: 0      1.000000     -0.133008      0.014035  0.017628  0.019829
# AveragePrice   -0.133008      1.000000     -0.192752 -0.208317 -0.172928
# Total Volume    0.014035     -0.192752      1.000000  0.977863  0.974181
# 4046            0.017628     -0.208317      0.977863  1.000000  0.926110
# 4225            0.019829     -0.172928      0.974181  0.926110  1.000000
# 4770            0.041752     -0.179446      0.872202  0.833389  0.887855
# Total Bags     -0.002219     -0.177088      0.963047  0.920057  0.905787
# Small Bags      0.000347     -0.174730      0.967238  0.925280  0.916031
# Large Bags     -0.009196     -0.172940      0.880640  0.838645  0.810015
# XLarge Bags    -0.011546     -0.117592      0.747157  0.699377  0.688809
# year           -0.171667      0.093197      0.017193  0.003353 -0.009559
#
#                   4770  Total Bags  Small Bags  Large Bags  XLarge Bags  \
# ...

# %%
plt.figure(figsize=(22,7))
sns.heatmap(df.corr(),annot=True,linewidths=0.1,linecolor="black",fmt="0.2f")
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Checking the columns which are positively and negetively correlated with taget columns

# %%
plt.figure(figsize=(22,7))
df.corr()["AveragePrice"].drop(['AveragePrice']).plot(kind="bar",color="c")
plt.xlabel("Feature",fontsize=14)
plt.ylabel('columns with target names' ,fontsize=14)
plt.title('correlation',fontsize=18)
plt.show()

# %%
df.skew()
# Out:
# C:\Users\Nirav\AppData\Local\Temp/ipykernel_7848/1665899112.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.skew()
# Unnamed: 0       0.108334
# AveragePrice     0.580303
# Total Volume     9.007687
# 4046             8.648220
# 4225             8.942466
# 4770            10.159396
# Total Bags       9.756072
# Small Bags       9.540660
# Large Bags       9.796455
# XLarge Bags     13.139751
# year             0.215339
# dtype: float64

# %% [markdown]
# # Outliers Checking

# %%
df.dtypes
# Out:
# Unnamed: 0        int64
# Date             object
# AveragePrice    float64
# Total Volume    float64
# 4046            float64
# 4225            float64
# 4770            float64
# Total Bags      float64
# Small Bags      float64
# Large Bags      float64
# XLarge Bags     float64
# type             object
# year              int64
# region           object
# dtype: object

# %% [markdown]
# # Data Cleaning:

# %%
delete=pd.DataFrame([["Date"],["region"]],columns=["column name"])
delete
# Out:
#   column name
# 0        Date
# 1      region

# %%
delete=pd.DataFrame([["type"]],columns=["column name"])
delete
# Out:
#   column name
# 0        type

# %%
df=df.drop(["Date","region"],axis=1)
df
# Out:
#        Unnamed: 0  AveragePrice  Total Volume     4046       4225    4770  \
# 0               0          1.33      64236.62  1036.74   54454.85   48.16
# 1               1          1.35      54876.98   674.28   44638.81   58.33
# 2               2          0.93     118220.22   794.70  109149.67  130.50
# 3               3          1.08      78992.15  1132.00   71976.41   72.58
# 4               4          1.28      51039.60   941.48   43838.39   75.78
# ...           ...           ...           ...      ...        ...     ...
# 18244           7          1.63      17074.83  2046.96    1529.20    0.00
# 18245           8          1.71      13888.04  1191.70    3431.50    0.00
# 18246           9          1.87      13766.76  1191.92    2452.79  727.94
# 18247          10          1.93      16205.22  1527.63    2981.04  727.01
# 18248          11          1.62      17489.58  2894.77    2356.13  224.53
#
#        Total Bags  Small Bags  Large Bags  XLarge Bags          type  year
# ...

# %%
df=df.drop(["type"],axis=1)
df
# Out:
#        Unnamed: 0  AveragePrice  Total Volume     4046       4225    4770  \
# 0               0          1.33      64236.62  1036.74   54454.85   48.16
# 1               1          1.35      54876.98   674.28   44638.81   58.33
# 2               2          0.93     118220.22   794.70  109149.67  130.50
# 3               3          1.08      78992.15  1132.00   71976.41   72.58
# 4               4          1.28      51039.60   941.48   43838.39   75.78
# ...           ...           ...           ...      ...        ...     ...
# 18244           7          1.63      17074.83  2046.96    1529.20    0.00
# 18245           8          1.71      13888.04  1191.70    3431.50    0.00
# 18246           9          1.87      13766.76  1191.92    2452.79  727.94
# 18247          10          1.93      16205.22  1527.63    2981.04  727.01
# 18248          11          1.62      17489.58  2894.77    2356.13  224.53
#
#        Total Bags  Small Bags  Large Bags  XLarge Bags  year
# ...

# %%
df['Unnamed: 0'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['AveragePrice'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['Total Volume'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['4046'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['4225'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['4770'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['Total Bags'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['Small Bags'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['Large Bags'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['XLarge Bags'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['year'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Removing outliers:

# %%
from scipy.stats import zscore
import numpy as np
z=np.abs(zscore(df))
z.shape
# Out:
# (18249, 11)

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([  346,   359,   780, ..., 17304, 17402, 17428], dtype=int64), array([3, 3, 9, ..., 1, 1, 1], dtype=int64))

# %%
df_new=df[(z<3).all(axis=1)]
print(df.shape)
print(df_new.shape)
# Out:
# (18249, 11)
# (17651, 11)

# %% [markdown]
# # Percentage data loss:

# %%
loss_percent=(18249-17651)/18249*100
print(loss_percent)
# Out:
# 3.276891884486821

# %% [markdown]
# # Model without outliers is df and model with desired outliers is df_new1

# %%
x=df_new.iloc[:,:-1]
y=df_new.iloc[:,-1]

# %% [markdown]
# # Transforming data to remove skewness

# %%
from sklearn.preprocessing import power_transform
x=power_transform(x,method='yeo-johnson')

# %%
x
# Out:
# array([[-1.96693909, -0.11782446, -0.07532391, ..., -0.34742097,
#         -0.78115255, -0.67791909],
#        [-1.79094114, -0.06432986, -0.14749743, ..., -0.31132237,
#         -0.77119787, -0.67791909],
#        [-1.64688084, -1.29886469,  0.20555557, ..., -0.374453  ,
#         -0.75852256, -0.67791909],
#        ...,
#        [-0.92726556,  1.18432357, -0.77527398, ..., -0.31375554,
#         -0.950743  , -0.67791909],
#        [-0.84393881,  1.31329624, -0.70179733, ..., -0.25040812,
#         -0.91606805, -0.67791909],
#        [-0.76343986,  0.61561867, -0.66738095, ..., -0.21175518,
#         -1.04811619, -0.67791909]])

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(x)
x
# Out:
# array([[-1.96693909, -0.11782446, -0.07532391, ..., -0.34742097,
#         -0.78115255, -0.67791909],
#        [-1.79094114, -0.06432986, -0.14749743, ..., -0.31132237,
#         -0.77119787, -0.67791909],
#        [-1.64688084, -1.29886469,  0.20555557, ..., -0.374453  ,
#         -0.75852256, -0.67791909],
#        ...,
#        [-0.92726556,  1.18432357, -0.77527398, ..., -0.31375554,
#         -0.950743  , -0.67791909],
#        [-0.84393881,  1.31329624, -0.70179733, ..., -0.25040812,
#         -0.91606805, -0.67791909],
#        [-0.76343986,  0.61561867, -0.66738095, ..., -0.21175518,
#         -1.04811619, -0.67791909]])

# %% [markdown]
# # Since the outcome has only two variable we willuse binary classification mode

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression()
from sklearn.metrics import accuracy_score

# %% [markdown]
# # Encoding of Dataframe

# %%
from sklearn.preprocessing import OrdinalEncoder
enc=OrdinalEncoder()

# %%
for i in df.columns:
    if df[i].dtypes=="object":
        df[i]=enc.fit_transform(df[i].values.reshape(-1,1))

# %%
df
# Out:
#        Unnamed: 0  AveragePrice  Total Volume     4046       4225    4770  \
# 0               0          1.33      64236.62  1036.74   54454.85   48.16
# 1               1          1.35      54876.98   674.28   44638.81   58.33
# 2               2          0.93     118220.22   794.70  109149.67  130.50
# 3               3          1.08      78992.15  1132.00   71976.41   72.58
# 4               4          1.28      51039.60   941.48   43838.39   75.78
# ...           ...           ...           ...      ...        ...     ...
# 18244           7          1.63      17074.83  2046.96    1529.20    0.00
# 18245           8          1.71      13888.04  1191.70    3431.50    0.00
# 18246           9          1.87      13766.76  1191.92    2452.79  727.94
# 18247          10          1.93      16205.22  1527.63    2981.04  727.01
# 18248          11          1.62      17489.58  2894.77    2356.13  224.53
#
#        Total Bags  Small Bags  Large Bags  XLarge Bags  year
# ...

# %% [markdown]
# # Let's Check the Data Distribution among all the columns

# %%
df.plot(kind='density', subplots=True, layout=(6,11), sharex=False, legend=False, fontsize=1, figsize=(18,12))
plt.show()

# %% [markdown]
# # Data distriubution in each column

# %%
plt.figure(figsize=(20,25), facecolor='white')
plotnumber = 1

for column in df:
    if plotnumber<=18:
        ax = plt.subplot(6,3,plotnumber)
        sns.distplot(df[column],color='b')
        plt.xlabel(column,fontsize=20)
    plotnumber+=1
plt.show()
# Out:
# C:\Users\Nirav\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Nirav\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %% [markdown]
# # Seprating the columns into features and target:

# %%
features=df.drop("AveragePrice",axis=1)
target=df["AveragePrice"]

# %% [markdown]
# # Scalling the data using min max scaler

# %%
from sklearn.preprocessing import MinMaxScaler
mms=MinMaxScaler()
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
for i in range(0,100):
    features_train,features_test,target_train,target_test=train_test_split(features,target,test_size=0.2,random_state=i)
    lr.fit(features_train,target_train)
    pred_train=lr.predict(features_train)
    pred_test=lr.predict(features_test)
    print(f"At random state {i},the training accuracy is: - {r2_score(target_train,pred_train)}")
    print(f"At random state {i},the testing accuracy is: - {r2_score(target_test,pred_test)}")
    print("\n")
# Out:
# At random state 0,the training accuracy is: - 0.0701202079089901
# At random state 0,the testing accuracy is: - 0.08006200312407863
#
#
# At random state 1,the training accuracy is: - 0.07197056321467821
# At random state 1,the testing accuracy is: - 0.0740868220977926
#
#
# At random state 2,the training accuracy is: - 0.07321381900891999
# At random state 2,the testing accuracy is: - 0.06904134320230526
#
#
# At random state 3,the training accuracy is: - 0.07357361972698395
# At random state 3,the testing accuracy is: - 0.0670145894296561
#
#
# At random state 4,the training accuracy is: - 0.0723057926773939
# At random state 4,the testing accuracy is: - 0.07199599466860496
#
#
# At random state 5,the training accuracy is: - 0.07329180134599278
# At random state 5,the testing accuracy is: - 0.06620495650115832
#
#
# At random state 6,the training accuracy is: - 0.07243352267497838
# At random state 6,the testing accuracy is: - 0.07224303106486873
#
#
# ...

# %%
features_train,features_test,target_train,target_test=train_test_split(features,target,test_size=0.2,random_state=12)

# %%
lr.fit(features_train,target_train)
# Out:
# LinearRegression()

# %%
pred_test=lr.predict(features_test)

# %%
print(r2_score(target_test,pred_test))
# Out:
# 0.06754681690210174

# %% [markdown]
# # Crosss-validation of the model

# %%
Train_accuracy=r2_score(target_train,pred_train)
Test_accuracy=r2_score(target_test,pred_test)

from sklearn.model_selection import cross_val_score
for j in range(2,10):
    cv_score=cross_val_score(lr,features,target,cv=j)
    cv_mean=cv_score.mean()
    print(f"At cross fold {j} the cv score is {cv_mean} and accuracy score for training is {Train_accuracy} and accuracy for the testing is {Test_accuracy}")
    print("\n")
# Out:
# At cross fold 2 the cv score is -6123.046176520206 and accuracy score for training is -0.07468952703570131 and accuracy for the testing is 0.06754681690210174
#
#
# At cross fold 3 the cv score is -6.538677996068787 and accuracy score for training is -0.07468952703570131 and accuracy for the testing is 0.06754681690210174
#
#
# At cross fold 4 the cv score is -7.997472231890136 and accuracy score for training is -0.07468952703570131 and accuracy for the testing is 0.06754681690210174
#
#
# At cross fold 5 the cv score is -5.962674825481108 and accuracy score for training is -0.07468952703570131 and accuracy for the testing is 0.06754681690210174
#
#
# At cross fold 6 the cv score is -2.4648646619505725 and accuracy score for training is -0.07468952703570131 and accuracy for the testing is 0.06754681690210174
#
#
# At cross fold 7 the cv score is -1.7317675064823488 and accuracy score for training is -0.07468952703570131 and accuracy for the testing is 0.06754681690210174
#
#
# ...

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(8,6))
plt.scatter(x=target_test, y=pred_test, color='r')
plt.plot(target_test,target_test, color='b')
plt.xlabel('Actual charges',fontsize=14)
plt.ylabel('Predicted charges',fontsize=14)
plt.title('Linear Regression',fontsize=18)
plt.show()

# %% [markdown]
# # Regularization

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
import warnings
warnings.filterwarnings('ignore')

# %%
from sklearn.linear_model import Lasso

parameters = {'alpha' :[.0001, .001, .01, .1, 1, 10], 'random_state':list(range(0,10))}
ls = Lasso()
clf = GridSearchCV(ls,parameters)
clf.fit(features_train,target_train)

print(clf.best_params_)
# Out:
# {'alpha': 0.0001, 'random_state': 0}

# %%
ls = Lasso(alpha=0.0001,random_state=0)
ls.fit(features_train,target_train)
ls.score(features_train,target_train)
pred_ls = ls.predict(features_test)

lss = r2_score(target_test,pred_ls)
lss
# Out:
# 0.06748939224802442

# %%
cv_score=cross_val_score(ls,features,target,cv=5)
cv_mean=cv_score.mean()
cv_mean
# Out:
# -1.741386730583865

# %% [markdown]
# # Ensemble technique

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor

parameters = {'criterion':['mse', 'mae'],'max_features':["auto", "sqrt", "log2"]}
rf =RandomForestRegressor()
clf = GridSearchCV(rf,parameters)
clf.fit(features_train,target_train)

print(clf.best_params_)
# Out:
# {'criterion': 'mae', 'max_features': 'auto'}

# %%
rf= RandomForestRegressor(criterion="mae",max_features="auto")
rf.fit(features_train, target_train)
rf.score(features_train, target_train)
pred_decision = rf.predict(features_test)

rfs = r2_score(target_test,pred_decision)
print('R2 Score:',rfs*100)

rfscore = cross_val_score(rf,features,target,cv=5)
rfc = rfscore.mean()
print('Cross Val Score:',rfc*100)
# Out:
# R2 Score: 87.22806640293437
# Cross Val Score: 9.715112801479746

# %% [markdown]
# # We are getting model accuracy 87.22% and cross validation 9.71%

# %%
import pickle
filename = 'Avocado.pkl'
pickle.dump(rf, open(filename, 'wb'))
