# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("https://raw.githubusercontent.com/dsrscientist/DSData/master/happiness_score_dataset.csv")

# %%
df
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# 1              7.561         0.04884                   1.30232  1.40223
# 2              7.527         0.03328                   1.32548  1.36058
# 3              7.522         0.03880                   1.45900  1.33095
# 4              7.427         0.03553                   1.32629  1.32261
# ..               ...             ...                       ...      ...
# 153            3.465         0.03464                   0.22208  0.77370
# 154            3.340         0.03656                   0.28665  0.35386
# 155            3.006         0.05015                   0.66320  0.47489
# 156            2.905         0.08658                   0.01530  0.41587
# 157            2.839         0.06727                   0.20868  0.13995
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                     0.94143  0.66557                        0.41978
# 1                     0.94784  0.62877                        0.14145
# 2                     0.87464  0.64938                        0.48357
# 3                     0.88521  0.66973                        0.36503
# 4                     0.90563  0.63297                        0.32957
# ..                        ...      ...                            ...
# 153                   0.42864  0.59201                        0.55191
# 154                   0.31910  0.48450                        0.08010
# 155                   0.72193  0.15684                        0.18906
# 156                   0.22396  0.11850                        0.10062
# 157                   0.28443  0.36453                        0.10731
#
#      Generosity  Dystopia Residual
# 0       0.29678            2.51738
# 1       0.43630            2.70201
# 2       0.34139            2.49204
# 3       0.34699            2.46531
# 4       0.45811            2.45176
# ..          ...                ...
# 153     0.22628            0.67042
# 154     0.18260            1.63328
# 155     0.47179            0.32858
# 156     0.19727            1.83302
# 157     0.16681            1.56726
#
# [158 rows x 12 columns]

# %%
df.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %% [markdown]
# # EDA

# %% [markdown]
# Scatterplot

# %%
import seaborn as sns
sns.scatterplot(x="Country",y="Dystopia Residual",data=df)
# Out:
# <AxesSubplot:xlabel='Country', ylabel='Dystopia Residual'>

# %%
sns.scatterplot(x="Region",y="Dystopia Residual",data=df)
# Out:
# <AxesSubplot:xlabel='Region', ylabel='Dystopia Residual'>

# %%
sns.scatterplot(x="Happiness Rank",y="Dystopia Residual",data=df)
# Out:
# <AxesSubplot:xlabel='Happiness Rank', ylabel='Dystopia Residual'>

# %%
sns.scatterplot(x="Happiness Score",y="Dystopia Residual",data=df)
# Out:
# <AxesSubplot:xlabel='Happiness Score', ylabel='Dystopia Residual'>

# %%
sns.scatterplot(x="Standard Error",y="Dystopia Residual",data=df)
# Out:
# <AxesSubplot:xlabel='Standard Error', ylabel='Dystopia Residual'>

# %%
sns.scatterplot(x="Economy (GDP per Capita)",y="Dystopia Residual",data=df)
# Out:
# <AxesSubplot:xlabel='Economy (GDP per Capita)', ylabel='Dystopia Residual'>

# %%
sns.scatterplot(x="Family",y="Dystopia Residual",data=df)
# Out:
# <AxesSubplot:xlabel='Family', ylabel='Dystopia Residual'>

# %%
sns.scatterplot(x="Health (Life Expectancy)",y="Dystopia Residual",data=df)
# Out:
# <AxesSubplot:xlabel='Health (Life Expectancy)', ylabel='Dystopia Residual'>

# %%
sns.scatterplot(x="Freedom",y="Dystopia Residual",data=df)
# Out:
# <AxesSubplot:xlabel='Freedom', ylabel='Dystopia Residual'>

# %%
sns.scatterplot(x="Trust (Government Corruption)",y="Dystopia Residual",data=df)
# Out:
# <AxesSubplot:xlabel='Trust (Government Corruption)', ylabel='Dystopia Residual'>

# %%
sns.scatterplot(x="Generosity",y="Dystopia Residual",data=df)
# Out:
# <AxesSubplot:xlabel='Generosity', ylabel='Dystopia Residual'>

# %% [markdown]
# # Correlation

# %%
df.corr()
# Out:
#                                Happiness Rank  Happiness Score  \
# Happiness Rank                       1.000000        -0.992105
# Happiness Score                     -0.992105         1.000000
# Standard Error                       0.158516        -0.177254
# Economy (GDP per Capita)            -0.785267         0.780966
# Family                              -0.733644         0.740605
# Health (Life Expectancy)            -0.735613         0.724200
# Freedom                             -0.556886         0.568211
# Trust (Government Corruption)       -0.372315         0.395199
# Generosity                          -0.160142         0.180319
# Dystopia Residual                   -0.521999         0.530474
#
#                                Standard Error  Economy (GDP per Capita)  \
# Happiness Rank                       0.158516                 -0.785267
# Happiness Score                     -0.177254                  0.780966
# Standard Error                       1.000000                 -0.217651
# Economy (GDP per Capita)            -0.217651                  1.000000
# Family                              -0.120728                  0.645299
# Health (Life Expectancy)            -0.310287                  0.816478
# Freedom                             -0.129773                  0.370300
# Trust (Government Corruption)       -0.178325                  0.307885
# Generosity                          -0.088439                 -0.010465
# Dystopia Residual                    0.083981                  0.040059
#
#                                  Family  Health (Life Expectancy)   Freedom  \
# Happiness Rank                -0.733644                 -0.735613 -0.556886
# Happiness Score                0.740605                  0.724200  0.568211
# Standard Error                -0.120728                 -0.310287 -0.129773
# Economy (GDP per Capita)       0.645299                  0.816478  0.370300
# Family                         1.000000                  0.531104  0.441518
# Health (Life Expectancy)       0.531104                  1.000000  0.360477
# Freedom                        0.441518                  0.360477  1.000000
# Trust (Government Corruption)  0.205605                  0.248335  0.493524
# Generosity                     0.087513                  0.108335  0.373916
# Dystopia Residual              0.148117                  0.018979  0.062783
#
#                                Trust (Government Corruption)  Generosity  \
# Happiness Rank                                     -0.372315   -0.160142
# Happiness Score                                     0.395199    0.180319
# Standard Error                                     -0.178325   -0.088439
# Economy (GDP per Capita)                            0.307885   -0.010465
# Family                                              0.205605    0.087513
# Health (Life Expectancy)                            0.248335    0.108335
# Freedom                                             0.493524    0.373916
# Trust (Government Corruption)                       1.000000    0.276123
# Generosity                                          0.276123    1.000000
# Dystopia Residual                                  -0.033105   -0.101301
#
#                                Dystopia Residual
# Happiness Rank                         -0.521999
# Happiness Score                         0.530474
# Standard Error                          0.083981
# Economy (GDP per Capita)                0.040059
# Family                                  0.148117
# Health (Life Expectancy)                0.018979
# Freedom                                 0.062783
# Trust (Government Corruption)          -0.033105
# Generosity                             -0.101301
# Dystopia Residual                       1.000000

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(15,7))
sns.heatmap(df.corr(), annot=True, linewidth=0.5, linecolor="black", fmt=".2f")
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Outcome of Correlation
#
# max correlation with :- Happiness Score
#
# min correlation with :- Happiness Rank

# %% [markdown]
# # Describing Dataset

# %%
df.describe()
# Out:
#        Happiness Rank  Happiness Score  Standard Error  \
# count      158.000000       158.000000      158.000000
# mean        79.493671         5.375734        0.047885
# std         45.754363         1.145010        0.017146
# min          1.000000         2.839000        0.018480
# 25%         40.250000         4.526000        0.037268
# 50%         79.500000         5.232500        0.043940
# 75%        118.750000         6.243750        0.052300
# max        158.000000         7.587000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                158.000000  158.000000                158.000000
# mean                   0.846137    0.991046                  0.630259
# std                    0.403121    0.272369                  0.247078
# min                    0.000000    0.000000                  0.000000
# 25%                    0.545808    0.856823                  0.439185
# 50%                    0.910245    1.029510                  0.696705
# 75%                    1.158448    1.214405                  0.811013
# max                    1.690420    1.402230                  1.025250
#
#           Freedom  Trust (Government Corruption)  Generosity  \
# count  158.000000                     158.000000  158.000000
# mean     0.428615                       0.143422    0.237296
# std      0.150693                       0.120034    0.126685
# min      0.000000                       0.000000    0.000000
# 25%      0.328330                       0.061675    0.150553
# 50%      0.435515                       0.107220    0.216130
# 75%      0.549092                       0.180255    0.309883
# max      0.669730                       0.551910    0.795880
#
#        Dystopia Residual
# count         158.000000
# mean            2.098977
# std             0.553550
# min             0.328580
# 25%             1.759410
# 50%             2.095415
# 75%             2.462415
# max             3.602140

# %%
plt.figure(figsize=(15,12))
sns.heatmap(round(df.describe()[1:].transpose(),2),linewidth=2,annot=True,fmt="f")
plt.xticks(fontsize=18)
plt.yticks(fontsize=12)
plt.title("Variables Summary")
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# dtypes: float64(9), int64(1), object(2)
# memory usage: 14.9+ KB

# %%
df.skew()
# Out:
# C:\Users\Nirav\AppData\Local\Temp/ipykernel_18224/1665899112.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.skew()
# Happiness Rank                   0.000418
# Happiness Score                  0.097769
# Standard Error                   1.983439
# Economy (GDP per Capita)        -0.317575
# Family                          -1.006893
# Health (Life Expectancy)        -0.705328
# Freedom                         -0.413462
# Trust (Government Corruption)    1.385463
# Generosity                       1.001961
# Dystopia Residual               -0.238911
# dtype: float64

# %% [markdown]
# # Normal Distribution Curve

# %%
sns.displot(df["Happiness Rank"])

# %%
sns.displot(df["Happiness Score"])

# %%
sns.displot(df["Standard Error"])

# %%
sns.displot(df["Economy (GDP per Capita)"])

# %%
sns.displot(df["Family"])

# %%
sns.displot(df["Health (Life Expectancy)"])

# %%
sns.displot(df["Freedom"])

# %%
sns.displot(df["Trust (Government Corruption)"])

# %%
sns.displot(df["Generosity"])

# %%
sns.displot(df["Dystopia Residual"])

# %% [markdown]
# # Encoding of Dataframe

# %%
from sklearn.preprocessing import OrdinalEncoder
enc=OrdinalEncoder()

# %%
for i in df.columns:
    if df[i].dtypes=="object":
        df[i]=enc.fit_transform(df[i].values.reshape(-1,1))

# %%
df
# Out:
#      Country  Region  Happiness Rank  Happiness Score  Standard Error  \
# 0      135.0     9.0               1            7.587         0.03411
# 1       58.0     9.0               2            7.561         0.04884
# 2       37.0     9.0               3            7.527         0.03328
# 3      105.0     9.0               4            7.522         0.03880
# 4       24.0     5.0               5            7.427         0.03553
# ..       ...     ...             ...              ...             ...
# 153    118.0     8.0             154            3.465         0.03464
# 154     13.0     8.0             155            3.340         0.03656
# 155    136.0     4.0             156            3.006         0.05015
# 156     21.0     8.0             157            2.905         0.08658
# 157    141.0     8.0             158            2.839         0.06727
#
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                     1.39651  1.34951                   0.94143  0.66557
# 1                     1.30232  1.40223                   0.94784  0.62877
# 2                     1.32548  1.36058                   0.87464  0.64938
# 3                     1.45900  1.33095                   0.88521  0.66973
# 4                     1.32629  1.32261                   0.90563  0.63297
# ..                        ...      ...                       ...      ...
# 153                   0.22208  0.77370                   0.42864  0.59201
# 154                   0.28665  0.35386                   0.31910  0.48450
# 155                   0.66320  0.47489                   0.72193  0.15684
# 156                   0.01530  0.41587                   0.22396  0.11850
# 157                   0.20868  0.13995                   0.28443  0.36453
#
#      Trust (Government Corruption)  Generosity  Dystopia Residual
# 0                          0.41978     0.29678            2.51738
# 1                          0.14145     0.43630            2.70201
# 2                          0.48357     0.34139            2.49204
# 3                          0.36503     0.34699            2.46531
# 4                          0.32957     0.45811            2.45176
# ..                             ...         ...                ...
# 153                        0.55191     0.22628            0.67042
# 154                        0.08010     0.18260            1.63328
# 155                        0.18906     0.47179            0.32858
# 156                        0.10062     0.19727            1.83302
# 157                        0.10731     0.16681            1.56726
#
# [158 rows x 12 columns]

# %% [markdown]
# # Describe the dataset

# %%
df.describe()
# Out:
#           Country      Region  Happiness Rank  Happiness Score  \
# count  158.000000  158.000000      158.000000       158.000000
# mean    78.500000    5.120253       79.493671         5.375734
# std     45.754781    2.993321       45.754363         1.145010
# min      0.000000    0.000000        1.000000         2.839000
# 25%     39.250000    3.000000       40.250000         4.526000
# 50%     78.500000    4.500000       79.500000         5.232500
# 75%    117.750000    8.000000      118.750000         6.243750
# max    157.000000    9.000000      158.000000         7.587000
#
#        Standard Error  Economy (GDP per Capita)      Family  \
# count      158.000000                158.000000  158.000000
# mean         0.047885                  0.846137    0.991046
# std          0.017146                  0.403121    0.272369
# min          0.018480                  0.000000    0.000000
# 25%          0.037268                  0.545808    0.856823
# 50%          0.043940                  0.910245    1.029510
# 75%          0.052300                  1.158448    1.214405
# max          0.136930                  1.690420    1.402230
#
#        Health (Life Expectancy)     Freedom  Trust (Government Corruption)  \
# count                158.000000  158.000000                     158.000000
# mean                   0.630259    0.428615                       0.143422
# std                    0.247078    0.150693                       0.120034
# min                    0.000000    0.000000                       0.000000
# 25%                    0.439185    0.328330                       0.061675
# 50%                    0.696705    0.435515                       0.107220
# 75%                    0.811013    0.549092                       0.180255
# max                    1.025250    0.669730                       0.551910
#
#        Generosity  Dystopia Residual
# count  158.000000         158.000000
# mean     0.237296           2.098977
# std      0.126685           0.553550
# min      0.000000           0.328580
# 25%      0.150553           1.759410
# 50%      0.216130           2.095415
# 75%      0.309883           2.462415
# max      0.795880           3.602140

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(22,7))
sns.heatmap(df.describe(),annot=True,linewidths=0.1,linecolor="black",fmt="0.2f")
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Correlation with target columns

# %%
df.corr()
# Out:
#                                 Country    Region  Happiness Rank  \
# Country                        1.000000  0.005092       -0.098538
# Region                         0.005092  1.000000        0.213773
# Happiness Rank                -0.098538  0.213773        1.000000
# Happiness Score                0.083380 -0.176791       -0.992105
# Standard Error                 0.033879 -0.022600        0.158516
# Economy (GDP per Capita)       0.037808 -0.260139       -0.785267
# Family                         0.159416 -0.168533       -0.733644
# Health (Life Expectancy)       0.037829 -0.357508       -0.735613
# Freedom                        0.085684  0.092567       -0.556886
# Trust (Government Corruption)  0.088155  0.165040       -0.372315
# Generosity                     0.118085  0.273557       -0.160142
# Dystopia Residual             -0.019778 -0.057276       -0.521999
#
#                                Happiness Score  Standard Error  \
# Country                               0.083380        0.033879
# Region                               -0.176791       -0.022600
# Happiness Rank                       -0.992105        0.158516
# Happiness Score                       1.000000       -0.177254
# Standard Error                       -0.177254        1.000000
# Economy (GDP per Capita)              0.780966       -0.217651
# Family                                0.740605       -0.120728
# Health (Life Expectancy)              0.724200       -0.310287
# Freedom                               0.568211       -0.129773
# Trust (Government Corruption)         0.395199       -0.178325
# Generosity                            0.180319       -0.088439
# Dystopia Residual                     0.530474        0.083981
#
#                                Economy (GDP per Capita)    Family  \
# Country                                        0.037808  0.159416
# Region                                        -0.260139 -0.168533
# Happiness Rank                                -0.785267 -0.733644
# Happiness Score                                0.780966  0.740605
# Standard Error                                -0.217651 -0.120728
# Economy (GDP per Capita)                       1.000000  0.645299
# Family                                         0.645299  1.000000
# Health (Life Expectancy)                       0.816478  0.531104
# Freedom                                        0.370300  0.441518
# Trust (Government Corruption)                  0.307885  0.205605
# Generosity                                    -0.010465  0.087513
# Dystopia Residual                              0.040059  0.148117
#
#                                Health (Life Expectancy)   Freedom  \
# Country                                        0.037829  0.085684
# Region                                        -0.357508  0.092567
# Happiness Rank                                -0.735613 -0.556886
# Happiness Score                                0.724200  0.568211
# Standard Error                                -0.310287 -0.129773
# Economy (GDP per Capita)                       0.816478  0.370300
# Family                                         0.531104  0.441518
# Health (Life Expectancy)                       1.000000  0.360477
# Freedom                                        0.360477  1.000000
# Trust (Government Corruption)                  0.248335  0.493524
# Generosity                                     0.108335  0.373916
# Dystopia Residual                              0.018979  0.062783
#
#                                Trust (Government Corruption)  Generosity  \
# Country                                             0.088155    0.118085
# Region                                              0.165040    0.273557
# Happiness Rank                                     -0.372315   -0.160142
# Happiness Score                                     0.395199    0.180319
# Standard Error                                     -0.178325   -0.088439
# Economy (GDP per Capita)                            0.307885   -0.010465
# Family                                              0.205605    0.087513
# Health (Life Expectancy)                            0.248335    0.108335
# Freedom                                             0.493524    0.373916
# Trust (Government Corruption)                       1.000000    0.276123
# Generosity                                          0.276123    1.000000
# Dystopia Residual                                  -0.033105   -0.101301
#
#                                Dystopia Residual
# Country                                -0.019778
# Region                                 -0.057276
# Happiness Rank                         -0.521999
# Happiness Score                         0.530474
# Standard Error                          0.083981
# Economy (GDP per Capita)                0.040059
# Family                                  0.148117
# Health (Life Expectancy)                0.018979
# Freedom                                 0.062783
# Trust (Government Corruption)          -0.033105
# Generosity                             -0.101301
# Dystopia Residual                       1.000000

# %%
plt.figure(figsize=(22,7))
sns.heatmap(df.corr(),annot=True,linewidths=0.1,linecolor="black",fmt="0.2f")
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(22,7))
df.corr()['Dystopia Residual'].sort_values(ascending=False).drop(['Dystopia Residual']).plot(kind='bar' ,color='c')
plt.xlabel('Feature' ,fontsize=14)
plt.ylabel('column with target names',fontsize=14)
plt.title('correlation',fontsize=18)
plt.show()

# %%
df.skew()
# Out:
# Country                          0.000000
# Region                          -0.116119
# Happiness Rank                   0.000418
# Happiness Score                  0.097769
# Standard Error                   1.983439
# Economy (GDP per Capita)        -0.317575
# Family                          -1.006893
# Health (Life Expectancy)        -0.705328
# Freedom                         -0.413462
# Trust (Government Corruption)    1.385463
# Generosity                       1.001961
# Dystopia Residual               -0.238911
# dtype: float64

# %% [markdown]
# # Outliers checking

# %%
df.dtypes
# Out:
# Country                          float64
# Region                           float64
# Happiness Rank                     int64
# Happiness Score                  float64
# Standard Error                   float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Dystopia Residual                float64
# dtype: object

# %%
df['Country'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['Region'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['Happiness Rank'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['Happiness Score'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['Standard Error'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['Economy (GDP per Capita)'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['Family'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['Health (Life Expectancy)'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['Freedom'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['Trust (Government Corruption)'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['Generosity'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['Dystopia Residual'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Considering the outliers removal

# %%
df.shape
# Out:
# (158, 12)

# %%
from scipy.stats import zscore
import numpy as np
z=np.abs(zscore(df))
threshold=3
np.where(z>3)
# Out:
# (array([ 27,  40,  64, 115, 128, 147, 153, 155, 157], dtype=int64),
#  array([ 9,  4,  4,  4, 10,  6,  9, 11,  6], dtype=int64))

# %%
df_new_z=df[(z<3).all(axis=1)]
df_new_z
# Out:
#      Country  Region  Happiness Rank  Happiness Score  Standard Error  \
# 0      135.0     9.0               1            7.587         0.03411
# 1       58.0     9.0               2            7.561         0.04884
# 2       37.0     9.0               3            7.527         0.03328
# 3      105.0     9.0               4            7.522         0.03880
# 4       24.0     5.0               5            7.427         0.03553
# ..       ...     ...             ...              ...             ...
# 150     66.0     8.0             151            3.655         0.05141
# 151     20.0     8.0             152            3.587         0.04324
# 152      0.0     7.0             153            3.575         0.03084
# 154     13.0     8.0             155            3.340         0.03656
# 156     21.0     8.0             157            2.905         0.08658
#
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                     1.39651  1.34951                   0.94143  0.66557
# 1                     1.30232  1.40223                   0.94784  0.62877
# 2                     1.32548  1.36058                   0.87464  0.64938
# 3                     1.45900  1.33095                   0.88521  0.66973
# 4                     1.32629  1.32261                   0.90563  0.63297
# ..                        ...      ...                       ...      ...
# 150                   0.46534  0.77115                   0.15185  0.46866
# 151                   0.25812  0.85188                   0.27125  0.39493
# 152                   0.31982  0.30285                   0.30335  0.23414
# 154                   0.28665  0.35386                   0.31910  0.48450
# 156                   0.01530  0.41587                   0.22396  0.11850
#
#      Trust (Government Corruption)  Generosity  Dystopia Residual
# 0                          0.41978     0.29678            2.51738
# 1                          0.14145     0.43630            2.70201
# 2                          0.48357     0.34139            2.49204
# 3                          0.36503     0.34699            2.46531
# 4                          0.32957     0.45811            2.45176
# ..                             ...         ...                ...
# 150                        0.17922     0.20165            1.41723
# 151                        0.12832     0.21747            1.46494
# 152                        0.09719     0.36510            1.95210
# 154                        0.08010     0.18260            1.63328
# 156                        0.10062     0.19727            1.83302
#
# [149 rows x 12 columns]

# %%
df_new_z.shape
# Out:
# (149, 12)

# %%
Data_loss=((158-149)/397)*100

# %%
Data_loss
# Out:
# 2.2670025188916876

# %% [markdown]
# # Separating the columns into features and target

# %%
features=df.drop("Dystopia Residual",axis=1)
target=df["Dystopia Residual"]

# %% [markdown]
# # Scaling the data using Min-max scalar

# %%
from sklearn.preprocessing import MinMaxScaler
mms=MinMaxScaler()
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
for i in range(0,100):
    features_train,features_test,target_train,target_test=train_test_split(features,target,test_size=0.2,random_state=i)
    lr.fit(features_train,target_train)
    pred_train=lr.predict(features_train)
    pred_test=lr.predict(features_test)
    print(f"At random state {i},the training accuracy is :- {r2_score(target_train,pred_train)}")
    print(f"At random state {i},the testing accuracy is :- {r2_score(target_test,pred_test)}")
    print("\n")
# Out:
# At random state 0,the training accuracy is :- 0.9999997862611527
# At random state 0,the testing accuracy is :- 0.9999996353305423
#
#
# At random state 1,the training accuracy is :- 0.9999997783485636
# At random state 1,the testing accuracy is :- 0.9999996039487905
#
#
# At random state 2,the training accuracy is :- 0.9999997439417716
# At random state 2,the testing accuracy is :- 0.9999997968523032
#
#
# At random state 3,the training accuracy is :- 0.9999997632553235
# At random state 3,the testing accuracy is :- 0.9999997045099205
#
#
# At random state 4,the training accuracy is :- 0.9999997472631316
# At random state 4,the testing accuracy is :- 0.999999758708397
#
#
# At random state 5,the training accuracy is :- 0.9999997762925007
# At random state 5,the testing accuracy is :- 0.9999996430016412
#
#
# At random state 6,the training accuracy is :- 0.9999997807417065
# At random state 6,the testing accuracy is :- 0.999999640569145
#
#
# At random state 7,the training accuracy is :- 0.9999997543462594
# At random state 7,the testing accuracy is :- 0.9999997774180681
#
#
# At random state 8,the training accuracy is :- 0.9999997590249573
# At random state 8,the testing accuracy is :- 0.9999997590259971
#
#
# At random state 9,the training accuracy is :- 0.9999997804293078
# At random state 9,the testing accuracy is :- 0.9999996226301694
#
#
# At random state 10,the training accuracy is :- 0.9999997864393456
# At random state 10,the testing accuracy is :- 0.9999995775961379
#
#
# At random state 11,the training accuracy is :- 0.9999997449405524
# At random state 11,the testing accuracy is :- 0.9999998129029921
#
#
# At random state 12,the training accuracy is :- 0.9999997470837769
# At random state 12,the testing accuracy is :- 0.9999997853490281
#
#
# At random state 13,the training accuracy is :- 0.9999997437214737
# At random state 13,the testing accuracy is :- 0.9999997865772123
#
#
# At random state 14,the training accuracy is :- 0.9999997715954304
# At random state 14,the testing accuracy is :- 0.9999996893098257
#
#
# At random state 15,the training accuracy is :- 0.9999997870463887
# At random state 15,the testing accuracy is :- 0.9999995632445701
#
#
# At random state 16,the training accuracy is :- 0.9999997723255989
# At random state 16,the testing accuracy is :- 0.9999997080139965
#
#
# At random state 17,the training accuracy is :- 0.9999997852724495
# At random state 17,the testing accuracy is :- 0.999999569860977
#
#
# At random state 18,the training accuracy is :- 0.9999997968625233
# At random state 18,the testing accuracy is :- 0.9999994926534812
#
#
# At random state 19,the training accuracy is :- 0.999999797111138
# At random state 19,the testing accuracy is :- 0.9999995949713086
#
#
# At random state 20,the training accuracy is :- 0.9999997473653806
# At random state 20,the testing accuracy is :- 0.9999997863255309
#
#
# At random state 21,the training accuracy is :- 0.9999997523556039
# At random state 21,the testing accuracy is :- 0.999999767995071
#
#
# At random state 22,the training accuracy is :- 0.999999722445101
# At random state 22,the testing accuracy is :- 0.999999840921272
#
#
# At random state 23,the training accuracy is :- 0.9999997838936729
# At random state 23,the testing accuracy is :- 0.9999995664083543
#
#
# At random state 24,the training accuracy is :- 0.9999997783117092
# At random state 24,the testing accuracy is :- 0.9999996358786364
#
#
# At random state 25,the training accuracy is :- 0.9999997934163346
# At random state 25,the testing accuracy is :- 0.9999995312148069
#
#
# At random state 26,the training accuracy is :- 0.9999997767138548
# At random state 26,the testing accuracy is :- 0.9999996730569786
#
#
# At random state 27,the training accuracy is :- 0.9999997693541215
# At random state 27,the testing accuracy is :- 0.9999996915570255
#
#
# At random state 28,the training accuracy is :- 0.9999997608684622
# At random state 28,the testing accuracy is :- 0.9999997542858748
#
#
# At random state 29,the training accuracy is :- 0.9999997810361007
# At random state 29,the testing accuracy is :- 0.999999666315237
#
#
# At random state 30,the training accuracy is :- 0.9999997810977905
# At random state 30,the testing accuracy is :- 0.9999996551029985
#
#
# At random state 31,the training accuracy is :- 0.9999997527621425
# At random state 31,the testing accuracy is :- 0.9999997603505246
#
#
# At random state 32,the training accuracy is :- 0.9999997318250919
# At random state 32,the testing accuracy is :- 0.9999998142539627
#
#
# At random state 33,the training accuracy is :- 0.9999997060628605
# At random state 33,the testing accuracy is :- 0.9999998506652613
#
#
# At random state 34,the training accuracy is :- 0.9999997807379429
# At random state 34,the testing accuracy is :- 0.9999996322852125
#
#
# At random state 35,the training accuracy is :- 0.9999997787460901
# At random state 35,the testing accuracy is :- 0.9999996670819028
#
#
# At random state 36,the training accuracy is :- 0.9999997569011793
# At random state 36,the testing accuracy is :- 0.999999755864418
#
#
# At random state 37,the training accuracy is :- 0.9999997681271167
# At random state 37,the testing accuracy is :- 0.9999997146015198
#
#
# At random state 38,the training accuracy is :- 0.9999997697230414
# At random state 38,the testing accuracy is :- 0.9999997048266934
#
#
# At random state 39,the training accuracy is :- 0.9999997504780441
# At random state 39,the testing accuracy is :- 0.9999997857864856
#
#
# At random state 40,the training accuracy is :- 0.9999997965570158
# At random state 40,the testing accuracy is :- 0.99999953097588
#
#
# At random state 41,the training accuracy is :- 0.9999997223362841
# At random state 41,the testing accuracy is :- 0.9999998309961903
#
#
# At random state 42,the training accuracy is :- 0.999999761991711
# At random state 42,the testing accuracy is :- 0.9999997325276134
#
#
# At random state 43,the training accuracy is :- 0.9999997618486235
# At random state 43,the testing accuracy is :- 0.9999997083594135
#
#
# At random state 44,the training accuracy is :- 0.9999997781949639
# At random state 44,the testing accuracy is :- 0.999999626232263
#
#
# At random state 45,the training accuracy is :- 0.9999997575120672
# At random state 45,the testing accuracy is :- 0.9999997493068469
#
#
# At random state 46,the training accuracy is :- 0.9999997276240555
# At random state 46,the testing accuracy is :- 0.9999998316513996
#
#
# At random state 47,the training accuracy is :- 0.9999997764949801
# At random state 47,the testing accuracy is :- 0.9999996485142958
#
#
# At random state 48,the training accuracy is :- 0.9999997132913674
# At random state 48,the testing accuracy is :- 0.9999998333168755
#
#
# At random state 49,the training accuracy is :- 0.9999997873138626
# At random state 49,the testing accuracy is :- 0.9999995516390078
#
#
# At random state 50,the training accuracy is :- 0.9999997729523308
# At random state 50,the testing accuracy is :- 0.9999996587602523
#
#
# At random state 51,the training accuracy is :- 0.9999997786618618
# At random state 51,the testing accuracy is :- 0.9999996500956485
#
#
# At random state 52,the training accuracy is :- 0.9999997855447557
# At random state 52,the testing accuracy is :- 0.9999994870246075
#
#
# At random state 53,the training accuracy is :- 0.9999997217951528
# At random state 53,the testing accuracy is :- 0.9999998381649889
#
#
# At random state 54,the training accuracy is :- 0.9999997499733527
# At random state 54,the testing accuracy is :- 0.9999997776399564
#
#
# At random state 55,the training accuracy is :- 0.9999997731600968
# At random state 55,the testing accuracy is :- 0.9999996606971125
#
#
# At random state 56,the training accuracy is :- 0.9999997802307556
# At random state 56,the testing accuracy is :- 0.9999996257333165
#
#
# At random state 57,the training accuracy is :- 0.9999997693846578
# At random state 57,the testing accuracy is :- 0.9999996947793939
#
#
# At random state 58,the training accuracy is :- 0.9999997638133423
# At random state 58,the testing accuracy is :- 0.9999996838095773
#
#
# At random state 59,the training accuracy is :- 0.9999997451357288
# At random state 59,the testing accuracy is :- 0.9999997431177916
#
#
# At random state 60,the training accuracy is :- 0.9999997386078655
# At random state 60,the testing accuracy is :- 0.9999998198434544
#
#
# At random state 61,the training accuracy is :- 0.9999997810395235
# At random state 61,the testing accuracy is :- 0.9999996238458686
#
#
# At random state 62,the training accuracy is :- 0.999999793529707
# At random state 62,the testing accuracy is :- 0.9999995869578606
#
#
# At random state 63,the training accuracy is :- 0.9999997565348516
# At random state 63,the testing accuracy is :- 0.9999997283673523
#
#
# At random state 64,the training accuracy is :- 0.9999997607734026
# At random state 64,the testing accuracy is :- 0.9999997266953543
#
#
# At random state 65,the training accuracy is :- 0.9999997686515545
# At random state 65,the testing accuracy is :- 0.9999997129862971
#
#
# At random state 66,the training accuracy is :- 0.9999997835172669
# At random state 66,the testing accuracy is :- 0.9999996001008721
#
#
# At random state 67,the training accuracy is :- 0.9999997621963312
# At random state 67,the testing accuracy is :- 0.9999996869508354
#
#
# At random state 68,the training accuracy is :- 0.9999997826814582
# At random state 68,the testing accuracy is :- 0.9999996063756561
#
#
# At random state 69,the training accuracy is :- 0.9999997588946641
# At random state 69,the testing accuracy is :- 0.9999997519110552
#
#
# At random state 70,the training accuracy is :- 0.9999997749167667
# At random state 70,the testing accuracy is :- 0.9999997040416221
#
#
# At random state 71,the training accuracy is :- 0.9999997602744195
# At random state 71,the testing accuracy is :- 0.9999997552698683
#
#
# At random state 72,the training accuracy is :- 0.9999997680215448
# At random state 72,the testing accuracy is :- 0.99999969069341
#
#
# At random state 73,the training accuracy is :- 0.9999997766692703
# At random state 73,the testing accuracy is :- 0.999999675503398
#
#
# At random state 74,the training accuracy is :- 0.9999997571881271
# At random state 74,the testing accuracy is :- 0.9999997632280814
#
#
# At random state 75,the training accuracy is :- 0.9999997521537632
# At random state 75,the testing accuracy is :- 0.9999997867336146
#
#
# At random state 76,the training accuracy is :- 0.9999997623034216
# At random state 76,the testing accuracy is :- 0.9999997508266144
#
#
# At random state 77,the training accuracy is :- 0.9999997542050222
# At random state 77,the testing accuracy is :- 0.9999997661034773
#
#
# At random state 78,the training accuracy is :- 0.9999997261555469
# At random state 78,the testing accuracy is :- 0.9999998207240216
#
#
# At random state 79,the training accuracy is :- 0.9999997303773187
# At random state 79,the testing accuracy is :- 0.9999998359600892
#
#
# At random state 80,the training accuracy is :- 0.9999997862239937
# At random state 80,the testing accuracy is :- 0.9999995314053398
#
#
# At random state 81,the training accuracy is :- 0.9999997541021225
# At random state 81,the testing accuracy is :- 0.999999738979218
# At random state 82,the training accuracy is :- 0.9999997697363181
# At random state 82,the testing accuracy is :- 0.9999997038382612
#
#
# At random state 83,the training accuracy is :- 0.9999997408413498
# At random state 83,the testing accuracy is :- 0.9999997970690191
#
#
# At random state 84,the training accuracy is :- 0.9999997679044266
# At random state 84,the testing accuracy is :- 0.9999997125939089
#
#
# At random state 85,the training accuracy is :- 0.9999997554447091
# At random state 85,the testing accuracy is :- 0.9999997253578623
#
#
# At random state 86,the training accuracy is :- 0.9999997683527265
# At random state 86,the testing accuracy is :- 0.9999997040149693
#
#
# At random state 87,the training accuracy is :- 0.9999997516317093
# At random state 87,the testing accuracy is :- 0.999999781395477
#
#
# At random state 88,the training accuracy is :- 0.9999997634717193
# At random state 88,the testing accuracy is :- 0.999999687827784
#
#
# At random state 89,the training accuracy is :- 0.9999997359311129
# At random state 89,the testing accuracy is :- 0.9999997924228562
#
#
# At random state 90,the training accuracy is :- 0.9999997354442685
# At random state 90,the testing accuracy is :- 0.9999998249741289
#
#
# At random state 91,the training accuracy is :- 0.9999997606091291
# At random state 91,the testing accuracy is :- 0.9999997520078062
#
#
# At random state 92,the training accuracy is :- 0.999999761432988
# At random state 92,the testing accuracy is :- 0.9999997362495553
#
#
# At random state 93,the training accuracy is :- 0.9999997727421359
# At random state 93,the testing accuracy is :- 0.9999996741502061
#
#
# At random state 94,the training accuracy is :- 0.9999997689109604
# At random state 94,the testing accuracy is :- 0.9999996240146686
#
#
# At random state 95,the training accuracy is :- 0.9999997629459005
# At random state 95,the testing accuracy is :- 0.9999997399313388
#
#
# At random state 96,the training accuracy is :- 0.9999997540675276
# At random state 96,the testing accuracy is :- 0.9999997770091222
#
#
# At random state 97,the training accuracy is :- 0.9999997667979513
# At random state 97,the testing accuracy is :- 0.9999997348608591
#
#
# At random state 98,the training accuracy is :- 0.9999997783128006
# At random state 98,the testing accuracy is :- 0.9999996847650163
#
#
# At random state 99,the training accuracy is :- 0.9999997598639974
# At random state 99,the testing accuracy is :- 0.9999997172819092

# %%
features_train,features_test,target_train,target_test=train_test_split(features,target,test_size=0.2,random_state=12)

# %%
lr.fit(features_train,target_train)
# Out:
# LinearRegression()

# %%
pred_test=lr.predict(features_test)

# %%
print(r2_score(target_test,pred_test))
# Out:
# 0.9999997853490281

# %% [markdown]
# # Crosss-validation of the model

# %%
Train_accuracy=r2_score(target_train,pred_train)
Test_accuracy=r2_score(target_test,pred_test)

from sklearn.model_selection import cross_val_score
for j in range(2,10):
    cv_score=cross_val_score(lr,features,target,cv=j)
    cv_mean=cv_score.mean()
    print(f"At cross fold {j} the cv score is {cv_mean} and accuracy score for training is {Train_accuracy} and accuracy for the testing is {Test_accuracy}")
    print("\n")
# Out:
# At cross fold 2 the cv score is 0.9999995935490962 and accuracy score for training is -1.051977019955138 and accuracy for the testing is 0.9999997853490281
#
#
# At cross fold 3 the cv score is 0.9999996146875224 and accuracy score for training is -1.051977019955138 and accuracy for the testing is 0.9999997853490281
#
#
# At cross fold 4 the cv score is 0.9999996269981235 and accuracy score for training is -1.051977019955138 and accuracy for the testing is 0.9999997853490281
#
#
# At cross fold 5 the cv score is 0.9999995717380642 and accuracy score for training is -1.051977019955138 and accuracy for the testing is 0.9999997853490281
#
#
# At cross fold 6 the cv score is 0.9999995796837596 and accuracy score for training is -1.051977019955138 and accuracy for the testing is 0.9999997853490281
#
#
# At cross fold 7 the cv score is 0.999999595347368 and accuracy score for training is -1.051977019955138 and accuracy for the testing is 0.9999997853490281
#
#
# At cross fold 8 the cv score is 0.9999995913260951 and accuracy score for training is -1.051977019955138 and accuracy for the testing is 0.9999997853490281
#
#
# At cross fold 9 the cv score is 0.9999995591903649 and accuracy score for training is -1.051977019955138 and accuracy for the testing is 0.9999997853490281

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(8,6))
plt.scatter(x=target_test, y=pred_test, color='r')
plt.plot(target_test,target_test, color='b')
plt.xlabel('Actual charges',fontsize=14)
plt.ylabel('Predicted charges',fontsize=14)
plt.title('Linear Regression',fontsize=18)
plt.show()

# %% [markdown]
# # Regularization

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
import warnings
warnings.filterwarnings('ignore')

# %%
from sklearn.linear_model import Lasso

parameters = {'alpha' :[.0001, .001, .01, .1, 1, 10], 'random_state':list(range(0,10))}
ls = Lasso()
clf = GridSearchCV(ls,parameters)
clf.fit(features_train,target_train)

print(clf.best_params_)
# Out:
# {'alpha': 0.0001, 'random_state': 0}

# %%
ls = Lasso(alpha=1,random_state=0)
ls.fit(features_train,target_train)
ls.score(features_train,target_train)
pred_ls = ls.predict(features_test)

lss = r2_score(target_test,pred_ls)
lss
# Out:
# 0.27959147265639706

# %%
cv_score=cross_val_score(ls,features,target,cv=5)
cv_mean=cv_score.mean()
cv_mean
# Out:
# -0.1636479758117898

# %% [markdown]
# # Ensemble technique

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor

parameters = {'criterion':['mse', 'mae'],'max_features':["auto", "sqrt", "log2"]}
rf =RandomForestRegressor()
clf = GridSearchCV(rf,parameters)
clf.fit(features_train,target_train)

print(clf.best_params_)
# Out:
# {'criterion': 'mse', 'max_features': 'auto'}

# %%
rf= RandomForestRegressor(criterion="mse",max_features="auto")
rf.fit(features_train, target_train)
rf.score(features_train, target_train)
pred_decision = rf.predict(features_test)

rfs = r2_score(target_test,pred_decision)
print('R2 Score:',rfs*100)

rfscore = cross_val_score(rf,features,target,cv=5)
rfc = rfscore.mean()
print('Cross Val Score:',rfc*100)
# Out:
# R2 Score: 61.82293741505488
# Cross Val Score: -31.385998474072718

# %% [markdown]
# # We are getting model accuracy 61.82% and cross validation -31.38%

# %%
import pickle
filename = 'world_happiness_report.pkl'
pickle.dump(rf, open(filename, 'wb'))
